# %%
from collections import defaultdict

# %%
from erd import *

# %%
from erd import generate_erd_for_top_nodes

# %%
from mcli.lib.auth.mcli_manager import MCLIManager, MCLIInstance, MCLIConnectionParams, create_mcli_instance

# %%
from mcli.app.readiness.readiness import _do_generate_type_graph
from mcli.app.readiness.generate_graph import (
  load_graph_data, 
  find_top_level_nodes,
  build_hierarchical_graph,
  count_descendants,
  transform_graph
)

# %%
from mcli.lib.logger.logger import get_logger

# %%
logger = get_logger()

# %%
env_url = "https://stgawsrso.mcli.ai/lefvdev/panda009"
mcli_mngr = MCLIManager(env_url=env_url)
mcli = mcli_mngr.mcli_as_basic_user()

# %%
def generate_type_graph_command(output="realGraph.json", analyze=True, generate_erds=True, depth=2, top=5, js_file=None):
    """Generate a type graph from a MCLI cluster and optionally analyze it
    
    This command connects to a MCLI cluster, generates a merged graph of entity types,
    saves it to a file, and optionally analyzes it to identify top nodes for hierarchical exports.
    
    If --analyze is specified, the graph will be analyzed to identify top nodes.
    If --generate-erds is specified, ERDs will be generated for the top nodes.
    If --js-file is specified, the JavaScript code in that file will be used instead of the default.
    """
    logger.info(f"Starting generate-type-graph with output={output}, analyze={analyze}, generate_erds={generate_erds}, depth={depth}, top={top}")
    
    try:
        # Create output directory if it doesn't exist (for ERD output)
        if generate_erds:
            # Get project root directory
            project_root = Path(".")
            # Go up to project root (file -> readiness -> app -> mcli -> src -> project_root)
            output_dir = project_root / "output"
            if not output_dir.exists():
                output_dir.mkdir(exist_ok=True)
                logger.info(f"Created output directory: {output_dir}")
        
        # Check if realGraph.json exists if we're trying to analyze or generate ERDs without creating a new graph
        if (analyze or generate_erds) and output == "realGraph.json" and not Path(output).exists():
            click.echo(f"Warning: {output} does not exist. You need to generate the graph first.")
        
        # Load custom JavaScript if specified
        js_code = None
        if js_file:
            try:
                with open(js_file, 'r') as f:
                    js_code = f.read()
                click.echo(f"Loaded JavaScript code from {js_file}")
                logger.info(f"Loaded JavaScript code from {js_file}")
            except Exception as e:
                error_msg = f"Error loading JavaScript file: {e}"
                click.echo(error_msg)
                logger.error(error_msg)
                return
        
        # Generate the graph
        logger.info(f"Generating type graph to {output}")
        graph_file = _do_generate_type_graph(output_file=output, analyze=analyze, js_code=js_code)
        
        if not graph_file:
            error_msg = "Failed to save graph file."
            click.echo(error_msg)
            logger.error(error_msg)
            return
            
        success_msg = f"Graph saved to {graph_file}"
        click.echo(success_msg)
        logger.info(success_msg)
        
        return
        # Generate ERDs if requested
        if generate_erds:
            info_msg = f"Generating ERDs for top {top} nodes with depth {depth}..."
            click.echo(info_msg)
            logger.info(info_msg)
            
            try:
                # Ensure the graph file exists
                if not Path(graph_file).exists():
                    error_msg = f"Graph file {graph_file} does not exist. Cannot generate ERDs."
                    click.echo(error_msg)
                    logger.error(error_msg)
                    return
                
                # Generate the ERDs
                files = generate_erd_for_top_nodes(graph_file, max_depth=depth, top_n=top)
                
                if files and len(files) > 0:
                    click.echo("Generated the following ERD files:")
                    for dot_file, png_file, count in files:
                        click.echo(f"{png_file} - {count} descendants")
                        logger.info(f"Generated ERD: {png_file} with {count} descendants")
                else:
                    error_msg = "No ERD files were generated. Check if the graph contains valid entity relationships."
                    click.echo(error_msg)
                    logger.warning(error_msg)
            except Exception as e:
                error_msg = f"Error generating ERDs: {str(e)}"
                click.echo(error_msg)
                logger.error(error_msg)
                
    except Exception as e:
        error_msg = f"Error generating type graph: {str(e)}"
        click.echo(error_msg)
        logger.error(error_msg)
        import traceback
        logger.error(f"Traceback: {traceback.format_exc()}")
        raise

# %%
generate_type_graph_command()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 generate_type_graph_command()
#
# NameError: name 'generate_type_graph_command' is not defined

# %%
def build_adjacency_list(graph_data):
    """Build an adjacency list from the graph data."""
    logger.info("build_adjacency_list")
    try:
        # Extract vertices and edges
        vertices = graph_data["graph"]["m_vertices"]
        edges = graph_data["graph"]["m_edges"]
        logger.info(f"Found the following vertices: {len(vertices)}")
        logger.info(f"Found the following edges: {len(edges)}")
        
        # Create mapping of IDs to node info
        node_map = {node["id"]: node for node in vertices}
        
        # Build adjacency list (directed graph)
        adj_list = defaultdict(list)
        for edge in edges:
            source = edge["from"]["id"]
            target = edge["to"]["id"]
            adj_list[source].append(target)
        
        return node_map, adj_list
    except KeyError as e:
        raise ValueError(f"Invalid graph data structure: missing key {e}. Check the format of your graph data file.")
    except TypeError as e:
        raise ValueError(f"Invalid graph data structure: {e}. Check the format of your graph data file.")

# %%
graph_data = load_graph_data("./realGraph.json")

# %%
build_adjacency_list(graph_data=graph_data)
# Out:
# ({'CaseCommentAttachment': {'id': 'CaseCommentAttachment',
#    'category': 'Entity',
#    'data': {'name': 'CaseCommentAttachment',
#     'categoryMetadataIdentifier': 'CaseCommentAttachment',
#     'package': 'reliabilityAssetCase'}},
#   'FailureRecommendationRelation': {'id': 'FailureRecommendationRelation',
#    'category': 'Entity',
#    'data': {'name': 'FailureRecommendationRelation',
#     'categoryMetadataIdentifier': 'FailureRecommendationRelation',
#     'package': 'failureMechanismRecommendation'}},
#   'DataValidationRuleset': {'id': 'DataValidationRuleset',
#    'category': 'Entity',
#    'data': {'name': 'DataValidationRuleset',
#     'categoryMetadataIdentifier': 'DataValidationRuleset',
#     'package': 'dataValidation'}},
#   'Tas.Response': {'id': 'Tas.Response',
#    'category': 'Entity',
#    'data': {'name': 'Tas.Response',
#     'categoryMetadataIdentifier': 'Tas.Response',
#     'package': 'platform'}},
#   'MasterSensor': {'id': 'MasterSensor',
#    'category': 'Entity',
#    'data': {'name': 'MasterSensor',
#     'categoryMetadataIdentifier': 'MasterSensor',
#     'package': 'masterSensor'}},
#   'MlProject': {'id': 'MlProject',
#    'category': 'Entity',
#    'data': {'name': 'MlProject',
#     'categoryMetadataIdentifier': 'MlProject',
#     'package': 'platform'}},
#   'Tas.KnownIssue': {'id': 'Tas.KnownIssue',
#    'category': 'Entity',
#    'data': {'name': 'Tas.KnownIssue',
#     'categoryMetadataIdentifier': 'Tas.KnownIssue',
#     'package': 'platform'}},
#   'VectorStore.Collection': {'id': 'VectorStore.Collection',
#    'category': 'Entity',
#    'data': {'name': 'VectorStore.Collection',
#     'categoryMetadataIdentifier': 'VectorStore.Collection',
#     'package': 'platform'}},
#   'DataValidationRun': {'id': 'DataValidationRun',
#    'category': 'Entity',
#    'data': {'name': 'DataValidationRun',
#     'categoryMetadataIdentifier': 'DataValidationRun',
#     'package': 'dataValidation'}},
#   'SystemUpdate': {'id': 'SystemUpdate',
#    'category': 'Entity',
#    'data': {'name': 'SystemUpdate',
#     'categoryMetadataIdentifier': 'SystemUpdate',
#     'package': 'readiness'}},
#   'MlModel.Monitor.Result': {'id': 'MlModel.Monitor.Result',
#    'category': 'Entity',
#    'data': {'name': 'MlModel.Monitor.Result',
#     'categoryMetadataIdentifier': 'MlModel.Monitor.Result',
#     'package': 'platform'}},
#   'PrivilegeBase': {'id': 'PrivilegeBase',
#    'category': 'Entity',
#    'data': {'name': 'PrivilegeBase',
#     'categoryMetadataIdentifier': 'PrivilegeBase',
#     'package': 'platform'}},
#   'UiSdlPageGroup': {'id': 'UiSdlPageGroup',
#    'category': 'Entity',
#    'data': {'name': 'UiSdlPageGroup',
#     'categoryMetadataIdentifier': 'UiSdlPageGroup',
#     'package': 'uiComponentLibrary'}},
#   'ControlValvesModelableBase': {'id': 'ControlValvesModelableBase',
#    'category': 'Entity',
#    'data': {'name': 'ControlValvesModelableBase',
#     'categoryMetadataIdentifier': 'ControlValvesModelableBase',
#     'package': 'reliabilityMl'}},
#   'SensorBounds': {'id': 'SensorBounds',
#    'category': 'Entity',
#    'data': {'name': 'SensorBounds',
#     'categoryMetadataIdentifier': 'SensorBounds',
#     'package': 'readiness'}},
#   'FinancialAsset': {'id': 'FinancialAsset',
#    'category': 'Entity',
#    'data': {'name': 'FinancialAsset',
#     'categoryMetadataIdentifier': 'FinancialAsset',
#     'package': 'currency'}},
#   'TestUser': {'id': 'TestUser',
#    'category': 'Entity',
#    'data': {'name': 'TestUser',
#     'categoryMetadataIdentifier': 'TestUser',
#     'package': 'platform'}},
#   'ReliabilityCaseSegment': {'id': 'ReliabilityCaseSegment',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityCaseSegment',
#     'categoryMetadataIdentifier': 'ReliabilityCaseSegment',
#     'package': 'panda'}},
#   'TypeId': {'id': 'TypeId',
#    'category': 'Entity',
#    'data': {'name': 'TypeId',
#     'categoryMetadataIdentifier': 'TypeId',
#     'package': 'platform'}},
#   'MetricProfilerSpec': {'id': 'MetricProfilerSpec',
#    'category': 'Entity',
#    'data': {'name': 'MetricProfilerSpec',
#     'categoryMetadataIdentifier': 'MetricProfilerSpec',
#     'package': 'testtools'}},
#   'ReliabilitySyntheticData.ReliabilityRisk.DataGenerationJob': {'id': 'ReliabilitySyntheticData.ReliabilityRisk.DataGenerationJob',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilitySyntheticData.ReliabilityRisk.DataGenerationJob',
#     'categoryMetadataIdentifier': 'ReliabilitySyntheticData.ReliabilityRisk.DataGenerationJob',
#     'package': 'reliabilityDataModel'}},
#   'BaseCodeAnalysis.Metric.HardcodedCredentials.RegexRule': {'id': 'BaseCodeAnalysis.Metric.HardcodedCredentials.RegexRule',
#    'category': 'Entity',
#    'data': {'name': 'BaseCodeAnalysis.Metric.HardcodedCredentials.RegexRule',
#     'categoryMetadataIdentifier': 'BaseCodeAnalysis.Metric.HardcodedCredentials.RegexRule',
#     'package': 'baseCodeAnalyzer'}},
#   'SbaDartIngestSensorBatchJob': {'id': 'SbaDartIngestSensorBatchJob',
#    'category': 'Entity',
#    'data': {'name': 'SbaDartIngestSensorBatchJob',
#     'categoryMetadataIdentifier': 'SbaDartIngestSensorBatchJob',
#     'package': 'panda'}},
#   'MlWorkflowCoordinatableResult': {'id': 'MlWorkflowCoordinatableResult',
#    'category': 'Entity',
#    'data': {'name': 'MlWorkflowCoordinatableResult',
#     'categoryMetadataIdentifier': 'MlWorkflowCoordinatableResult',
#     'package': 'platform'}},
#   'GanttChartDemoResourceToCalendar': {'id': 'GanttChartDemoResourceToCalendar',
#    'category': 'Entity',
#    'data': {'name': 'GanttChartDemoResourceToCalendar',
#     'categoryMetadataIdentifier': 'GanttChartDemoResourceToCalendar',
#     'package': 'uiGanttChartDemo'}},
#   'Exchange': {'id': 'Exchange',
#    'category': 'Entity',
#    'data': {'name': 'Exchange',
#     'categoryMetadataIdentifier': 'Exchange',
#     'package': 'currency'}},
#   'Employee': {'id': 'Employee',
#    'category': 'Entity',
#    'data': {'name': 'Employee',
#     'categoryMetadataIdentifier': 'Employee',
#     'package': 'party'}},
#   'RateData': {'id': 'RateData',
#    'category': 'Entity',
#    'data': {'name': 'RateData',
#     'categoryMetadataIdentifier': 'RateData',
#     'package': 'currency'}},
#   'SourceTarget': {'id': 'SourceTarget',
#    'category': 'Entity',
#    'data': {'name': 'SourceTarget',
#     'categoryMetadataIdentifier': 'SourceTarget',
#     'package': 'baseCanonicalTester'}},
#   'Action.Spy.Claim': {'id': 'Action.Spy.Claim',
#    'category': 'Entity',
#    'data': {'name': 'Action.Spy.Claim',
#     'categoryMetadataIdentifier': 'Action.Spy.Claim',
#     'package': 'platform'}},
#   'PendingRefreshUniqueIndexesReq': {'id': 'PendingRefreshUniqueIndexesReq',
#    'category': 'Entity',
#    'data': {'name': 'PendingRefreshUniqueIndexesReq',
#     'categoryMetadataIdentifier': 'PendingRefreshUniqueIndexesReq',
#     'package': 'platform'}},
#   'ReliabilityRiskMl.Reconstruction.LightGBMPipe': {'id': 'ReliabilityRiskMl.Reconstruction.LightGBMPipe',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityRiskMl.Reconstruction.LightGBMPipe',
#     'categoryMetadataIdentifier': 'ReliabilityRiskMl.Reconstruction.LightGBMPipe',
#     'package': 'reliabilityMl'}},
#   'ModelRegistry.ModelDependency': {'id': 'ModelRegistry.ModelDependency',
#    'category': 'Entity',
#    'data': {'name': 'ModelRegistry.ModelDependency',
#     'categoryMetadataIdentifier': 'ModelRegistry.ModelDependency',
#     'package': 'platform'}},
#   'SqlCalcFieldsQueueEntry': {'id': 'SqlCalcFieldsQueueEntry',
#    'category': 'Entity',
#    'data': {'name': 'SqlCalcFieldsQueueEntry',
#     'categoryMetadataIdentifier': 'SqlCalcFieldsQueueEntry',
#     'package': 'platform'}},
#   'PhysicalAssetEvent': {'id': 'PhysicalAssetEvent',
#    'category': 'Entity',
#    'data': {'name': 'PhysicalAssetEvent',
#     'categoryMetadataIdentifier': 'PhysicalAssetEvent',
#     'package': 'physicalAsset'}},
#   'ItemFacilityInventoryParams': {'id': 'ItemFacilityInventoryParams',
#    'category': 'Entity',
#    'data': {'name': 'ItemFacilityInventoryParams',
#     'categoryMetadataIdentifier': 'ItemFacilityInventoryParams',
#     'package': 'item'}},
#   'MaintenanceDataSourceSpec': {'id': 'MaintenanceDataSourceSpec',
#    'category': 'Entity',
#    'data': {'name': 'MaintenanceDataSourceSpec',
#     'categoryMetadataIdentifier': 'MaintenanceDataSourceSpec',
#     'package': 'panda'}},
#   'CalcFieldIssue': {'id': 'CalcFieldIssue',
#    'category': 'Entity',
#    'data': {'name': 'CalcFieldIssue',
#     'categoryMetadataIdentifier': 'CalcFieldIssue',
#     'package': 'platform'}},
#   'TestScenario': {'id': 'TestScenario',
#    'category': 'Entity',
#    'data': {'name': 'TestScenario',
#     'categoryMetadataIdentifier': 'TestScenario',
#     'package': 'testtools'}},
#   'InvalidationQueuePaused': {'id': 'InvalidationQueuePaused',
#    'category': 'Entity',
#    'data': {'name': 'InvalidationQueuePaused',
#     'categoryMetadataIdentifier': 'InvalidationQueuePaused',
#     'package': 'platform'}},
#   'MlSubjectToModelRelation': {'id': 'MlSubjectToModelRelation',
#    'category': 'Entity',
#    'data': {'name': 'MlSubjectToModelRelation',
#     'categoryMetadataIdentifier': 'MlSubjectToModelRelation',
#     'package': 'platform'}},
#   'MlModel.Train.JobRun': {'id': 'MlModel.Train.JobRun',
#    'category': 'Entity',
#    'data': {'name': 'MlModel.Train.JobRun',
#     'categoryMetadataIdentifier': 'MlModel.Train.JobRun',
#     'package': 'platform'}},
#   'TestStateMachineWithAfterUpdate': {'id': 'TestStateMachineWithAfterUpdate',
#    'category': 'Entity',
#    'data': {'name': 'TestStateMachineWithAfterUpdate',
#     'categoryMetadataIdentifier': 'TestStateMachineWithAfterUpdate',
#     'package': 'stateMachineWorkflow'}},
#   'ReplacementPandaRulePredicter': {'id': 'ReplacementPandaRulePredicter',
#    'category': 'Entity',
#    'data': {'name': 'ReplacementPandaRulePredicter',
#     'categoryMetadataIdentifier': 'ReplacementPandaRulePredicter',
#     'package': 'panda'}},
#   'InvalidationQueueHistory': {'id': 'InvalidationQueueHistory',
#    'category': 'Entity',
#    'data': {'name': 'InvalidationQueueHistory',
#     'categoryMetadataIdentifier': 'InvalidationQueueHistory',
#     'package': 'platform'}},
#   'MlModel.Train.Job': {'id': 'MlModel.Train.Job',
#    'category': 'Entity',
#    'data': {'name': 'MlModel.Train.Job',
#     'categoryMetadataIdentifier': 'MlModel.Train.Job',
#     'package': 'platform'}},
#   'ReliabilityRiskMl.DataConcatenationPipe': {'id': 'ReliabilityRiskMl.DataConcatenationPipe',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityRiskMl.DataConcatenationPipe',
#     'categoryMetadataIdentifier': 'ReliabilityRiskMl.DataConcatenationPipe',
#     'package': 'reliabilityMl'}},
#   'SklearnLikePipe': {'id': 'SklearnLikePipe',
#    'category': 'Entity',
#    'data': {'name': 'SklearnLikePipe',
#     'categoryMetadataIdentifier': 'SklearnLikePipe',
#     'package': 'platform'}},
#   'SbaDartKeyCodeToFileMapping': {'id': 'SbaDartKeyCodeToFileMapping',
#    'category': 'Entity',
#    'data': {'name': 'SbaDartKeyCodeToFileMapping',
#     'categoryMetadataIdentifier': 'SbaDartKeyCodeToFileMapping',
#     'package': 'panda'}},
#   'PandaUser': {'id': 'PandaUser',
#    'category': 'Entity',
#    'data': {'name': 'PandaUser',
#     'categoryMetadataIdentifier': 'PandaUser',
#     'package': 'panda'}},
#   'SchemaSpreadsheetResult': {'id': 'SchemaSpreadsheetResult',
#    'category': 'Entity',
#    'data': {'name': 'SchemaSpreadsheetResult',
#     'categoryMetadataIdentifier': 'SchemaSpreadsheetResult',
#     'package': 'platform'}},
#   'SplunkSearchResult': {'id': 'SplunkSearchResult',
#    'category': 'Entity',
#    'data': {'name': 'SplunkSearchResult',
#     'categoryMetadataIdentifier': 'SplunkSearchResult',
#     'package': 'platform'}},
#   'Majcom': {'id': 'Majcom',
#    'category': 'Entity',
#    'data': {'name': 'Majcom',
#     'categoryMetadataIdentifier': 'Majcom',
#     'package': 'readiness'}},
#   'DbLockEntry': {'id': 'DbLockEntry',
#    'category': 'Entity',
#    'data': {'name': 'DbLockEntry',
#     'categoryMetadataIdentifier': 'DbLockEntry',
#     'package': 'platform'}},
#   'EventDFEMapper': {'id': 'EventDFEMapper',
#    'category': 'Entity',
#    'data': {'name': 'EventDFEMapper',
#     'categoryMetadataIdentifier': 'EventDFEMapper',
#     'package': 'platform'}},
#   'ReliabilityRiskMl.Pipeline.Interpreter.GeneralSimpleResidualInterpreter': {'id': 'ReliabilityRiskMl.Pipeline.Interpreter.GeneralSimpleResidualInterpreter',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityRiskMl.Pipeline.Interpreter.GeneralSimpleResidualInterpreter',
#     'categoryMetadataIdentifier': 'ReliabilityRiskMl.Pipeline.Interpreter.GeneralSimpleResidualInterpreter',
#     'package': 'reliabilityMl'}},
#   'TestStateMachineHistory': {'id': 'TestStateMachineHistory',
#    'category': 'Entity',
#    'data': {'name': 'TestStateMachineHistory',
#     'categoryMetadataIdentifier': 'TestStateMachineHistory',
#     'package': 'stateMachineWorkflow'}},
#   'DocPackage': {'id': 'DocPackage',
#    'category': 'Entity',
#    'data': {'name': 'DocPackage',
#     'categoryMetadataIdentifier': 'DocPackage',
#     'package': 'docgen'}},
#   'WebServiceConfig': {'id': 'WebServiceConfig',
#    'category': 'Entity',
#    'data': {'name': 'WebServiceConfig',
#     'categoryMetadataIdentifier': 'WebServiceConfig',
#     'package': 'platform'}},
#   'TargetStageKey': {'id': 'TargetStageKey',
#    'category': 'Entity',
#    'data': {'name': 'TargetStageKey',
#     'categoryMetadataIdentifier': 'TargetStageKey',
#     'package': 'platform'}},
#   'BatchTestStateMachineHistory': {'id': 'BatchTestStateMachineHistory',
#    'category': 'Entity',
#    'data': {'name': 'BatchTestStateMachineHistory',
#     'categoryMetadataIdentifier': 'BatchTestStateMachineHistory',
#     'package': 'stateMachineWorkflow'}},
#   'Reconstruction.ScoreAggregationPipe': {'id': 'Reconstruction.ScoreAggregationPipe',
#    'category': 'Entity',
#    'data': {'name': 'Reconstruction.ScoreAggregationPipe',
#     'categoryMetadataIdentifier': 'Reconstruction.ScoreAggregationPipe',
#     'package': 'reconstructionToolkit'}},
#   'Data.Spec': {'id': 'Data.Spec',
#    'category': 'Entity',
#    'data': {'name': 'Data.Spec',
#     'categoryMetadataIdentifier': 'Data.Spec',
#     'package': 'platform'}},
#   'CommentBoard': {'id': 'CommentBoard',
#    'category': 'Entity',
#    'data': {'name': 'CommentBoard',
#     'categoryMetadataIdentifier': 'CommentBoard',
#     'package': 'panda'}},
#   'ReliabilityAssetCaseFailureModeRelation': {'id': 'ReliabilityAssetCaseFailureModeRelation',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityAssetCaseFailureModeRelation',
#     'categoryMetadataIdentifier': 'ReliabilityAssetCaseFailureModeRelation',
#     'package': 'reliabilityAssetCase'}},
#   'ReadinessRiskMlModel': {'id': 'ReadinessRiskMlModel',
#    'category': 'Entity',
#    'data': {'name': 'ReadinessRiskMlModel',
#     'categoryMetadataIdentifier': 'ReadinessRiskMlModel',
#     'package': 'readiness'}},
#   'ScheduleHoliday': {'id': 'ScheduleHoliday',
#    'category': 'Entity',
#    'data': {'name': 'ScheduleHoliday',
#     'categoryMetadataIdentifier': 'ScheduleHoliday',
#     'package': 'schedule'}},
#   'AnalysisWorkflowState': {'id': 'AnalysisWorkflowState',
#    'category': 'Entity',
#    'data': {'name': 'AnalysisWorkflowState',
#     'categoryMetadataIdentifier': 'AnalysisWorkflowState',
#     'package': 'panda'}},
#   'MlModel.RuleRouter': {'id': 'MlModel.RuleRouter',
#    'category': 'Entity',
#    'data': {'name': 'MlModel.RuleRouter',
#     'categoryMetadataIdentifier': 'MlModel.RuleRouter',
#     'package': 'platform'}},
#   'BaseCanonicalTesterResults': {'id': 'BaseCanonicalTesterResults',
#    'category': 'Entity',
#    'data': {'name': 'BaseCanonicalTesterResults',
#     'categoryMetadataIdentifier': 'BaseCanonicalTesterResults',
#     'package': 'baseCanonicalTester'}},
#   'TargetStatus': {'id': 'TargetStatus',
#    'category': 'Entity',
#    'data': {'name': 'TargetStatus',
#     'categoryMetadataIdentifier': 'TargetStatus',
#     'package': 'platform'}},
#   'NormalizedTimeseriesPersister': {'id': 'NormalizedTimeseriesPersister',
#    'category': 'Entity',
#    'data': {'name': 'NormalizedTimeseriesPersister',
#     'categoryMetadataIdentifier': 'NormalizedTimeseriesPersister',
#     'package': 'platform'}},
#   'SandboxMdmDatasetToExcisionRuleMapping': {'id': 'SandboxMdmDatasetToExcisionRuleMapping',
#    'category': 'Entity',
#    'data': {'name': 'SandboxMdmDatasetToExcisionRuleMapping',
#     'categoryMetadataIdentifier': 'SandboxMdmDatasetToExcisionRuleMapping',
#     'package': 'panda'}},
#   'WorkOrderUpdateLogMergeBatchJob': {'id': 'WorkOrderUpdateLogMergeBatchJob',
#    'category': 'Entity',
#    'data': {'name': 'WorkOrderUpdateLogMergeBatchJob',
#     'categoryMetadataIdentifier': 'WorkOrderUpdateLogMergeBatchJob',
#     'package': 'reliabilityDataModel'}},
#   'MaximGunUser': {'id': 'MaximGunUser',
#    'category': 'Entity',
#    'data': {'name': 'MaximGunUser',
#     'categoryMetadataIdentifier': 'MaximGunUser',
#     'package': 'platform'}},
#   'TestSpyAnimal': {'id': 'TestSpyAnimal',
#    'category': 'Entity',
#    'data': {'name': 'TestSpyAnimal',
#     'categoryMetadataIdentifier': 'TestSpyAnimal',
#     'package': 'testtools'}},
#   'RefreshAnalyticsBatchJob': {'id': 'RefreshAnalyticsBatchJob',
#    'category': 'Entity',
#    'data': {'name': 'RefreshAnalyticsBatchJob',
#     'categoryMetadataIdentifier': 'RefreshAnalyticsBatchJob',
#     'package': 'platform'}},
#   'StagingRemisOnEquipmentMaintenanceActionTable': {'id': 'StagingRemisOnEquipmentMaintenanceActionTable',
#    'category': 'Entity',
#    'data': {'name': 'StagingRemisOnEquipmentMaintenanceActionTable',
#     'categoryMetadataIdentifier': 'StagingRemisOnEquipmentMaintenanceActionTable',
#     'package': 'panda'}},
#   'TargetExampleThree': {'id': 'TargetExampleThree',
#    'category': 'Entity',
#    'data': {'name': 'TargetExampleThree',
#     'categoryMetadataIdentifier': 'TargetExampleThree',
#     'package': 'baseCanonicalTester'}},
#   'BatchJob': {'id': 'BatchJob',
#    'category': 'Entity',
#    'data': {'name': 'BatchJob',
#     'categoryMetadataIdentifier': 'BatchJob',
#     'package': 'platform'}},
#   'MaintenanceSeverityCode': {'id': 'MaintenanceSeverityCode',
#    'category': 'Entity',
#    'data': {'name': 'MaintenanceSeverityCode',
#     'categoryMetadataIdentifier': 'MaintenanceSeverityCode',
#     'package': 'panda'}},
#   'SecondaryDsUpsert': {'id': 'SecondaryDsUpsert',
#    'category': 'Entity',
#    'data': {'name': 'SecondaryDsUpsert',
#     'categoryMetadataIdentifier': 'SecondaryDsUpsert',
#     'package': 'platform'}},
#   'SbaDegScoreInterpreter': {'id': 'SbaDegScoreInterpreter',
#    'category': 'Entity',
#    'data': {'name': 'SbaDegScoreInterpreter',
#     'categoryMetadataIdentifier': 'SbaDegScoreInterpreter',
#     'package': 'panda'}},
#   'PartyRole': {'id': 'PartyRole',
#    'category': 'Entity',
#    'data': {'name': 'PartyRole',
#     'categoryMetadataIdentifier': 'PartyRole',
#     'package': 'party'}},
#   'DataLake.Table.ShareRequest': {'id': 'DataLake.Table.ShareRequest',
#    'category': 'Entity',
#    'data': {'name': 'DataLake.Table.ShareRequest',
#     'categoryMetadataIdentifier': 'DataLake.Table.ShareRequest',
#     'package': 'platform'}},
#   'InventoryItemKits': {'id': 'InventoryItemKits',
#    'category': 'Entity',
#    'data': {'name': 'InventoryItemKits',
#     'categoryMetadataIdentifier': 'InventoryItemKits',
#     'package': 'panda'}},
#   'ReliabilityRiskMl.DataColumnSelectionPipe': {'id': 'ReliabilityRiskMl.DataColumnSelectionPipe',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityRiskMl.DataColumnSelectionPipe',
#     'categoryMetadataIdentifier': 'ReliabilityRiskMl.DataColumnSelectionPipe',
#     'package': 'reliabilityMl'}},
#   'Hpo.Experiment': {'id': 'Hpo.Experiment',
#    'category': 'Entity',
#    'data': {'name': 'Hpo.Experiment',
#     'categoryMetadataIdentifier': 'Hpo.Experiment',
#     'package': 'platform'}},
#   'StagingRemisActualConfigurationWorkUnitCodeTable': {'id': 'StagingRemisActualConfigurationWorkUnitCodeTable',
#    'category': 'Entity',
#    'data': {'name': 'StagingRemisActualConfigurationWorkUnitCodeTable',
#     'categoryMetadataIdentifier': 'StagingRemisActualConfigurationWorkUnitCodeTable',
#     'package': 'panda'}},
#   'SensorDataReport': {'id': 'SensorDataReport',
#    'category': 'Entity',
#    'data': {'name': 'SensorDataReport',
#     'categoryMetadataIdentifier': 'SensorDataReport',
#     'package': 'reliabilityMl'}},
#   'ReliabilityAssetAlertToCaseRelation': {'id': 'ReliabilityAssetAlertToCaseRelation',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityAssetAlertToCaseRelation',
#     'categoryMetadataIdentifier': 'ReliabilityAssetAlertToCaseRelation',
#     'package': 'reliabilityAssetCase'}},
#   'Workflow.Run.Nested.Action': {'id': 'Workflow.Run.Nested.Action',
#    'category': 'Entity',
#    'data': {'name': 'Workflow.Run.Nested.Action',
#     'categoryMetadataIdentifier': 'Workflow.Run.Nested.Action',
#     'package': 'platform'}},
#   'GanttChartDemoEvent': {'id': 'GanttChartDemoEvent',
#    'category': 'Entity',
#    'data': {'name': 'GanttChartDemoEvent',
#     'categoryMetadataIdentifier': 'GanttChartDemoEvent',
#     'package': 'uiGanttChartDemo'}},
#   'FakeTypeOne': {'id': 'FakeTypeOne',
#    'category': 'Entity',
#    'data': {'name': 'FakeTypeOne',
#     'categoryMetadataIdentifier': 'FakeTypeOne',
#     'package': 'pdfGeneration'}},
#   'SqlPiiQueueEntry': {'id': 'SqlPiiQueueEntry',
#    'category': 'Entity',
#    'data': {'name': 'SqlPiiQueueEntry',
#     'categoryMetadataIdentifier': 'SqlPiiQueueEntry',
#     'package': 'platform'}},
#   'RollupMetricBatchJob': {'id': 'RollupMetricBatchJob',
#    'category': 'Entity',
#    'data': {'name': 'RollupMetricBatchJob',
#     'categoryMetadataIdentifier': 'RollupMetricBatchJob',
#     'package': 'rollupMetricBatchJob'}},
#   'FileSystemBatchJob': {'id': 'FileSystemBatchJob',
#    'category': 'Entity',
#    'data': {'name': 'FileSystemBatchJob',
#     'categoryMetadataIdentifier': 'FileSystemBatchJob',
#     'package': 'platform'}},
#   'JSBatchJob': {'id': 'JSBatchJob',
#    'category': 'Entity',
#    'data': {'name': 'JSBatchJob',
#     'categoryMetadataIdentifier': 'JSBatchJob',
#     'package': 'platform'}},
#   'TestAffiliationAssociation': {'id': 'TestAffiliationAssociation',
#    'category': 'Entity',
#    'data': {'name': 'TestAffiliationAssociation',
#     'categoryMetadataIdentifier': 'TestAffiliationAssociation',
#     'package': 'physicalAsset'}},
#   'StagingRemisReportingOrganizationTable': {'id': 'StagingRemisReportingOrganizationTable',
#    'category': 'Entity',
#    'data': {'name': 'StagingRemisReportingOrganizationTable',
#     'categoryMetadataIdentifier': 'StagingRemisReportingOrganizationTable',
#     'package': 'panda'}},
#   'ClusterBoundPoint': {'id': 'ClusterBoundPoint',
#    'category': 'Entity',
#    'data': {'name': 'ClusterBoundPoint',
#     'categoryMetadataIdentifier': 'ClusterBoundPoint',
#     'package': 'platform'}},
#   'CodeSample': {'id': 'CodeSample',
#    'category': 'Entity',
#    'data': {'name': 'CodeSample',
#     'categoryMetadataIdentifier': 'CodeSample',
#     'package': 'platform'}},
#   'SqlSqsQueueEntry': {'id': 'SqlSqsQueueEntry',
#    'category': 'Entity',
#    'data': {'name': 'SqlSqsQueueEntry',
#     'categoryMetadataIdentifier': 'SqlSqsQueueEntry',
#     'package': 'platform'}},
#   'StagingRemisOnEquipmentWorkOrderTable': {'id': 'StagingRemisOnEquipmentWorkOrderTable',
#    'category': 'Entity',
#    'data': {'name': 'StagingRemisOnEquipmentWorkOrderTable',
#     'categoryMetadataIdentifier': 'StagingRemisOnEquipmentWorkOrderTable',
#     'package': 'panda'}},
#   'ItemPartyRole': {'id': 'ItemPartyRole',
#    'category': 'Entity',
#    'data': {'name': 'ItemPartyRole',
#     'categoryMetadataIdentifier': 'ItemPartyRole',
#     'package': 'item'}},
#   'Persistable.Bin.Strategy.Custom': {'id': 'Persistable.Bin.Strategy.Custom',
#    'category': 'Entity',
#    'data': {'name': 'Persistable.Bin.Strategy.Custom',
#     'categoryMetadataIdentifier': 'Persistable.Bin.Strategy.Custom',
#     'package': 'platform'}},
#   'Reconstruction.Post.AppendDataByStatePipe': {'id': 'Reconstruction.Post.AppendDataByStatePipe',
#    'category': 'Entity',
#    'data': {'name': 'Reconstruction.Post.AppendDataByStatePipe',
#     'categoryMetadataIdentifier': 'Reconstruction.Post.AppendDataByStatePipe',
#     'package': 'reconstructionToolkit'}},
#   'Action.Spy.Registry': {'id': 'Action.Spy.Registry',
#    'category': 'Entity',
#    'data': {'name': 'Action.Spy.Registry',
#     'categoryMetadataIdentifier': 'Action.Spy.Registry',
#     'package': 'platform'}},
#   'UserAccessRequestTransition': {'id': 'UserAccessRequestTransition',
#    'category': 'Entity',
#    'data': {'name': 'UserAccessRequestTransition',
#     'categoryMetadataIdentifier': 'UserAccessRequestTransition',
#     'package': 'panda'}},
#   'EtlLog': {'id': 'EtlLog',
#    'category': 'Entity',
#    'data': {'name': 'EtlLog',
#     'categoryMetadataIdentifier': 'EtlLog',
#     'package': 'platform'}},
#   'KerasPipeCpu': {'id': 'KerasPipeCpu',
#    'category': 'Entity',
#    'data': {'name': 'KerasPipeCpu',
#     'categoryMetadataIdentifier': 'KerasPipeCpu',
#     'package': 'platform'}},
#   'TimeOnWingJob': {'id': 'TimeOnWingJob',
#    'category': 'Entity',
#    'data': {'name': 'TimeOnWingJob',
#     'categoryMetadataIdentifier': 'TimeOnWingJob',
#     'package': 'panda'}},
#   'X12ParserProperties': {'id': 'X12ParserProperties',
#    'category': 'Entity',
#    'data': {'name': 'X12ParserProperties',
#     'categoryMetadataIdentifier': 'X12ParserProperties',
#     'package': 'platform'}},
#   'NsnToWucMapping': {'id': 'NsnToWucMapping',
#    'category': 'Entity',
#    'data': {'name': 'NsnToWucMapping',
#     'categoryMetadataIdentifier': 'NsnToWucMapping',
#     'package': 'panda'}},
#   'DataApiEntityType': {'id': 'DataApiEntityType',
#    'category': 'Entity',
#    'data': {'name': 'DataApiEntityType',
#     'categoryMetadataIdentifier': 'DataApiEntityType',
#     'package': 'testtools'}},
#   'HealthCheckLog': {'id': 'HealthCheckLog',
#    'category': 'Entity',
#    'data': {'name': 'HealthCheckLog',
#     'categoryMetadataIdentifier': 'HealthCheckLog',
#     'package': 'platform'}},
#   'PendingRefreshReq': {'id': 'PendingRefreshReq',
#    'category': 'Entity',
#    'data': {'name': 'PendingRefreshReq',
#     'categoryMetadataIdentifier': 'PendingRefreshReq',
#     'package': 'platform'}},
#   'SqlKinesisQueueEntry': {'id': 'SqlKinesisQueueEntry',
#    'category': 'Entity',
#    'data': {'name': 'SqlKinesisQueueEntry',
#     'categoryMetadataIdentifier': 'SqlKinesisQueueEntry',
#     'package': 'platform'}},
#   'SourceStatus': {'id': 'SourceStatus',
#    'category': 'Entity',
#    'data': {'name': 'SourceStatus',
#     'categoryMetadataIdentifier': 'SourceStatus',
#     'package': 'platform'}},
#   'Action.Mock.Auto': {'id': 'Action.Mock.Auto',
#    'category': 'Entity',
#    'data': {'name': 'Action.Mock.Auto',
#     'categoryMetadataIdentifier': 'Action.Mock.Auto',
#     'package': 'platform'}},
#   'MlModel.Evaluator': {'id': 'MlModel.Evaluator',
#    'category': 'Entity',
#    'data': {'name': 'MlModel.Evaluator',
#     'categoryMetadataIdentifier': 'MlModel.Evaluator',
#     'package': 'platform'}},
#   'AssetClassParentChildRelation': {'id': 'AssetClassParentChildRelation',
#    'category': 'Entity',
#    'data': {'name': 'AssetClassParentChildRelation',
#     'categoryMetadataIdentifier': 'AssetClassParentChildRelation',
#     'package': 'reliabilityDataModel'}},
#   'TranslationIssue': {'id': 'TranslationIssue',
#    'category': 'Entity',
#    'data': {'name': 'TranslationIssue',
#     'categoryMetadataIdentifier': 'TranslationIssue',
#     'package': 'platform'}},
#   'AircraftAssignment': {'id': 'AircraftAssignment',
#    'category': 'Entity',
#    'data': {'name': 'AircraftAssignment',
#     'categoryMetadataIdentifier': 'AircraftAssignment',
#     'package': 'panda'}},
#   'ReduceResult': {'id': 'ReduceResult',
#    'category': 'Entity',
#    'data': {'name': 'ReduceResult',
#     'categoryMetadataIdentifier': 'ReduceResult',
#     'package': 'platform'}},
#   'StagingRemisOffEquipmentWorkCenterEventDiscrepancyNarrativeTable': {'id': 'StagingRemisOffEquipmentWorkCenterEventDiscrepancyNarrativeTable',
#    'category': 'Entity',
#    'data': {'name': 'StagingRemisOffEquipmentWorkCenterEventDiscrepancyNarrativeTable',
#     'categoryMetadataIdentifier': 'StagingRemisOffEquipmentWorkCenterEventDiscrepancyNarrativeTable',
#     'package': 'panda'}},
#   'ReliabilityAssetTteAlert': {'id': 'ReliabilityAssetTteAlert',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityAssetTteAlert',
#     'categoryMetadataIdentifier': 'ReliabilityAssetTteAlert',
#     'package': 'reliabilityMl'}},
#   'RawRemisData': {'id': 'RawRemisData',
#    'category': 'Entity',
#    'data': {'name': 'RawRemisData',
#     'categoryMetadataIdentifier': 'RawRemisData',
#     'package': 'panda'}},
#   'PhysicalAssetEventResponse': {'id': 'PhysicalAssetEventResponse',
#    'category': 'Entity',
#    'data': {'name': 'PhysicalAssetEventResponse',
#     'categoryMetadataIdentifier': 'PhysicalAssetEventResponse',
#     'package': 'physicalAsset'}},
#   'ReliabilityMl.ValidationPrediction': {'id': 'ReliabilityMl.ValidationPrediction',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityMl.ValidationPrediction',
#     'categoryMetadataIdentifier': 'ReliabilityMl.ValidationPrediction',
#     'package': 'reliabilityMl'}},
#   'Persistable.Bin.Strategy.Custom.State': {'id': 'Persistable.Bin.Strategy.Custom.State',
#    'category': 'Entity',
#    'data': {'name': 'Persistable.Bin.Strategy.Custom.State',
#     'categoryMetadataIdentifier': 'Persistable.Bin.Strategy.Custom.State',
#     'package': 'platform'}},
#   'UiSdlMetadataFileManifest': {'id': 'UiSdlMetadataFileManifest',
#    'category': 'Entity',
#    'data': {'name': 'UiSdlMetadataFileManifest',
#     'categoryMetadataIdentifier': 'UiSdlMetadataFileManifest',
#     'package': 'uiInfrastructure'}},
#   'DataValidationPersistedResult': {'id': 'DataValidationPersistedResult',
#    'category': 'Entity',
#    'data': {'name': 'DataValidationPersistedResult',
#     'categoryMetadataIdentifier': 'DataValidationPersistedResult',
#     'package': 'dataValidation'}},
#   'ReliabilityMlModel': {'id': 'ReliabilityMlModel',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityMlModel',
#     'categoryMetadataIdentifier': 'ReliabilityMlModel',
#     'package': 'reliabilityMl'}},
#   'SbaAdvanaToPandaDatalakeFileCopyJob': {'id': 'SbaAdvanaToPandaDatalakeFileCopyJob',
#    'category': 'Entity',
#    'data': {'name': 'SbaAdvanaToPandaDatalakeFileCopyJob',
#     'categoryMetadataIdentifier': 'SbaAdvanaToPandaDatalakeFileCopyJob',
#     'package': 'panda'}},
#   'SqlMetricDepsQueueEntry': {'id': 'SqlMetricDepsQueueEntry',
#    'category': 'Entity',
#    'data': {'name': 'SqlMetricDepsQueueEntry',
#     'categoryMetadataIdentifier': 'SqlMetricDepsQueueEntry',
#     'package': 'platform'}},
#   'ReliabilityMl.ModelReport': {'id': 'ReliabilityMl.ModelReport',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityMl.ModelReport',
#     'categoryMetadataIdentifier': 'ReliabilityMl.ModelReport',
#     'package': 'reliabilityMl'}},
#   'TargetExampleTDH': {'id': 'TargetExampleTDH',
#    'category': 'Entity',
#    'data': {'name': 'TargetExampleTDH',
#     'categoryMetadataIdentifier': 'TargetExampleTDH',
#     'package': 'baseCanonicalTester'}},
#   'ScheduleExceptionDatetimeWindow': {'id': 'ScheduleExceptionDatetimeWindow',
#    'category': 'Entity',
#    'data': {'name': 'ScheduleExceptionDatetimeWindow',
#     'categoryMetadataIdentifier': 'ScheduleExceptionDatetimeWindow',
#     'package': 'schedule'}},
#   'SchemaMigrationVersion': {'id': 'SchemaMigrationVersion',
#    'category': 'Entity',
#    'data': {'name': 'SchemaMigrationVersion',
#     'categoryMetadataIdentifier': 'SchemaMigrationVersion',
#     'package': 'platform'}},
#   'ReliabilityAssetToModelValidationRelation': {'id': 'ReliabilityAssetToModelValidationRelation',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityAssetToModelValidationRelation',
#     'categoryMetadataIdentifier': 'ReliabilityAssetToModelValidationRelation',
#     'package': 'reliabilityMl'}},
#   'Rate': {'id': 'Rate',
#    'category': 'Entity',
#    'data': {'name': 'Rate',
#     'categoryMetadataIdentifier': 'Rate',
#     'package': 'currency'}},
#   'Publication': {'id': 'Publication',
#    'category': 'Entity',
#    'data': {'name': 'Publication',
#     'categoryMetadataIdentifier': 'Publication',
#     'package': 'platform'}},
#   'VaultCertificate': {'id': 'VaultCertificate',
#    'category': 'Entity',
#    'data': {'name': 'VaultCertificate',
#     'categoryMetadataIdentifier': 'VaultCertificate',
#     'package': 'platform'}},
#   'ReliabilityRiskScoreMlValidationContribution': {'id': 'ReliabilityRiskScoreMlValidationContribution',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityRiskScoreMlValidationContribution',
#     'categoryMetadataIdentifier': 'ReliabilityRiskScoreMlValidationContribution',
#     'package': 'reliabilityMl'}},
#   'DeltaNiinDemandForecast': {'id': 'DeltaNiinDemandForecast',
#    'category': 'Entity',
#    'data': {'name': 'DeltaNiinDemandForecast',
#     'categoryMetadataIdentifier': 'DeltaNiinDemandForecast',
#     'package': 'panda'}},
#   'AwsCloudWatchDimensions': {'id': 'AwsCloudWatchDimensions',
#    'category': 'Entity',
#    'data': {'name': 'AwsCloudWatchDimensions',
#     'categoryMetadataIdentifier': 'AwsCloudWatchDimensions',
#     'package': 'platform'}},
#   'ReliabilityRiskScoreMlContribution': {'id': 'ReliabilityRiskScoreMlContribution',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityRiskScoreMlContribution',
#     'categoryMetadataIdentifier': 'ReliabilityRiskScoreMlContribution',
#     'package': 'reliabilityMl'}},
#   'InvalidationQueueErrorReviewComment': {'id': 'InvalidationQueueErrorReviewComment',
#    'category': 'Entity',
#    'data': {'name': 'InvalidationQueueErrorReviewComment',
#     'categoryMetadataIdentifier': 'InvalidationQueueErrorReviewComment',
#     'package': 'platform'}},
#   'TestPersistable': {'id': 'TestPersistable',
#    'category': 'Entity',
#    'data': {'name': 'TestPersistable',
#     'categoryMetadataIdentifier': 'TestPersistable',
#     'package': 'testtools'}},
#   'NormalizedTimeseriesHotColdMigrator': {'id': 'NormalizedTimeseriesHotColdMigrator',
#    'category': 'Entity',
#    'data': {'name': 'NormalizedTimeseriesHotColdMigrator',
#     'categoryMetadataIdentifier': 'NormalizedTimeseriesHotColdMigrator',
#     'package': 'platform'}},
#   'TestFileAttachment': {'id': 'TestFileAttachment',
#    'category': 'Entity',
#    'data': {'name': 'TestFileAttachment',
#     'categoryMetadataIdentifier': 'TestFileAttachment',
#     'package': 'fileAttachment'}},
#   'Workflow.Run.Make': {'id': 'Workflow.Run.Make',
#    'category': 'Entity',
#    'data': {'name': 'Workflow.Run.Make',
#     'categoryMetadataIdentifier': 'Workflow.Run.Make',
#     'package': 'platform'}},
#   'Person': {'id': 'Person',
#    'category': 'Entity',
#    'data': {'name': 'Person',
#     'categoryMetadataIdentifier': 'Person',
#     'package': 'party'}},
#   'TestMajcom': {'id': 'TestMajcom',
#    'category': 'Entity',
#    'data': {'name': 'TestMajcom',
#     'categoryMetadataIdentifier': 'TestMajcom',
#     'package': 'panda'}},
#   'Organization': {'id': 'Organization',
#    'category': 'Entity',
#    'data': {'name': 'Organization',
#     'categoryMetadataIdentifier': 'Organization',
#     'package': 'party'}},
#   'InvalidationQueueError': {'id': 'InvalidationQueueError',
#    'category': 'Entity',
#    'data': {'name': 'InvalidationQueueError',
#     'categoryMetadataIdentifier': 'InvalidationQueueError',
#     'package': 'platform'}},
#   'X12Segment': {'id': 'X12Segment',
#    'category': 'Entity',
#    'data': {'name': 'X12Segment',
#     'categoryMetadataIdentifier': 'X12Segment',
#     'package': 'platform'}},
#   'FacilityReliabilityAssetRelation': {'id': 'FacilityReliabilityAssetRelation',
#    'category': 'Entity',
#    'data': {'name': 'FacilityReliabilityAssetRelation',
#     'categoryMetadataIdentifier': 'FacilityReliabilityAssetRelation',
#     'package': 'reliabilityDataModel'}},
#   'MdmExcisionRule': {'id': 'MdmExcisionRule',
#    'category': 'Entity',
#    'data': {'name': 'MdmExcisionRule',
#     'categoryMetadataIdentifier': 'MdmExcisionRule',
#     'package': 'panda'}},
#   'FlightHourForecast': {'id': 'FlightHourForecast',
#    'category': 'Entity',
#    'data': {'name': 'FlightHourForecast',
#     'categoryMetadataIdentifier': 'FlightHourForecast',
#     'package': 'panda'}},
#   'PhysicalAssetCategory': {'id': 'PhysicalAssetCategory',
#    'category': 'Entity',
#    'data': {'name': 'PhysicalAssetCategory',
#     'categoryMetadataIdentifier': 'PhysicalAssetCategory',
#     'package': 'physicalAsset'}},
#   'MlModel.Train.Result': {'id': 'MlModel.Train.Result',
#    'category': 'Entity',
#    'data': {'name': 'MlModel.Train.Result',
#     'categoryMetadataIdentifier': 'MlModel.Train.Result',
#     'package': 'platform'}},
#   'AbstractHelpContent': {'id': 'AbstractHelpContent',
#    'category': 'Entity',
#    'data': {'name': 'AbstractHelpContent',
#     'categoryMetadataIdentifier': 'AbstractHelpContent',
#     'package': 'panda'}},
#   'Feature.Set.ExportSnapshotJob': {'id': 'Feature.Set.ExportSnapshotJob',
#    'category': 'Entity',
#    'data': {'name': 'Feature.Set.ExportSnapshotJob',
#     'categoryMetadataIdentifier': 'Feature.Set.ExportSnapshotJob',
#     'package': 'platform'}},
#   'Workflow.Run': {'id': 'Workflow.Run',
#    'category': 'Entity',
#    'data': {'name': 'Workflow.Run',
#     'categoryMetadataIdentifier': 'Workflow.Run',
#     'package': 'platform'}},
#   'EnvReport': {'id': 'EnvReport',
#    'category': 'Entity',
#    'data': {'name': 'EnvReport',
#     'categoryMetadataIdentifier': 'EnvReport',
#     'package': 'platform'}},
#   'SbaDartDataFile': {'id': 'SbaDartDataFile',
#    'category': 'Entity',
#    'data': {'name': 'SbaDartDataFile',
#     'categoryMetadataIdentifier': 'SbaDartDataFile',
#     'package': 'panda'}},
#   'ReadinessOperation': {'id': 'ReadinessOperation',
#    'category': 'Entity',
#    'data': {'name': 'ReadinessOperation',
#     'categoryMetadataIdentifier': 'ReadinessOperation',
#     'package': 'readiness'}},
#   'GuideDocExport': {'id': 'GuideDocExport',
#    'category': 'Entity',
#    'data': {'name': 'GuideDocExport',
#     'categoryMetadataIdentifier': 'GuideDocExport',
#     'package': 'docgen'}},
#   'RegionHierarchyDenorm': {'id': 'RegionHierarchyDenorm',
#    'category': 'Entity',
#    'data': {'name': 'RegionHierarchyDenorm',
#     'categoryMetadataIdentifier': 'RegionHierarchyDenorm',
#     'package': 'location'}},
#   'User.Event.Login': {'id': 'User.Event.Login',
#    'category': 'Entity',
#    'data': {'name': 'User.Event.Login',
#     'categoryMetadataIdentifier': 'User.Event.Login',
#     'package': 'platform'}},
#   'ObservedK8sPod': {'id': 'ObservedK8sPod',
#    'category': 'Entity',
#    'data': {'name': 'ObservedK8sPod',
#     'categoryMetadataIdentifier': 'ObservedK8sPod',
#     'package': 'platform'}},
#   'TargetExampleTDP': {'id': 'TargetExampleTDP',
#    'category': 'Entity',
#    'data': {'name': 'TargetExampleTDP',
#     'categoryMetadataIdentifier': 'TargetExampleTDP',
#     'package': 'baseCanonicalTester'}},
#   'JobStatusTracker': {'id': 'JobStatusTracker',
#    'category': 'Entity',
#    'data': {'name': 'JobStatusTracker',
#     'categoryMetadataIdentifier': 'JobStatusTracker',
#     'package': 'testtools'}},
#   'MlPipe': {'id': 'MlPipe',
#    'category': 'Entity',
#    'data': {'name': 'MlPipe',
#     'categoryMetadataIdentifier': 'MlPipe',
#     'package': 'platform'}},
#   'TSPerfTest': {'id': 'TSPerfTest',
#    'category': 'Entity',
#    'data': {'name': 'TSPerfTest',
#     'categoryMetadataIdentifier': 'TSPerfTest',
#     'package': 'testtools'}},
#   'DataLoadError': {'id': 'DataLoadError',
#    'category': 'Entity',
#    'data': {'name': 'DataLoadError',
#     'categoryMetadataIdentifier': 'DataLoadError',
#     'package': 'panda'}},
#   'SignUpToken': {'id': 'SignUpToken',
#    'category': 'Entity',
#    'data': {'name': 'SignUpToken',
#     'categoryMetadataIdentifier': 'SignUpToken',
#     'package': 'platform'}},
#   'Checkpoint': {'id': 'Checkpoint',
#    'category': 'Entity',
#    'data': {'name': 'Checkpoint',
#     'categoryMetadataIdentifier': 'Checkpoint',
#     'package': 'platform'}},
#   'GanttChartDemoEventGroup': {'id': 'GanttChartDemoEventGroup',
#    'category': 'Entity',
#    'data': {'name': 'GanttChartDemoEventGroup',
#     'categoryMetadataIdentifier': 'GanttChartDemoEventGroup',
#     'package': 'uiGanttChartDemo'}},
#   'MLDataSourceSpec': {'id': 'MLDataSourceSpec',
#    'category': 'Entity',
#    'data': {'name': 'MLDataSourceSpec',
#     'categoryMetadataIdentifier': 'MLDataSourceSpec',
#     'package': 'platform'}},
#   'ObservedEvent': {'id': 'ObservedEvent',
#    'category': 'Entity',
#    'data': {'name': 'ObservedEvent',
#     'categoryMetadataIdentifier': 'ObservedEvent',
#     'package': 'platform'}},
#   'MlModel.Route.OperationJob': {'id': 'MlModel.Route.OperationJob',
#    'category': 'Entity',
#    'data': {'name': 'MlModel.Route.OperationJob',
#     'categoryMetadataIdentifier': 'MlModel.Route.OperationJob',
#     'package': 'platform'}},
#   'ReadinessAlertComment': {'id': 'ReadinessAlertComment',
#    'category': 'Entity',
#    'data': {'name': 'ReadinessAlertComment',
#     'categoryMetadataIdentifier': 'ReadinessAlertComment',
#     'package': 'readiness'}},
#   'TypeMetaDocGetterSampleType': {'id': 'TypeMetaDocGetterSampleType',
#    'category': 'Entity',
#    'data': {'name': 'TypeMetaDocGetterSampleType',
#     'categoryMetadataIdentifier': 'TypeMetaDocGetterSampleType',
#     'package': 'reliabilityDataModel'}},
#   'PartitionableCompactionIssue': {'id': 'PartitionableCompactionIssue',
#    'category': 'Entity',
#    'data': {'name': 'PartitionableCompactionIssue',
#     'categoryMetadataIdentifier': 'PartitionableCompactionIssue',
#     'package': 'platform'}},
#   'ReliabilityRiskMl.Reconstruction.ElasticNetPipe': {'id': 'ReliabilityRiskMl.Reconstruction.ElasticNetPipe',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityRiskMl.Reconstruction.ElasticNetPipe',
#     'categoryMetadataIdentifier': 'ReliabilityRiskMl.Reconstruction.ElasticNetPipe',
#     'package': 'reliabilityMl'}},
#   'ForecastedAircraftPart': {'id': 'ForecastedAircraftPart',
#    'category': 'Entity',
#    'data': {'name': 'ForecastedAircraftPart',
#     'categoryMetadataIdentifier': 'ForecastedAircraftPart',
#     'package': 'panda'}},
#   'ReliabilityAssetAlertFeedback': {'id': 'ReliabilityAssetAlertFeedback',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityAssetAlertFeedback',
#     'categoryMetadataIdentifier': 'ReliabilityAssetAlertFeedback',
#     'package': 'reliabilityMl'}},
#   'AbstractStateMachine': {'id': 'AbstractStateMachine',
#    'category': 'Entity',
#    'data': {'name': 'AbstractStateMachine',
#     'categoryMetadataIdentifier': 'AbstractStateMachine',
#     'package': 'stateMachineWorkflow'}},
#   'PhysicalAssetHierarchyDenorm': {'id': 'PhysicalAssetHierarchyDenorm',
#    'category': 'Entity',
#    'data': {'name': 'PhysicalAssetHierarchyDenorm',
#     'categoryMetadataIdentifier': 'PhysicalAssetHierarchyDenorm',
#     'package': 'physicalAsset'}},
#   'ActiveUnreliabilityJob': {'id': 'ActiveUnreliabilityJob',
#    'category': 'Entity',
#    'data': {'name': 'ActiveUnreliabilityJob',
#     'categoryMetadataIdentifier': 'ActiveUnreliabilityJob',
#     'package': 'panda'}},
#   'RollupMetricPersistedResult': {'id': 'RollupMetricPersistedResult',
#    'category': 'Entity',
#    'data': {'name': 'RollupMetricPersistedResult',
#     'categoryMetadataIdentifier': 'RollupMetricPersistedResult',
#     'package': 'rollupMetricBatchJob'}},
#   'CustomerContact': {'id': 'CustomerContact',
#    'category': 'Entity',
#    'data': {'name': 'CustomerContact',
#     'categoryMetadataIdentifier': 'CustomerContact',
#     'package': 'party'}},
#   'DataValidationRule': {'id': 'DataValidationRule',
#    'category': 'Entity',
#    'data': {'name': 'DataValidationRule',
#     'categoryMetadataIdentifier': 'DataValidationRule',
#     'package': 'dataValidation'}},
#   'RefreshAclsBatchJob': {'id': 'RefreshAclsBatchJob',
#    'category': 'Entity',
#    'data': {'name': 'RefreshAclsBatchJob',
#     'categoryMetadataIdentifier': 'RefreshAclsBatchJob',
#     'package': 'platform'}},
#   'PhysicalAsset': {'id': 'PhysicalAsset',
#    'category': 'Entity',
#    'data': {'name': 'PhysicalAsset',
#     'categoryMetadataIdentifier': 'PhysicalAsset',
#     'package': 'physicalAsset'}},
#   'LabeledMaintenanceAction': {'id': 'LabeledMaintenanceAction',
#    'category': 'Entity',
#    'data': {'name': 'LabeledMaintenanceAction',
#     'categoryMetadataIdentifier': 'LabeledMaintenanceAction',
#     'package': 'panda'}},
#   'ThresholdHistory': {'id': 'ThresholdHistory',
#    'category': 'Entity',
#    'data': {'name': 'ThresholdHistory',
#     'categoryMetadataIdentifier': 'ThresholdHistory',
#     'package': 'panda'}},
#   'MlAtomicPipe': {'id': 'MlAtomicPipe',
#    'category': 'Entity',
#    'data': {'name': 'MlAtomicPipe',
#     'categoryMetadataIdentifier': 'MlAtomicPipe',
#     'package': 'platform'}},
#   'ControlValvesModelable': {'id': 'ControlValvesModelable',
#    'category': 'Entity',
#    'data': {'name': 'ControlValvesModelable',
#     'categoryMetadataIdentifier': 'ControlValvesModelable',
#     'package': 'reliabilityMl'}},
#   'App.State': {'id': 'App.State',
#    'category': 'Entity',
#    'data': {'name': 'App.State',
#     'categoryMetadataIdentifier': 'App.State',
#     'package': 'platform'}},
#   'Tas.MatchedIssue': {'id': 'Tas.MatchedIssue',
#    'category': 'Entity',
#    'data': {'name': 'Tas.MatchedIssue',
#     'categoryMetadataIdentifier': 'Tas.MatchedIssue',
#     'package': 'platform'}},
#   'MlModel.Monitor.Job': {'id': 'MlModel.Monitor.Job',
#    'category': 'Entity',
#    'data': {'name': 'MlModel.Monitor.Job',
#     'categoryMetadataIdentifier': 'MlModel.Monitor.Job',
#     'package': 'platform'}},
#   'DynMapReduce': {'id': 'DynMapReduce',
#    'category': 'Entity',
#    'data': {'name': 'DynMapReduce',
#     'categoryMetadataIdentifier': 'DynMapReduce',
#     'package': 'platform'}},
#   'StateMachineState': {'id': 'StateMachineState',
#    'category': 'Entity',
#    'data': {'name': 'StateMachineState',
#     'categoryMetadataIdentifier': 'StateMachineState',
#     'package': 'stateMachineWorkflow'}},
#   'MdmTrdExcRuleJob': {'id': 'MdmTrdExcRuleJob',
#    'category': 'Entity',
#    'data': {'name': 'MdmTrdExcRuleJob',
#     'categoryMetadataIdentifier': 'MdmTrdExcRuleJob',
#     'package': 'panda'}},
#   'MdmDataRuleVersion': {'id': 'MdmDataRuleVersion',
#    'category': 'Entity',
#    'data': {'name': 'MdmDataRuleVersion',
#     'categoryMetadataIdentifier': 'MdmDataRuleVersion',
#     'package': 'panda'}},
#   'Tas.TestSuiteResponse': {'id': 'Tas.TestSuiteResponse',
#    'category': 'Entity',
#    'data': {'name': 'Tas.TestSuiteResponse',
#     'categoryMetadataIdentifier': 'Tas.TestSuiteResponse',
#     'package': 'platform'}},
#   'StagingRemisHowMalfunctionCodeTable': {'id': 'StagingRemisHowMalfunctionCodeTable',
#    'category': 'Entity',
#    'data': {'name': 'StagingRemisHowMalfunctionCodeTable',
#     'categoryMetadataIdentifier': 'StagingRemisHowMalfunctionCodeTable',
#     'package': 'panda'}},
#   'UiBundlerResult': {'id': 'UiBundlerResult',
#    'category': 'Entity',
#    'data': {'name': 'UiBundlerResult',
#     'categoryMetadataIdentifier': 'UiBundlerResult',
#     'package': 'uiBundler'}},
#   'ReliabilityRiskMl.Scaler.Pipe': {'id': 'ReliabilityRiskMl.Scaler.Pipe',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityRiskMl.Scaler.Pipe',
#     'categoryMetadataIdentifier': 'ReliabilityRiskMl.Scaler.Pipe',
#     'package': 'reliabilityMl'}},
#   'ReliabilityMl.Project': {'id': 'ReliabilityMl.Project',
#    'category': 'Entity',
#    'data': {'name': 'ReliabilityMl.Project',
#     'categoryMetadataIdentifier': 'ReliabilityMl.Project',
#     'package': 'reliabilityMl'}},
#   'ClusterCenterSeries': {'id': 'ClusterCenterSeries',
#    'category': 'Entity',
#    'data': {'name': 'ClusterCenterSeries',
#     'categoryMetadataIdentifier': 'ClusterCenterSeries',
#     'package': 'platform'}},
#   'ExMachina_Seq': {'id': 'ExMachina_Seq',
#    'category': 'Entity',
#    'data': {'name': 'ExMachina_Seq',
#     'categoryMetadataIdentifier': 'ExMachina_Seq',
#     'package': 'platform'}},
#   'GanttChartDemoTimeRange': {'id': 'GanttChartDemoTimeRange',
#    'category': 'Entity',
#    'data': {'name': 'GanttChartDemoTimeRange',
#     'categoryMetadataIdentifier': 'GanttChartDemoTimeRange',
#     'package': 'uiGanttChartDemo'}},
#   'StagingRemisStatusTable': {'id': 'StagingRemisStatusTable',
#    'category': 'Entity',
#    'data': {'name': 'StagingRemisStatusTable',
#     'categoryMetadataIdentifier': 'StagingRemisStatusTable',
#     'package': 'panda'}},
#   'UserAccessRequestState': {'id': 'UserAccessRequestState',
#    'category': 'Entity',
#    'data': {'name': 'UserAccessRequestState',
#     'categoryMetadataIdentifier': 'UserAccessRequestState',
#     'package': 'panda'}},
#   'ActionContextExtension': {'id': 'ActionContextExtension',
#    'category': 'Entity',
# ...
#               'PartyRoleRelation': ['PartyRole'],
#               'PeriodicCalcStateHistory': ['PeriodicCalcState',
#                'RefreshCalcFieldsBatchJob'],
#               'StagingRemisOffEquipmentDiscrepancyTable': ['StagingRemisOffEquipmentWorkOrderTable'],
#               'MdmWucCorrectionRule': ['MdmDataset', 'WorkUnitCode'],
#               'UserPreference': ['Member'],
#               'NotificationCategoryPreference': ['NotificationRecipient'],
#               'GanttChartDemoResourceTimeRanges': ['GanttChartDemoResource'],
#               'InventoryItem': ['NationalStockNumber',
#                'InventoryHistory',
#                'SupplyLocation'],
#               'ScheduleHolidayDate': ['ScheduleHoliday'],
#               'DataValidationRuleset': ['DataValidationRule',
#                'DataValidationRulesetHierarchicalRelation'],
#               'MxEffort': ['MaintenanceToPart',
#                'ReliabilityAssetCase',
#                'MaintenanceEvent'],
#               'MlModel.Route': ['MlModel.Router',
#                'MlProject',
#                'MlModel.Route.StatusHistory',
#                'MlModel'],
#               'TrainingVideoFile': ['User'],
#               'MlModel.Monitor.BatchResult': ['MlModel.Monitor.JobRun'],
#               'UiBundlerPerformanceProfile': ['SetupWorkingDirPerformanceProfile',
#                'UiBundler',
#                'WebpackPerformanceProfile'],
#               'MaximGun': ['MaximGunFire'],
#               'PageGroup': ['Application'],
#               'CustomerRelation': ['Organization', 'Supplier', 'Customer'],
#               'StagingRemisOffEquipmentCorrectiveActionTable': ['StagingRemisOffEquipmentMaintenanceActionTable'],
#               'MdmTrdExcRuleJob': ['MdmExcisionRule'],
#               'Workflow.Run': ['Workflow', 'Workflow.Run'],
#               'MlSubject.Group': ['MlSubject.Group'],
#               'Action.Spy.Registry': ['Action.Spy'],
#               'GeoPoliticalRegion': ['GeoPoliticalRegionRelation'],
#               'ModelConfigCachedHyperparams': ['ReliabilityMlModel'],
#               'MlSubject.OperationJob.Result': ['MlModel.Route'],
#               'UiBundler': ['UiBundlerPerformanceProfile', 'BundleStatus'],
#               'InvalidationQueueErrorReview': ['InvalidationQueueErrorReviewComment'],
#               'TestResult': ['CodeCoverageCounter'],
#               'StagingRemisOffEquipmentWorkCenterEventDiscrepancyNarrativeTable': ['StagingRemisOffEquipmentMaintenanceActionTable'],
#               'StagingRemisUtilizationTable': ['StagingRemisInventoryPossessionTable'],
#               'InvalidationQueueReport': ['InvalidationQueueHistory'],
#               'InvalidationQueueError': ['InvalidationQueueErrorReview'],
#               'AircraftModelVariant': ['AircraftModel'],
#               'DataApiEntityType': ['TestApiEntityType', 'Unit'],
#               'GanttChartDemoResourceToCalendar': ['GanttChartDemoResource',
#                'GanttChartDemoCalendar'],
#               'Country': ['Currency'],
#               'PandaRulePredicter': ['ReliabilityCase',
#                'PandaRulePredicterWord'],
#               'ScheduleExceptionDatetimeWindow': ['ScheduleCalendar'],
#               'PurchaseOrder': ['PurchaseOrderLine'],
#               'EngineeringRecommendation': ['ReadinessAssetPositionToFailureModeRelation',
#                'AssetClass',
#                'FailureMode'],
#               'ReliabilityAssetSensorRelation': ['ExpectedSensor'],
#               'DataLake.Table.DownloadRequest': ['DataLake.Table.Managed'],
#               'Hpo.Experiment': ['Hpo.Trial', 'Workflow', 'MlPipe'],
#               'AirBaseToUsafOrganizationMapping': ['AirBase',
#                'UsafOrganization'],
#               'FacilityReliabilityAssetRelation': ['ReliabilityAsset',
#                'Facility'],
#               'RawRemisData': ['TransformedRemisData'],
#               'EventWindow': ['ObservedEvent'],
#               'UiBundlerResult': ['UiBundler'],
#               'ReliabilityAssetToRiskModelValidationRelation': ['ReliabilityRiskScoreMlValidationPredictionHeader',
#                'ReliabilityAssetValidationAlert',
#                'ReliabilityRiskScoreMlValidationContributionHeader'],
#               'WucToReliabilityCaseMapping': ['AircraftModel',
#                'ReliabilityCase',
#                'WorkUnitCode'],
#               'SandboxMdmDatasetToTrdMapping': ['SandboxMdmDataset',
#                'SandboxTransformedRemisData'],
#               'Employee': ['Person', 'Country'],
#               'TestApiObj': ['TestApiContext'],
#               'MlModel.Router': ['MlModel.Route', 'MlProject'],
#               'SupplyLocation': ['AirBase'],
#               'MlModel.Monitor.Result': ['MlModel.Monitor.JobRun',
#                'MlModel',
#                'MlModel.Monitor.Job'],
#               'ReadinessRiskInferenceJob': ['ReadinessAssetPositionToFailureModeRelation',
#                'AssetClass'],
#               'ReliabilityAssetCaseFailureModeRelation': ['ReliabilityAssetCase'],
#               'SupplyTransactionLinkagesJob': ['MonthlyPartsRemovedJob'],
#               'ReliabilityRiskScoreMlValidationPredictionHeader': ['ReliabilityAssetToRiskModelValidationRelation',
#                'Unit'],
#               'InventorySeries': ['Unit', 'WorkOrderPartsForecast'],
#               'MaintenanceEventDescriptionSegment': ['MaintenanceEvent'],
#               'UiSdlMetadataFileManifest': ['UiBundler'],
#               'MapReduceRun': ['ReduceResult'],
#               'Tas.Response': ['Tas.BuildInfo'],
#               'WorkItem': ['WorkOrder'],
#               'MlWorkflowCoordinatableResult': ['MlWorkflowCoordinatable'],
#               'MdmExcisionRule': ['MdmDataset'],
#               'PurchaseOrderPartsForecast': ['InventorySeries'],
#               'GenerateTagSpec': ['Tag'],
#               'LMEChangeHistory': ['AdjudicatedMaintenanceEvent',
#                'LabeledMaintenanceEvent',
#                'PandaUser'],
#               'ReliabilityModelRegistry.TargetEntry': ['ReliabilityMlModel'],
#               'TestStateMachine': ['WorkOrderPerfTest'],
#               'ClusterCenterSeries': ['Unit'],
#               'ReduceResult': ['MapReduceRun'],
#               'PartyPhone': ['Party'],
#               'MdmDatasetToExcisionRuleMapping': ['MdmDataset',
#                'MdmExcisionRule'],
#               'GanttChartDemoCalendar': ['GanttChartDemoCalendarInterval',
#                'GanttChartDemoCalendar'],
#               'ReliabilityAssetToModelValidationRelation': ['ReliabilityMl.ValidationContributionHeader',
#                'ReliabilityMl.ValidationPredictionHeader'],
#               'PersonOrganizationRelation': ['Person', 'Organization'],
#               'NotificationHistory': ['NotificationRecipient'],
#               'PositionToReliabilityCaseMapping': ['Position',
#                'ReliabilityCase'],
#               'ReliabilityMl.ContributionHeader': ['ReliabilityAssetToModelRelation'],
#               'Workflow.Run.Nested': ['Workflow.Run'],
#               'SbaDartDataFile': ['ReadinessOperation'],
#               'StagingRemisOnEquipmentMaintenanceActionTable': ['StagingRemisOnEquipmentWorkOrderTable',
#                'StagingRemisOnEquipmentMaintenanceRemoveAndInstallDataTable'],
#               'TimeBoundAlertMetric': ['FailureMode'],
#               'StagingRemisInventoryTable': ['StagingRemisEndItemTable'],
#               'FailureModePositionToOperation': ['ReadinessAssetPositionToFailureModeRelation',
#                'ReadinessOperation'],
#               'MlModel.Route.OperationJob.Run': ['MlModel.Route.OperationJob'],
#               'Tas.TestSuiteResponse': ['Tas.TestCase'],
#               'FlightHourForecast': ['Majcom'],
#               'ReliabilityModelRegistry.SourceEntry': ['ReliabilityMlModel'],
#               'SplitSpec': ['ReliabilityCase'],
#               'ReliabilityAssetCaseToAssetRelation': ['ReliabilityAsset',
#                'ReliabilityAssetCase'],
#               'TestGraphVisualizationEdge': ['TestGraphVisualizationNode'],
#               'App.Metric': ['App.Metric', 'Unit'],
#               'CommentBoard': ['CommentBoardReply'],
#               'TransformedRemisData': ['TransformedRemisDataToMdmDataRuleRelation',
#                'MdmExcisionRule',
#                'RawRemisData'],
#               'PersonUser': ['Person', 'User'],
#               'FailureModeRelation': ['FailureModeFeedback',
#                'FailureModeLineItem'],
#               'AirBaseModelPair': ['Aircraft', 'AircraftModel', 'AirBase'],
#               'AiAssistant.Feedback.Answer': ['AiAssistant.Feedback.Question'],
#               'ReliabilityTteMlModel': ['ReliabilityAssetToTteModelRelation'],
#               'ExternalNiinDemandForecast': ['DeltaNiinDemandForecast',
#                'CbmNiinDemandForecast'],
#               'MlProject': ['MlModel.Router'],
#               'JupyterDirectory': ['JupyterContent'],
#               'TestApiEntityType': ['DataApiEntityType'],
#               'MlModel.Health.History': ['MlModel.HealthCalc.JobRun',
#                'MlModel.HealthCalc.Result'],
#               'CronJob': ['JobHistory'],
#               'LocationMeasurementDevice': ['Location'],
#               'FixedAssetHierarchyRelation': ['FixedAsset'],
#               'WebpackPerformanceProfile': ['UiBundlerPerformanceProfile'],
#               'MlModel.Monitor.JobRun': ['MlModel.Monitor.Job'],
#               'MdmDataRuleVersion': ['PandaUser', 'MdmDataRule'],
#               'GeoPoliticalRegionRelation': ['GeoPoliticalRegion'],
#               'Translation': ['Locale'],
#               'SetupWorkingDirPerformanceProfile': ['UiBundlerPerformanceProfile'],
#               'ItemFacilityInventoryParams': ['Item', 'Facility'],
#               'ReadinessRiskInferenceLog': ['ReadinessRiskInferenceJob'],
#               'DataConfiguration': ['PandaUser'],
#               'SourceFile': ['SourceStatus'],
#               'PhysicalAssetRealTimeLocation': ['PhysicalAsset'],
#               'PurchaseOrderLineReceipt': ['PurchaseOrderLine'],
#               'ReliabilityMl.Project': ['MlProject'],
#               'ReliabilityAssetTteAlert': ['ReliabilityTteMlModel'],
#               'MonthlyPartsRemoved': ['SupplyTransaction'],
#               'TestActionMock': ['Action.Spy'],
#               'SensorValueMapping': ['ExpectedSensor'],
#               'InvalidationQueueErrorReviewComment': ['InvalidationQueueErrorReview'],
#               'ReliabilityAssetToModelRelation': ['ReliabilityMl.PredictionHeader',
#                'ReliabilityMlModel',
#                'ReliabilityMl.ContributionHeader'],
#               'Hpo.Run': ['MlOperationRun', 'MlPipe'],
#               'ReliabilityTteForecastContributionHeader': ['ReliabilityAssetToTteModelRelation'],
#               'ProtectionLoopSensorRelation': ['Sensor', 'ProtectionLoop'],
#               'GovUser': ['User'],
#               'InventoryItem218': ['InventoryItem',
#                'NationalStockNumber',
#                'SupplyLocation'],
#               'PandaFeedback': ['User'],
#               'ProtectionLoop': ['ProtectionLoopSensorRelation',
#                'ProtectionLoopAlert'],
#               'TestOrganization': ['TestOrganizationDenorm',
#                'TestOrganization'],
#               'Rate': ['Exchange', 'Currency'],
#               'BusinessRegion': ['BusinessRegionRelation'],
#               'UserGroup': ['User'],
#               'MlModel.HealthCalc.JobRun': ['MlModel.HealthCalc.Job'],
#               'PartyCommunicationPreference': ['Party'],
#               'User': ['UserGroup'],
#               'PandaRulePredicterWord': ['PandaRulePredicter'],
#               'ProtectionLoopAlert': ['ProtectionLoop', 'Sensor'],
#               'ReliabilitySyntheticData.ReliabilityRisk.AssetHierarchySpreadsheet': ['ReliabilitySyntheticData.ReliabilityRisk.DataGenerationJob'],
#               'GanttChartDemoCalendarInterval': ['GanttChartDemoCalendar'],
#               'AdditionalRelationalDataSpec': ['AdditionalExportSpec'],
#               'ReliabilityAssetClassDefinitionParserJob': ['ReliabilityAssetClassDefinitionParserJobBatchResult'],
#               'EtlLog': ['EtlCoordinator'],
#               'UserRecommendationStatusHistory': ['UserRecommendation',
#                'User'],
#               'FailureModeLibrary': ['FailureMode'],
#               'FailureRecommendationRelation': ['FailureRecommendationFeedback',
#                'FailureModeRecommendation'],
#               'DataLake.Table.ShareRequest': ['DataLake.Table.Managed',
#                'UserGroup'],
#               'CustomerContact': ['Contact', 'Customer'],
#               'ReadinessIngestEvent': ['ReadinessDataIngest'],
#               'SensorBounds': ['ExpectedSensor'],
#               'ReliabilityTteContributionHeader': ['ReliabilityAssetToTteModelRelation'],
#               'ReliabilityTtePredictionHeader': ['ReliabilityAssetToTteModelRelation'],
#               'SourceStatus': ['SourceChunkStatus'],
#               'BusinessRegionRelation': ['BusinessRegion'],
#               'PhysicalAssetLocationHistory': ['Location'],
#               'MlModel.Evaluation.Run': ['MlModel.Evaluator'],
#               'CommentBoardReply': ['CommentBoard',
#                'CommentBoardReply',
#                'PandaUser'],
#               'Workflow.Run.Vertex': ['Workflow.Run'],
#               'AssetOnboardingSourceFile': ['AssetOnboardingSourceFile'],
#               'MapResult': ['MapReduceRun'],
#               'ReliabilityRiskMlModel': ['ReliabilityMlDatasetPreparationRun',
#                'ModelTemplate',
#                'ReliabilityAssetToRiskModelRelation'],
#               'TestSmartBulb': ['TestSmartBulbToApartmentRelation'],
#               'WorkOrderPerfTest': ['TestStateMachine'],
#               'FacilityHierarchicalRelation': ['Facility'],
#               'DataLake.Table.MetaFieldValue': ['DataLake.Table.Managed'],
#               'AiAssistant.Feedback.Question': ['AiAssistant.Feedback.Answer'],
#               'Tas.CloseAutomationState': ['JobHistory'],
#               'ReliabilityMl.PredictionHeader': ['Unit',
#                'ReliabilityAssetToModelRelation'],
#               'TSStats': ['TSStatsJob'],
#               'ReliabilityRiskScoreMlScoreHeader': ['ReliabilityAssetToRiskModelRelation'],
#               'JobStatusReport': ['JobStatusTracker'],
#               'WucToMdmWucCorrectionRulesMapping': ['MdmWucCorrectionRule'],
#               'StagingRemisInventoryPossessionTable': ['StagingRemisEndItemTable'],
#               'Hpo.Trial': ['Hpo.Run'],
#               'SensorEventType': ['AircraftSensorEventValueHistory'],
#               'Idp': ['IdpCertificate'],
#               'SandboxMdmDatasetToExcisionRuleMapping': ['SandboxMdmDataset',
#                'MdmExcisionRule'],
#               'SensorDataSummary': ['Sensor'],
#               'Workflow.Run.Batch': ['BatchJobRun'],
#               'TrainingHandbookFile': ['User'],
#               'MlModel.Monitor.TimedResultHeader': ['MlModel'],
#               'Position': ['PositionToReliabilityCaseMapping'],
#               'GitHubToken': ['User'],
#               'Supplier': ['Organization'],
#               'RegionRelation': ['Region'],
#               'Tas.TrackingResponse': ['Tas.MatchedIssue'],
#               'ReliabilityAssetToReadinessRiskModelRelation': ['ReadinessRiskMlModel'],
#               'MaintenanceActionDescriptionSegment': ['MaintenanceAction'],
#               'CreateLabeledMaintenanceJob': ['ReliabilityCase'],
#               'SensorMeasurementBounds': ['Sensor'],
#               'AssetPartyRole': ['PhysicalAsset', 'PartyRole'],
#               'WorkOrderPartsForecast': ['InventorySeries'],
#               'StagingRemisOnEquipmentWorkCenterEventDiscrepancyNarrativeTable': ['StagingRemisOnEquipmentMaintenanceActionTable'],
#               'DataValidationSubject': ['DataValidationRun'],
#               'BasePhysicalMeasurementSeries': ['Unit',
#                'BasePhysicalMeasurementSeries'],
#               'MetricProfileSpec': ['MetricProfilerSpec'],
#               'X12Loop': ['X12Loop'],
#               'MdmGetTrdsAndExcRulesJob': ['MdmDataset'],
#               'AnalysisWorkflowStateHistory': ['PandaUser'],
#               'AircraftAssetMaintenanceRecommendationAlert': ['UserAircraftAssetMaintenanceRecommendationRelation'],
#               'DeltaSegmentDemandForecast': ['AircraftModel']}))

# %%
node_map, adj_list = build_adjacency_list(graph_data)

# %%
adj_list
# Out:
# defaultdict(list,
#             {'AircraftAssetMaintenanceRecommendation': ['PandaUser',
#               'ForecastedAircraftPart',
#               'AircraftModel',
#               'Aircraft',
#               'NationalStockNumber',
#               'ReliabilityCase',
#               'UserAircraftAssetMaintenanceRecommendationRelation'],
#              'StagingRemisOffEquipmentWorkOrderTable': ['StagingRemisOnEquipmentWorkOrderTable',
#               'StagingRemisEndItemTable'],
#              'AdjudicatedMaintenanceAction': ['PandaMlMetadata',
#               'ReliabilityCase',
#               'Position',
#               'AdjudicatedMaintenanceEvent',
#               'PandaInferenceJob',
#               'MaintenanceAction',
#               'ActionTakenCode',
#               'MaintenanceEvent'],
#              'EnvReport': ['EnvLog'],
#              'ExpectedSensor': ['SensorBounds',
#               'ReliabilityAssetSensorRelation',
#               'FailureModeLineItem',
#               'Unit',
#               'SensorValueMapping',
#               'FailureModeLibrary',
#               'PointPhysicalMeasurementSeries'],
#              'PandaDataPipelineTracker': ['PandaDataPipelineStatusHistory',
#               'PandaDataPipelineToAdvanaDataMapping'],
#              'ReliabilityMlModelExperiment': ['Workflow.Run',
#               'ReliabilityMlModel'],
#              'CaseToPartQuantityRelation': ['ReliabilityAssetCase',
#               'NationalStockNumber',
#               'FailureMode'],
#              'ScheduleHoliday': ['ScheduleHolidayDate',
#               'Region',
#               'ScheduleHolidaySchedule'],
#              'Aircraft': ['UsafOrganization',
#               'Flight',
#               'AirBaseModelPair',
#               'AircraftAsset',
#               'AircraftModel',
#               'AirBase',
#               'AircraftModelVariant',
#               'ReliabilityAsset',
#               'ForecastedAircraftPart',
#               'PandaGroup',
#               'AircraftAssignment',
#               'AircraftStatus',
#               'MaintenanceEvent',
#               'ReadinessOperation'],
#              'FixedAsset': ['FixedAsset',
#               'AssetOwner',
#               'Region',
#               'PartyRole',
#               'Organization',
#               'AssetPartyRole',
#               'AssetHierarchyDenorm',
#               'Location'],
#              'MlModel': ['MlPipeline',
#               'Feature.Set.Snapshot',
#               'MlModel.Health.History',
#               'Feature.Set',
#               'MlModel.Monitor.TimedResult',
#               'MlModel.Evaluation.Result'],
#              'StagingRemisOnEquipmentDiscrepancyTable': ['StagingRemisOnEquipmentWorkOrderTable'],
#              'StagingRemisStatusTable': ['StagingRemisInventoryPossessionTable'],
#              'DisclosureReviewRequest': ['User'],
#              'ReliabilityAssetClassDefinitionParserJobBatchResult': ['ReliabilityAssetClassDefinitionParserJob',
#               'AssetClass'],
#              'SbaOperationData': ['ReadinessOperation',
#               'ReliabilityAsset',
#               'SbaOperationDataStatusHistory',
#               'SbaDataFile',
#               'AssetClass',
#               'SbaDartDataFile'],
#              'ReliabilityAssetCaseUpdateHistory': ['CaseState',
#               'MxEffort',
#               'WorkOrder',
#               'ReliabilityAssetCase',
#               'ReadinessAssetAlert'],
#              'ReliabilityAssetSensorHierarchicalRelation': ['ReliabilityAsset',
#               'Sensor'],
#              'AircraftStatus': ['WorkUnitCode',
#               'AircraftStatusCode',
#               'AircraftAsset',
#               'Location'],
#              'Person': ['PersonUser',
#               'Member',
#               'Country',
#               'PersonOrganizationRelation',
#               'Contact'],
#              'ReliabilityAssetToTteModelRelation': ['ReliabilityTteForecastContributionHeader',
#               'ReliabilityTtePredictionHeader',
#               'ReliabilityTteContributionHeader',
#               'ReliabilityTteMlModel',
#               'ReliabilityTteForecastPredictionHeader'],
#              'MaintenanceAction': ['HowMalfunctionCode',
#               'LabeledMaintenanceAction',
#               'MaintenanceAction',
#               'Aircraft',
#               'UsafOrganization',
#               'MaintenanceTypeCode',
#               'Majcom',
#               'ActionTakenCode',
#               'WorkUnitCode',
#               'MaintenanceEvent',
#               'MaintenanceActionDescriptionSegment',
#               'AircraftAsset',
#               'MaintenanceActionGroup',
#               'WhenDiscoveredCode'],
#              'MlModel.HealthCalc.Result': ['MlModel'],
#              'TestDepartment': ['TestDepartment', 'TestDepartmentDenorm'],
#              'ReliabilityAssetCase': ['ReliabilityAsset',
#               'ReadinessAssetAlertToCaseRelation',
#               'ReadinessAssetAlert',
#               'ReliabilityAssetAlertToCaseRelation',
#               'CaseAssigneeHistory',
#               'CaseComment',
#               'MxEffort',
#               'WorkOrder',
#               'ReliabilityAssetCaseToAssetRelation',
#               'ReadinessAssetPositionToFailureModeRelation',
#               'ReliabilityAssetAlert',
#               'CaseToPartQuantityRelation',
#               'CasePriorityHistory',
#               'AssetClass',
#               'ReliabilityAssetCaseUpdateHistory',
#               'ReliabilityAssetCaseFailureModeRelation',
#               'Facility'],
#              'MdmDatasetToTrdMapping': ['MdmDataset', 'TransformedRemisData'],
#              'NationalItemIdentificationNumber': ['DeltaNiinDemandForecast',
#               'ReliabilityCaseSegment',
#               'NationalStockNumber',
#               'CbmNiinDemandForecast',
#               'ExternalNiinDemandForecast',
#               'AircraftModel',
#               'WorkUnitCode'],
#              'LabeledMaintenanceEvent': ['ReliabilityCase',
#               'Position',
#               'MaintenanceEvent',
#               'SupplyTransaction'],
#              'ReadinessAssetPositionToFailureModeRelation': ['FailureMode',
#               'FailureModePositionToOperation',
#               'EngineeringRecommendation',
#               'ReadinessDatasetPreparationRun',
#               'ReliabilityAssetCase',
#               'Feature.Set',
#               'NationalStockNumber',
#               'ReadinessOperation',
#               'AssetClass',
#               'ReadinessAssetAlert',
#               'MxEffort',
#               'PositionFailureModeToNSNRelation',
#               'MlProject'],
#              'PandaDataPipelineToAdvanaDataMapping': ['PandaDataPipelineTracker',
#               'AdvanaDataTracker'],
#              'NsnToWucMapping': ['ReliabilityCaseSegment',
#               'Position',
#               'NationalStockNumber',
#               'WorkUnitCode',
#               'NsnToWucMapping',
#               'ReliabilityCase'],
#              'ReliabilityCase': ['SplitSpec',
#               'PositionToReliabilityCaseMapping',
#               'WorkUnitCode',
#               'AircraftModel',
#               'AircraftAsset',
#               'ForecastedAircraftPart',
#               'PandaMlMetadata',
#               'ReliabilityCaseSegment',
#               'LabeledMaintenanceAction',
#               'WucToReliabilityCaseMapping',
#               'Position',
#               'NationalStockNumber',
#               'PandaUser',
#               'LabeledMaintenanceEvent',
#               'AircraftAssetMaintenanceRecommendation'],
#              'PandaMlMetadata': ['ReliabilityCase',
#               'PandaInferenceJob',
#               'SplitSpec',
#               'Workflow',
#               'PandaRulePredicter'],
#              'Party': ['PartyPhone',
#               'PartyElectronicCommunication',
#               'Customer',
#               'PartyRole',
#               'ScheduleRecurringDayRule',
#               'PartyCommunicationPreference',
#               'Party',
#               'Locale',
#               'PartyTimedIntervalRelation',
#               'PartyPostalAddress',
#               'PartyEdge'],
#              'AircraftModel': ['PandaGroup',
#               'FlightHourForecast',
#               'Aircraft',
#               'Majcom',
#               'AircraftModel',
#               'AssetClass',
#               'MonthlyPartsRemoved',
#               'ReliabilityCase',
#               'PandaUser',
#               'AircraftModelVariant',
#               'WorkUnitCode',
#               'UserAccessRequest'],
#              'ReliabilityRiskScoreMlPredictionHeader': ['MlModel',
#               'ReliabilityAssetToRiskModelRelation',
#               'ReadinessOperation',
#               'ReliabilityAsset',
#               'Unit'],
#              'MlModel.Train.JobResult': ['MlOperationRun',
#               'MlModel.Train.Job',
#               'MlModel.Train.JobRun'],
#              'Region': ['GeoPoliticalRegionRelation',
#               'GeographicalEntity',
#               'RegionRelation',
#               'RegionHierarchyDenorm',
#               'Region',
#               'BusinessRegionRelation'],
#              'MlModel.Monitor.GroupRun': ['MlModel.Monitor.GroupResult'],
#              'MlModel.Route.OperationJob.Result': ['MlModel.Route'],
#              'AdvanaDataTracker': ['PandaDataPipelineToAdvanaDataMapping',
#               'AdvanaDataIngestStatusHistory'],
#              'ReliabilityAssetRiskAlert': ['ReliabilityRiskMlModel'],
#              'ReliabilitySparePartsSimilarityJobHelper': ['WorkOrder'],
#              'Majcom': ['ReliabilityAsset',
#               'UsafOrganization',
#               'FlightHourForecast'],
#              'MaximGunUser': ['MaximGunFire'],
#              'NormalizedTimeseries': ['NormalizedTimeseriesState'],
#              'ReliabilityMlDatasetPreparationJob': ['ReliabilityMlDatasetPreparationRun'],
#              'ReliabilityAssetAlertBase': ['ReliabilityAsset',
#               'ReliabilityMlModel'],
#              'UserAccessRequest': ['PandaUser',
#               'PandaGroup',
#               'UsafOrganization',
#               'User',
#               'AirBase',
#               'PandaRole',
#               'AircraftModel',
#               'Majcom'],
#              'FailureModeLineItem': ['FailureModePriority',
#               'FailureModeDiagnostic',
#               'FailureModeLibrary',
#               'FailureModeRecommendation',
#               'ExpectedSensor',
#               'FailureMode'],
#              'SupplyTransactionEditedMetadata': ['WorkUnitCode',
#               'AirBase',
#               'UsafOrganization',
#               'AircraftModel',
#               'SupplyTransaction'],
#              'PandaInferenceJob': ['AdjudicatedMaintenanceEvent',
#               'PandaMlMetadata',
#               'AdjudicatedMaintenanceAction'],
#              'ReliabilityCaseSegment': ['ForecastedAircraftPart',
#               'AircraftModelVariant',
#               'Position',
#               'NationalItemIdentificationNumber',
#               'ThresholdHistory',
#               'NsnToWucMapping',
#               'DeltaSegmentDemandForecast',
#               'AircraftModel',
#               'ReliabilityCase'],
#              'WorkOrder': ['WorkUnitCode',
#               'ReliabilityAssetCase',
#               'WorkOrderPartsSimilarityPredictions',
#               'Customer',
#               'Organization',
#               'Facility',
#               'WorkOrder',
#               'FixedAsset',
#               'WorkOrderSimilarityPredictions',
#               'Person',
#               'User',
#               'ReliabilityAsset',
#               'WorkItem',
#               'Item',
#               'Location'],
#              'NationalStockNumber': ['PositionFailureModeToNSNRelation',
#               'EditedNationalStockNumber',
#               'WorkUnitCode',
#               'CaseToPartQuantityRelation',
#               'SupplyTransaction',
#               'InventoryItem218',
#               'NationalItemIdentificationNumber',
#               'FailureMode',
#               'InventoryItemKits',
#               'MaintenanceToPart',
#               'ReliabilityAssetCase',
#               'InventoryItem',
#               'NsnToWucMapping',
#               'MxEffort',
#               'AssetClass',
#               'ReliabilityCase'],
#              'MaintenanceActionGroupDescriptionSegment': ['MaintenanceActionGroup'],
#              'Workflow': ['Workflow.Run'],
#              'WorkOrderSimilarityPredictions': ['WorkOrder',
#               'InventorySeries'],
#              'OrganizationRollup': ['Department', 'Organization'],
#              'Sensor': ['PointPhysicalMeasurementSeries',
#               'BasePhysicalMeasurementSeries',
#               'PhysicalAssetEvent',
#               'ReliabilityAssetSensorRelation',
#               'ReliabilityAssetSensorHierarchicalRelation',
#               'SensorDataSummary',
#               'Unit',
#               'SensorMeasurementBounds',
#               'ReliabilityAsset',
#               'PhysicalMeasurementSeries'],
#              'ReliabilityAssetHierarchicalRelation': ['ReliabilityAsset'],
#              'SupplyTransaction': ['UsafOrganization',
#               'SupplyTransactionEditedMetadata',
#               'MaintenanceEvent',
#               'SupplyLocation',
#               'NationalStockNumber',
#               'Aircraft',
#               'Majcom',
#               'MaintenanceAction',
#               'NsnToWucMapping',
#               'WorkUnitCode',
#               'AirBase',
#               'ReliabilityCase',
#               'AircraftModel'],
#              'PhysicalAssetEventResponse': ['PhysicalAssetEvent'],
#              'MaintenanceEvent': ['MaintenanceEventDescriptionSegment',
#               'SupplyTransaction',
#               'LabeledMaintenanceEvent',
#               'MxEffort',
#               'MaintenanceActionGroup',
#               'AdjudicatedMaintenanceEvent',
#               'MaintenanceSeverityCode',
#               'AirBase',
#               'MaintenanceAction'],
#              'DeltaNiinDemandForecast': ['DeltaSegmentDemandForecast',
#               'DeltaNiinDemandForecast',
#               'CbmNiinDemandForecast',
#               'ExternalNiinDemandForecast'],
#              'PositionFailureModeToNSNRelation': ['MxEffort',
#               'NationalStockNumber',
#               'ReadinessAssetPositionToFailureModeRelation',
#               'WorkUnitCode'],
#              'FailureMode': ['FailureModeLibrary',
#               'FailureModeLineItem',
#               'ExpectedSensor',
#               'ReadinessAssetPositionToFailureModeRelation',
#               'ReadinessAssetAlert'],
#              'SbaDataFile': ['PandaUser', 'SbaOperationData'],
#              'MlModel.OperationRun': ['MlModel', 'MlOperationRun'],
#              'AdjudicatedMaintenanceEvent': ['PandaInferenceJob',
#               'ClassifierScore',
#               'AdjudicatedMaintenanceAction',
#               'Aircraft',
#               'MaintenanceEvent',
#               'Position',
#               'LabeledMaintenanceEvent'],
#              'AssetDocument': ['ReliabilityAsset'],
#              'Feature.Set.ExportSnapshotJob': ['Feature.Set.Snapshot'],
#              'ReliabilityMlDatasetPreparationRun': ['ReliabilityMl.Project',
#               'Sensor',
#               'User',
#               'ReliabilityMlDatasetPreparationJob'],
#              'Feature.Set.Snapshot': ['Feature.Set.Snapshot.Subject',
#               'MlModel',
#               'Feature.Set'],
#              'TargetExampleTDH': ['Unit'],
#              'Facility': ['Facility',
#               'FacilityCharacteristicSet',
#               'FacilityHierarchicalRelation'],
#              'PointPhysicalMeasurementSeries': ['ExpectedSensor',
#               'ReadinessOperation'],
#              'MlModel.Evaluation.JobRun': ['MlModel.Train.JobRun',
#               'MlModel.Evaluation.Job'],
#              'MlModel.Train.JobRun': ['MlOperationRun',
#               'MlModel.Train.Job',
#               'MlModel.Train.JobResult'],
#              'FailureModeRecommendation': ['FailureModeLineItem'],
#              'AssetClass': ['AircraftModel',
#               'FailureMode',
#               'ReliabilityAssetCase',
#               'FailureModeLibrary',
#               'ReliabilityAsset',
#               'AssetClassParentChildRelation',
#               'PandaGroup',
#               'AssetHierarchyTemplate',
#               'ExpectedSensor'],
#              'SourceTarget': ['SourceTargetTwo'],
#              'ForecastedAircraftPart': ['BaseAdjudicatedMaintenanceEvent',
#               'AircraftAssetMaintenanceRecommendation',
#               'Position',
#               'Aircraft',
#               'ReliabilityCaseSegment',
#               'ReliabilityCase'],
#              'AirBase': ['UserAccessRequest',
#               'AircraftModel',
#               'PandaUser',
#               'SupplyLocation',
#               'PandaGroup',
#               'AircraftAssignment',
#               'UsafOrganization',
#               'AirBaseToUsafOrganizationMapping'],
#              'MaximGunFire': ['MaximGun', 'MaximGunUser'],
#              'Contact': ['Person'],
#              'MeasurementSeries': ['PhysicalAsset'],
#              'ReliabilityAssetValidationAlert': ['ReliabilityAssetToRiskModelValidationRelation'],
#              'ReliabilityMl.ValidationContributionHeader': ['ReliabilityAssetToModelValidationRelation'],
#              'LambdaPandaRulePredicter': ['StoredLambda'],
#              'PandaUser': ['User.Event.Login',
#               'PandaGroup',
#               'ReliabilityCase',
#               'UserAccessRequest',
#               'UserAircraftAssetMaintenanceRecommendationRelation',
#               'PandaUser',
#               'Majcom',
#               'User',
#               'AirBase',
#               'PandaUserStatusHistory',
#               'UsafOrganization',
#               'PandaRole',
#               'AircraftModel'],
#              'ReliabilityMlModel': ['MlModel.Train.Result',
#               'ReliabilityAssetToModelValidationRelation',
#               'ReliabilityMlModel.ClassificationScore',
#               'ReliabilityMlDatasetPreparationRun',
#               'ReliabilityMl.Project',
#               'ReliabilityMl.ModelReport',
#               'ReliabilityMlModel',
#               'ReliabilityAssetToModelRelation',
#               'ReliabilityMlModel.MonitoringScore',
#               'ReliabilityModelRegistry.SourceEntry',
#               'ReliabilityMlModelExperiment',
#               'ModelTemplate'],
#              'WorkUnitCode': ['NsnToWucMapping',
#               'AircraftModel',
#               'AircraftAsset',
#               'ReliabilityCase',
#               'NationalItemIdentificationNumber',
#               'WucToReliabilityCaseMapping',
#               'NationalStockNumber',
#               'MaintenanceAction'],
#              'ScheduleCalendar': ['PartyRole',
#               'ScheduleRecurringDayRule',
#               'ScheduleExceptionDatetimeWindow',
#               'ScheduleHolidaySchedule'],
#              'PurchaseOrderLine': ['InventorySeries',
#               'PurchaseOrder',
#               'PurchaseOrderLineReceipt'],
#              'Department': ['Organization', 'DepartmentLevel'],
#              'ReliabilityAsset': ['ReliabilityAssetSensorRelation',
#               'WorkOrder',
#               'ReliabilityAssetCharacteristicValue',
#               'ReliabilityAssetHierarchyDenorm',
#               'ReliabilityAssetToRiskModelRelation',
#               'Majcom',
#               'AssetDocument',
#               'ReliabilityAssetCase',
#               'ReliabilityAssetToModelRelation',
#               'Member',
#               'ReliabilityAssetHierarchicalRelation',
#               'ReliabilityAssetAlert',
#               'Aircraft',
#               'FacilityReliabilityAssetHierarchicalRelation',
#               'ReadinessAssetAlert',
#               'Facility',
#               'ReliabilityAssetSensorHierarchicalRelation',
#               'ReliabilityAssetToReadinessOperationRelation',
#               'ReliabilityAsset',
#               'ReliabilityAssetToReadinessRiskModelRelation',
#               'ReliabilityAssetEvent',
#               'ReliabilityAssetToRiskModelValidationRelation',
#               'AssetClass'],
#              'ReliabilityAssetToRiskModelRelation': ['RiskMlModelPredictionHistory',
#               'ReliabilityRiskScoreMlScoreHeader',
#               'ReliabilityRiskMlModel',
#               'ReliabilityRiskScoreMlPredictionHeader',
#               'ReliabilityRiskScoreMlContributionHeader'],
#              'Feature.Store.Block': ['FeatureEvaluatable.Bin.Strategy'],
#              'PandaGroup': ['UserGroup',
#               'AircraftModel',
#               'UserAccessRequest',
#               'AirBase',
#               'PandaUser'],
#              'AircraftAsset': ['WorkUnitCode',
#               'AircraftModel',
#               'Aircraft',
#               'MaintenanceAction'],
#              'ReadinessAssetAlert': ['ReadinessAssetPositionToFailureModeRelation',
#               'FailureMode',
#               'ReliabilityAssetAlertFeedback',
#               'User',
#               'ReadinessAssetAlertToCaseRelation',
#               'ReadinessAlertAssigneeHistory',
#               'ReadinessOperation',
#               'ReliabilityAssetCase',
#               'ReadinessAssetAlert'],
#              'JobHistory': ['CronJob'],
#              'UserFieldPreference': ['Member', 'PersonUser'],
#              'JobStatusTracker': ['JobStatusReport'],
#              'MlModel.Monitor.ModelToMetricMapping': ['MlModel'],
#              'MlModel.Monitor.TimedResult': ['MlModel.Monitor.BatchResult',
#               'MlModel.Monitor.JobRun'],
#              'UserEmailPreference': ['Facility',
#               'ReliabilityAsset',
#               'AssetClass',
#               'User'],
#              'AircraftOperationSensorEventSeries': ['SensorEventType',
#               'ReadinessOperation'],
#              'ClusterBoundSeries': ['Unit'],
#              'TargetExampleTwo': ['TargetExampleOne'],
#              'RollupMetricBatchJobTestDataPoint': ['RollupMetricBatchJobTestDataSourceEntity'],
#              'NotificationRecipient': ['NotificationCategoryPreference',
#               'NotificationHistory'],
#              'WorkOrderPartsDenormalized': ['WorkOrder', 'InventorySeries'],
#              'TestScenario': ['TestMetricData'],
#              'SandboxSampleFile': ['SourceFile', 'AircraftModel', 'PandaUser'],
#              'LabeledMaintenanceAction': ['Position',
#               'MaintenanceAction',
#               'ReliabilityCase'],
#              'MasterSensor': ['Unit', 'Facility', 'Sensor'],
#              'EditedNationalStockNumber': ['PandaUser', 'NationalStockNumber'],
#              'PartyPostalAddress': ['Party'],
#              'MlSubject.OperationJob.Run': ['MlSubject.OperationJob'],
#              'EtlCoordinator': ['EtlLog', 'Workflow'],
#              'ReliabilityAssetEvent': ['ReliabilityAsset',
#               'ReliabilityAssetAlert',
#               'Facility',
#               'User',
#               'MlProject'],
#              'ReliabilityAssetCaseFailureRecommendationRelation': ['ReliabilityAssetCase'],
#              'AircraftAssignment': ['Aircraft', 'UsafOrganization', 'AirBase'],
#              'PartyRole': ['Party',
#               'OrganizationHierarchyDenorm',
#               'ScheduleCalendar',
#               'PartyRoleRelation',
#               'PartyRole'],
#              'FacilityReliabilityAssetHierarchicalRelation': ['ReliabilityAsset',
#               'Facility'],
#              'CodeCoverageCounter': ['TestResult'],
#              'TestApartment': ['TestSmartBulbToApartmentRelation'],
#              'TestDataValidation': ['TestDataValidation'],
#              'UsafOrganization': ['AircraftModel',
#               'PandaUser',
#               'AirBaseToUsafOrganizationMapping',
#               'Aircraft',
#               'UserAccessRequest',
#               'Majcom',
#               'AirBase'],
#              'MapInValue': ['MapReduceRun'],
#              'PeriodicCalcState': ['PeriodicCalcStateHistory'],
#              'SandboxRawRemisData': ['SandboxTransformedRemisData',
#               'SandboxSampleFile'],
#              'SandboxMdmDataset': ['SandboxSampleFile',
#               'MdmExcisionRule',
#               'SandboxMdmDatasetToExcisionRuleMapping',
#               'SandboxTransformedRemisData',
#               'SandboxMdmDatasetToTrdMapping',
#               'MdmWucCorrectionRule'],
#              'RollupMetricBatchJob': ['RollupMetricBatchJobBatchResult',
#               'RollupMetricBatchJobResult'],
#              'DataValidationRun': ['DataValidationPersistedResult',
#               'DataValidationSubject',
#               'DataValidationPersistedRulesetResult',
#               'DataValidationRuleset'],
#              'TransformedRemisDataToMdmDataRuleRelation': ['TransformedRemisData',
#               'MdmDataRule'],
#              'MlModel.Monitor.BatchGroupRun': ['MlModel.Monitor.GroupResult'],
#              'DataValidationBatchJob': ['DataValidationRule',
#               'DataValidationRun'],
#              'ReadinessOperation': ['ReliabilityAsset',
#               'PointPhysicalMeasurementSeries',
#               'ReadinessAssetAlert',
#               'ReliabilityRiskScoreMlPredictionHeader',
#               'AircraftOperationSensorEventSeries',
#               'SbaOperationData',
#               'FailureModePositionToOperation'],
#              'ReliabilityRiskScoreMlValidationContributionHeader': ['ReliabilityAssetToRiskModelValidationRelation'],
#              'JupyterNotebook': ['JupyterContent', 'ResourceProfile'],
#              'SimpleSynchronousPyRun': ['SimpleSynchronousPyRun'],
#              'CaseStateHistory': ['CaseComment'],
#              'MdmDataset': ['TransformedRemisData',
#               'MdmDatasetToTrdMapping',
#               'MdmDatasetToExcisionRuleMapping'],
#              'CbmNiinDemandForecast': ['ExternalNiinDemandForecast',
#               'DeltaNiinDemandForecast'],
#              'UserAircraftAssetMaintenanceRecommendationRelation': ['PandaUser',
#               'AircraftAssetMaintenanceRecommendation'],
#              'AdoptionReport': ['Majcom', 'AssetClass', 'Facility'],
#              'MaintenanceDataSourceSpec': ['SplitSpec',
#               'PandaMlMetadata',
#               'ReliabilityCase'],
#              'ReliabilityAssetAlertFeedback': ['ReliabilityAssetAlert'],
#              'OAuthAccess': ['OAuthApplication', 'User'],
#              'GanttChartDemoResource': ['GanttChartDemoResource',
#               'GanttChartDemoResourceToCalendar',
#               'GanttChartDemoEvent',
#               'GanttChartDemoCalendar',
#               'GanttChartDemoResourceTimeRanges'],
#              'ScheduleRecurringDayRule': ['ScheduleCalendar'],
#              'StagingRemisOffEquipmentMaintenanceActionTable': ['StagingRemisOffEquipmentWorkOrderTable'],
#              'Organization': ['OrganizationHierarchyDenorm',
#               'OrganizationSegment',
#               'OrganizationRollup',
#               'PersonOrganizationRelation',
#               'Organization',
#               'OrganizationCharacteristicSet',
#               'CustomerRelation',
#               'Country'],
#              'PhysicalAssetEvent': ['PhysicalAssetEventResponse',
#               'PhysicalAsset'],
#              'ReliabilityAssetAlertToCaseRelation': ['ReliabilityAssetCase',
#               'ReliabilityAssetAlert'],
#              'MlModel.Evaluation.Result': ['MlModel.Evaluator', 'MlModel'],
#              'ReliabilityMlModel.ClassificationScore': ['ReliabilityMl.Project',
#               'ReliabilityMlModel',
#               'User',
#               'ReliabilityAsset'],
#              'PartyElectronicCommunication': ['Party'],
#              'MlModel.Train.Result': ['MlModel.Train.JobResult',
#               'MlModel.Train.Job',
#               'MlOperationRun',
#               'MlModel',
#               'MlModel.Train.JobRun'],
#              'TypeMetaDocGetterSampleType': ['ReliabilityAsset'],
#              'Hpo.RunCoordinator': ['Hpo.Trial'],
#              'FakeTypeOne': ['FakeTypeTwo'],
#              'ScheduleHolidaySchedule': ['ScheduleCalendar',
#               'ScheduleHoliday'],
#              'DataValidationMapReduceJob': ['DataValidationRule',
#               'DataValidationRun'],
#              'GanttChartDemoEvent': ['GanttChartDemoEventDependency',
#               'GanttChartDemoEventGroup',
#               'GanttChartDemoResource'],
#              'DataIntegStatus': ['SourceStatus',
#               'TransformStatus',
#               'DataIntegStatus',
#               'TargetStatus'],
#              'UserRecommendation': ['UserRecommendationDismissedHistory',
#               'UserRecommendationCategory'],
#              'AircraftTelemetryHistory': ['Flight', 'Aircraft'],
#              'AdditionalExportSpec': ['AdditionalRelationalDataSpec'],
#              'Flight': ['Location'],
#              'MdmDataRule': ['TransformedRemisDataToMdmDataRuleRelation',
#               'SandboxTransformedRemisDataToMdmDataRuleRelation',
#               'AircraftModel',
#               'MdmDataRuleVersion'],
#              'BaseAdjudicatedMaintenanceEvent': ['ReliabilityCase',
#               'PandaMlMetadata',
#               'ForecastedAircraftPart',
#               'AdjudicatedMaintenanceEvent',
#               'Position',
#               'Aircraft'],
#              'RollupMetricBatchJobTestDataSourceEntity': ['RollupMetricBatchJobTestDataPoint',
#               'RollupMetricBatchJob'],
#              'OrganizationSegment': ['Organization', 'OrganizationSegment'],
#              'StagingRemisInventoryAssignmentTable': ['StagingRemisEndItemTable'],
#              'ReliabilityTteForecastPredictionHeader': ['ReliabilityAssetToTteModelRelation'],
#              'Tas.TestCase': ['Tas.MatchedIssue'],
#              'NotificationUserRecipient': ['User'],
#              'InventoryItemKits': ['InventoryItem',
#               'SupplyLocation',
#               'NationalStockNumber'],
#              'ReadinessAssetAlertToCaseRelation': ['ReadinessAssetAlert',
#               'ReliabilityAssetCase'],
#              'ReadinessDatasetPreparationRun': ['ReadinessAssetPositionToFailureModeRelation',
#               'Workflow.Run'],
#              'OperationFileTracker': ['ReadinessIngestEvent',
#               'ReadinessOperation',
#               'ReliabilityAsset'],
#              'PhysicalAsset': ['PhysicalAssetRelativePositionHistory',
#               'PhysicalAssetHierarchyRelation',
#               'PhysicalAssetLocationHistory',
#               'PhysicalAssetRealTimeLocation',
#               'BasePhysicalMeasurementSeries',
#               'PhysicalAssetEvent',
#               'PointPhysicalMeasurementSeries',
#               'PhysicalAssetHierarchyDenorm'],
#              'AssetClassParentChildRelation': ['AssetClass'],
#              'FakeTypeTwo': ['FakeTypeOne'],
#              'WorkOrderPartsSimilarityPredictions': ['WorkOrder',
#               'InventorySeries'],
#              'BundleStatus': ['UiBundler'],
#              'DataValidationRule': ['DataValidationRuleset'],
#              'StagingRemisOnEquipmentCorrectiveActionTable': ['StagingRemisOnEquipmentMaintenanceActionTable'],
#              'ReliabilityMl.ModelReport': ['ReliabilityMlModel',
#               'ReliabilityAsset'],
#              'MaintenanceToPart': ['NationalStockNumber',
#               'ReliabilityAssetCase',
#               'MxEffort'],
#              'ReliabilityMl.ValidationPredictionHeader': ['Unit',
#               'ReliabilityAssetToModelValidationRelation'],
#              'DataValidationRulesetHierarchicalRelation': ['DataValidationRuleset'],
#              'ReliabilityRiskScoreMlContributionHeader': ['ReadinessOperation',
#               'ReliabilityAsset',
#               'MlModel',
#               'ReliabilityAssetToRiskModelRelation'],
#              'Workflow.Run.MapReduce': ['MapReduceRun'],
#              'ItemPartyRole': ['PartyRole', 'Item'],
#              'MaintenanceActionGroup': ['MaintenanceAction',
#               'MaintenanceActionGroupDescriptionSegment'],
#              'PandaMail': ['PandaGroup', 'PandaUser', 'Mail'],
#              'SandboxTransformedRemisDataToMdmDataRuleRelation': ['MdmDataRule',
#               'SandboxTransformedRemisData'],
#              'InventoryHistory': ['InventoryItem', 'Location'],
#              'TestApiContext': ['TestApiObj', 'Action.Spy', 'TestApiContext'],
#              'SandboxTransformedRemisData': ['SandboxSampleFile',
#               'SandboxRawRemisData',
#               'SandboxTransformedRemisDataToMdmDataRuleRelation'],
#              'PartyRoleRelation': ['PartyRole'],
#              'PeriodicCalcStateHistory': ['PeriodicCalcState',
#               'RefreshCalcFieldsBatchJob'],
#              'StagingRemisOffEquipmentDiscrepancyTable': ['StagingRemisOffEquipmentWorkOrderTable'],
#              'MdmWucCorrectionRule': ['MdmDataset', 'WorkUnitCode'],
#              'UserPreference': ['Member'],
#              'NotificationCategoryPreference': ['NotificationRecipient'],
#              'GanttChartDemoResourceTimeRanges': ['GanttChartDemoResource'],
#              'InventoryItem': ['NationalStockNumber',
#               'InventoryHistory',
#               'SupplyLocation'],
#              'ScheduleHolidayDate': ['ScheduleHoliday'],
#              'DataValidationRuleset': ['DataValidationRule',
#               'DataValidationRulesetHierarchicalRelation'],
#              'MxEffort': ['MaintenanceToPart',
#               'ReliabilityAssetCase',
#               'MaintenanceEvent'],
#              'MlModel.Route': ['MlModel.Router',
#               'MlProject',
#               'MlModel.Route.StatusHistory',
#               'MlModel'],
#              'TrainingVideoFile': ['User'],
#              'MlModel.Monitor.BatchResult': ['MlModel.Monitor.JobRun'],
#              'UiBundlerPerformanceProfile': ['SetupWorkingDirPerformanceProfile',
#               'UiBundler',
#               'WebpackPerformanceProfile'],
#              'MaximGun': ['MaximGunFire'],
#              'PageGroup': ['Application'],
#              'CustomerRelation': ['Organization', 'Supplier', 'Customer'],
#              'StagingRemisOffEquipmentCorrectiveActionTable': ['StagingRemisOffEquipmentMaintenanceActionTable'],
#              'MdmTrdExcRuleJob': ['MdmExcisionRule'],
#              'Workflow.Run': ['Workflow', 'Workflow.Run'],
#              'MlSubject.Group': ['MlSubject.Group'],
#              'Action.Spy.Registry': ['Action.Spy'],
#              'GeoPoliticalRegion': ['GeoPoliticalRegionRelation'],
#              'ModelConfigCachedHyperparams': ['ReliabilityMlModel'],
#              'MlSubject.OperationJob.Result': ['MlModel.Route'],
#              'UiBundler': ['UiBundlerPerformanceProfile', 'BundleStatus'],
#              'InvalidationQueueErrorReview': ['InvalidationQueueErrorReviewComment'],
#              'TestResult': ['CodeCoverageCounter'],
#              'StagingRemisOffEquipmentWorkCenterEventDiscrepancyNarrativeTable': ['StagingRemisOffEquipmentMaintenanceActionTable'],
#              'StagingRemisUtilizationTable': ['StagingRemisInventoryPossessionTable'],
#              'InvalidationQueueReport': ['InvalidationQueueHistory'],
#              'InvalidationQueueError': ['InvalidationQueueErrorReview'],
#              'AircraftModelVariant': ['AircraftModel'],
#              'DataApiEntityType': ['TestApiEntityType', 'Unit'],
#              'GanttChartDemoResourceToCalendar': ['GanttChartDemoResource',
#               'GanttChartDemoCalendar'],
#              'Country': ['Currency'],
#              'PandaRulePredicter': ['ReliabilityCase',
#               'PandaRulePredicterWord'],
#              'ScheduleExceptionDatetimeWindow': ['ScheduleCalendar'],
#              'PurchaseOrder': ['PurchaseOrderLine'],
#              'EngineeringRecommendation': ['ReadinessAssetPositionToFailureModeRelation',
#               'AssetClass',
#               'FailureMode'],
#              'ReliabilityAssetSensorRelation': ['ExpectedSensor'],
#              'DataLake.Table.DownloadRequest': ['DataLake.Table.Managed'],
#              'Hpo.Experiment': ['Hpo.Trial', 'Workflow', 'MlPipe'],
#              'AirBaseToUsafOrganizationMapping': ['AirBase',
#               'UsafOrganization'],
#              'FacilityReliabilityAssetRelation': ['ReliabilityAsset',
#               'Facility'],
#              'RawRemisData': ['TransformedRemisData'],
#              'EventWindow': ['ObservedEvent'],
#              'UiBundlerResult': ['UiBundler'],
#              'ReliabilityAssetToRiskModelValidationRelation': ['ReliabilityRiskScoreMlValidationPredictionHeader',
#               'ReliabilityAssetValidationAlert',
#               'ReliabilityRiskScoreMlValidationContributionHeader'],
#              'WucToReliabilityCaseMapping': ['AircraftModel',
#               'ReliabilityCase',
#               'WorkUnitCode'],
#              'SandboxMdmDatasetToTrdMapping': ['SandboxMdmDataset',
#               'SandboxTransformedRemisData'],
#              'Employee': ['Person', 'Country'],
#              'TestApiObj': ['TestApiContext'],
#              'MlModel.Router': ['MlModel.Route', 'MlProject'],
#              'SupplyLocation': ['AirBase'],
#              'MlModel.Monitor.Result': ['MlModel.Monitor.JobRun',
#               'MlModel',
#               'MlModel.Monitor.Job'],
#              'ReadinessRiskInferenceJob': ['ReadinessAssetPositionToFailureModeRelation',
#               'AssetClass'],
#              'ReliabilityAssetCaseFailureModeRelation': ['ReliabilityAssetCase'],
#              'SupplyTransactionLinkagesJob': ['MonthlyPartsRemovedJob'],
#              'ReliabilityRiskScoreMlValidationPredictionHeader': ['ReliabilityAssetToRiskModelValidationRelation',
#               'Unit'],
#              'InventorySeries': ['Unit', 'WorkOrderPartsForecast'],
#              'MaintenanceEventDescriptionSegment': ['MaintenanceEvent'],
#              'UiSdlMetadataFileManifest': ['UiBundler'],
#              'MapReduceRun': ['ReduceResult'],
#              'Tas.Response': ['Tas.BuildInfo'],
#              'WorkItem': ['WorkOrder'],
#              'MlWorkflowCoordinatableResult': ['MlWorkflowCoordinatable'],
#              'MdmExcisionRule': ['MdmDataset'],
#              'PurchaseOrderPartsForecast': ['InventorySeries'],
#              'GenerateTagSpec': ['Tag'],
#              'LMEChangeHistory': ['AdjudicatedMaintenanceEvent',
#               'LabeledMaintenanceEvent',
#               'PandaUser'],
#              'ReliabilityModelRegistry.TargetEntry': ['ReliabilityMlModel'],
#              'TestStateMachine': ['WorkOrderPerfTest'],
#              'ClusterCenterSeries': ['Unit'],
#              'ReduceResult': ['MapReduceRun'],
#              'PartyPhone': ['Party'],
#              'MdmDatasetToExcisionRuleMapping': ['MdmDataset',
#               'MdmExcisionRule'],
#              'GanttChartDemoCalendar': ['GanttChartDemoCalendarInterval',
#               'GanttChartDemoCalendar'],
#              'ReliabilityAssetToModelValidationRelation': ['ReliabilityMl.ValidationContributionHeader',
#               'ReliabilityMl.ValidationPredictionHeader'],
#              'PersonOrganizationRelation': ['Person', 'Organization'],
#              'NotificationHistory': ['NotificationRecipient'],
#              'PositionToReliabilityCaseMapping': ['Position',
#               'ReliabilityCase'],
#              'ReliabilityMl.ContributionHeader': ['ReliabilityAssetToModelRelation'],
#              'Workflow.Run.Nested': ['Workflow.Run'],
#              'SbaDartDataFile': ['ReadinessOperation'],
#              'StagingRemisOnEquipmentMaintenanceActionTable': ['StagingRemisOnEquipmentWorkOrderTable',
#               'StagingRemisOnEquipmentMaintenanceRemoveAndInstallDataTable'],
#              'TimeBoundAlertMetric': ['FailureMode'],
#              'StagingRemisInventoryTable': ['StagingRemisEndItemTable'],
#              'FailureModePositionToOperation': ['ReadinessAssetPositionToFailureModeRelation',
#               'ReadinessOperation'],
#              'MlModel.Route.OperationJob.Run': ['MlModel.Route.OperationJob'],
#              'Tas.TestSuiteResponse': ['Tas.TestCase'],
#              'FlightHourForecast': ['Majcom'],
#              'ReliabilityModelRegistry.SourceEntry': ['ReliabilityMlModel'],
#              'SplitSpec': ['ReliabilityCase'],
#              'ReliabilityAssetCaseToAssetRelation': ['ReliabilityAsset',
#               'ReliabilityAssetCase'],
#              'TestGraphVisualizationEdge': ['TestGraphVisualizationNode'],
#              'App.Metric': ['App.Metric', 'Unit'],
#              'CommentBoard': ['CommentBoardReply'],
#              'TransformedRemisData': ['TransformedRemisDataToMdmDataRuleRelation',
#               'MdmExcisionRule',
#               'RawRemisData'],
#              'PersonUser': ['Person', 'User'],
#              'FailureModeRelation': ['FailureModeFeedback',
#               'FailureModeLineItem'],
#              'AirBaseModelPair': ['Aircraft', 'AircraftModel', 'AirBase'],
#              'AiAssistant.Feedback.Answer': ['AiAssistant.Feedback.Question'],
#              'ReliabilityTteMlModel': ['ReliabilityAssetToTteModelRelation'],
#              'ExternalNiinDemandForecast': ['DeltaNiinDemandForecast',
#               'CbmNiinDemandForecast'],
#              'MlProject': ['MlModel.Router'],
#              'JupyterDirectory': ['JupyterContent'],
#              'TestApiEntityType': ['DataApiEntityType'],
#              'MlModel.Health.History': ['MlModel.HealthCalc.JobRun',
#               'MlModel.HealthCalc.Result'],
#              'CronJob': ['JobHistory'],
#              'LocationMeasurementDevice': ['Location'],
#              'FixedAssetHierarchyRelation': ['FixedAsset'],
#              'WebpackPerformanceProfile': ['UiBundlerPerformanceProfile'],
#              'MlModel.Monitor.JobRun': ['MlModel.Monitor.Job'],
#              'MdmDataRuleVersion': ['PandaUser', 'MdmDataRule'],
#              'GeoPoliticalRegionRelation': ['GeoPoliticalRegion'],
#              'Translation': ['Locale'],
#              'SetupWorkingDirPerformanceProfile': ['UiBundlerPerformanceProfile'],
#              'ItemFacilityInventoryParams': ['Item', 'Facility'],
#              'ReadinessRiskInferenceLog': ['ReadinessRiskInferenceJob'],
#              'DataConfiguration': ['PandaUser'],
#              'SourceFile': ['SourceStatus'],
#              'PhysicalAssetRealTimeLocation': ['PhysicalAsset'],
#              'PurchaseOrderLineReceipt': ['PurchaseOrderLine'],
#              'ReliabilityMl.Project': ['MlProject'],
#              'ReliabilityAssetTteAlert': ['ReliabilityTteMlModel'],
#              'MonthlyPartsRemoved': ['SupplyTransaction'],
#              'TestActionMock': ['Action.Spy'],
#              'SensorValueMapping': ['ExpectedSensor'],
#              'InvalidationQueueErrorReviewComment': ['InvalidationQueueErrorReview'],
#              'ReliabilityAssetToModelRelation': ['ReliabilityMl.PredictionHeader',
#               'ReliabilityMlModel',
#               'ReliabilityMl.ContributionHeader'],
#              'Hpo.Run': ['MlOperationRun', 'MlPipe'],
#              'ReliabilityTteForecastContributionHeader': ['ReliabilityAssetToTteModelRelation'],
#              'ProtectionLoopSensorRelation': ['Sensor', 'ProtectionLoop'],
#              'GovUser': ['User'],
#              'InventoryItem218': ['InventoryItem',
#               'NationalStockNumber',
#               'SupplyLocation'],
#              'PandaFeedback': ['User'],
#              'ProtectionLoop': ['ProtectionLoopSensorRelation',
#               'ProtectionLoopAlert'],
#              'TestOrganization': ['TestOrganizationDenorm',
#               'TestOrganization'],
#              'Rate': ['Exchange', 'Currency'],
#              'BusinessRegion': ['BusinessRegionRelation'],
#              'UserGroup': ['User'],
#              'MlModel.HealthCalc.JobRun': ['MlModel.HealthCalc.Job'],
#              'PartyCommunicationPreference': ['Party'],
#              'User': ['UserGroup'],
#              'PandaRulePredicterWord': ['PandaRulePredicter'],
#              'ProtectionLoopAlert': ['ProtectionLoop', 'Sensor'],
#              'ReliabilitySyntheticData.ReliabilityRisk.AssetHierarchySpreadsheet': ['ReliabilitySyntheticData.ReliabilityRisk.DataGenerationJob'],
#              'GanttChartDemoCalendarInterval': ['GanttChartDemoCalendar'],
#              'AdditionalRelationalDataSpec': ['AdditionalExportSpec'],
#              'ReliabilityAssetClassDefinitionParserJob': ['ReliabilityAssetClassDefinitionParserJobBatchResult'],
#              'EtlLog': ['EtlCoordinator'],
#              'UserRecommendationStatusHistory': ['UserRecommendation', 'User'],
#              'FailureModeLibrary': ['FailureMode'],
#              'FailureRecommendationRelation': ['FailureRecommendationFeedback',
#               'FailureModeRecommendation'],
#              'DataLake.Table.ShareRequest': ['DataLake.Table.Managed',
#               'UserGroup'],
#              'CustomerContact': ['Contact', 'Customer'],
#              'ReadinessIngestEvent': ['ReadinessDataIngest'],
#              'SensorBounds': ['ExpectedSensor'],
#              'ReliabilityTteContributionHeader': ['ReliabilityAssetToTteModelRelation'],
#              'ReliabilityTtePredictionHeader': ['ReliabilityAssetToTteModelRelation'],
#              'SourceStatus': ['SourceChunkStatus'],
#              'BusinessRegionRelation': ['BusinessRegion'],
#              'PhysicalAssetLocationHistory': ['Location'],
#              'MlModel.Evaluation.Run': ['MlModel.Evaluator'],
#              'CommentBoardReply': ['CommentBoard',
#               'CommentBoardReply',
#               'PandaUser'],
#              'Workflow.Run.Vertex': ['Workflow.Run'],
#              'AssetOnboardingSourceFile': ['AssetOnboardingSourceFile'],
#              'MapResult': ['MapReduceRun'],
#              'ReliabilityRiskMlModel': ['ReliabilityMlDatasetPreparationRun',
#               'ModelTemplate',
#               'ReliabilityAssetToRiskModelRelation'],
#              'TestSmartBulb': ['TestSmartBulbToApartmentRelation'],
#              'WorkOrderPerfTest': ['TestStateMachine'],
#              'FacilityHierarchicalRelation': ['Facility'],
#              'DataLake.Table.MetaFieldValue': ['DataLake.Table.Managed'],
#              'AiAssistant.Feedback.Question': ['AiAssistant.Feedback.Answer'],
#              'Tas.CloseAutomationState': ['JobHistory'],
#              'ReliabilityMl.PredictionHeader': ['Unit',
#               'ReliabilityAssetToModelRelation'],
#              'TSStats': ['TSStatsJob'],
#              'ReliabilityRiskScoreMlScoreHeader': ['ReliabilityAssetToRiskModelRelation'],
#              'JobStatusReport': ['JobStatusTracker'],
#              'WucToMdmWucCorrectionRulesMapping': ['MdmWucCorrectionRule'],
#              'StagingRemisInventoryPossessionTable': ['StagingRemisEndItemTable'],
#              'Hpo.Trial': ['Hpo.Run'],
#              'SensorEventType': ['AircraftSensorEventValueHistory'],
#              'Idp': ['IdpCertificate'],
#              'SandboxMdmDatasetToExcisionRuleMapping': ['SandboxMdmDataset',
#               'MdmExcisionRule'],
#              'SensorDataSummary': ['Sensor'],
#              'Workflow.Run.Batch': ['BatchJobRun'],
#              'TrainingHandbookFile': ['User'],
#              'MlModel.Monitor.TimedResultHeader': ['MlModel'],
#              'Position': ['PositionToReliabilityCaseMapping'],
#              'GitHubToken': ['User'],
#              'Supplier': ['Organization'],
#              'RegionRelation': ['Region'],
#              'Tas.TrackingResponse': ['Tas.MatchedIssue'],
#              'ReliabilityAssetToReadinessRiskModelRelation': ['ReadinessRiskMlModel'],
#              'MaintenanceActionDescriptionSegment': ['MaintenanceAction'],
#              'CreateLabeledMaintenanceJob': ['ReliabilityCase'],
#              'SensorMeasurementBounds': ['Sensor'],
#              'AssetPartyRole': ['PhysicalAsset', 'PartyRole'],
#              'WorkOrderPartsForecast': ['InventorySeries'],
#              'StagingRemisOnEquipmentWorkCenterEventDiscrepancyNarrativeTable': ['StagingRemisOnEquipmentMaintenanceActionTable'],
#              'DataValidationSubject': ['DataValidationRun'],
#              'BasePhysicalMeasurementSeries': ['Unit',
#               'BasePhysicalMeasurementSeries'],
#              'MetricProfileSpec': ['MetricProfilerSpec'],
#              'X12Loop': ['X12Loop'],
#              'MdmGetTrdsAndExcRulesJob': ['MdmDataset'],
#              'AnalysisWorkflowStateHistory': ['PandaUser'],
#              'AircraftAssetMaintenanceRecommendationAlert': ['UserAircraftAssetMaintenanceRecommendationRelation'],
#              'DeltaSegmentDemandForecast': ['AircraftModel']})

# %%
top_nodes = find_top_level_nodes(node_map, adj_list, 50)

# %%
top_nodes
# Out:
# ['SandboxMdmDatasetToExcisionRuleMapping',
#  'SandboxMdmDataset',
#  'SandboxMdmDatasetToTrdMapping',
#  'WucToMdmWucCorrectionRulesMapping',
#  'MdmTrdExcRuleJob',
#  'MdmGetTrdsAndExcRulesJob',
#  'MdmWucCorrectionRule',
#  'RawRemisData',
#  'MdmExcisionRule',
#  'MdmDataRuleVersion',
#  'TransformedRemisData',
#  'MdmDatasetToExcisionRuleMapping',
#  'MdmDataset',
#  'SandboxTransformedRemisDataToMdmDataRuleRelation',
#  'MdmDataRule',
#  'SandboxRawRemisData',
#  'TransformedRemisDataToMdmDataRuleRelation',
#  'MdmDatasetToTrdMapping',
#  'SandboxTransformedRemisData',
#  'SandboxSampleFile',
#  'ProtectionLoop',
#  'OperationFileTracker',
#  'ProtectionLoopSensorRelation',
#  'ProtectionLoopAlert',
#  'FailureRecommendationRelation',
#  'CommentBoard',
#  'PandaMail',
#  'CommentBoardReply',
#  'ReadinessRiskInferenceLog',
#  'ReliabilityAssetClassDefinitionParserJobBatchResult',
#  'ReliabilityAssetClassDefinitionParserJob',
#  'FailureModeRelation',
#  'MasterSensor',
#  'MaintenanceDataSourceSpec',
#  'FacilityReliabilityAssetRelation',
#  'TypeMetaDocGetterSampleType',
#  'AircraftAssetMaintenanceRecommendationAlert',
#  'ReliabilityAssetRiskAlert',
#  'MeasurementSeries',
#  'ReliabilityModelRegistry.TargetEntry',
#  'ModelConfigCachedHyperparams',
#  'TimeBoundAlertMetric',
#  'ReadinessRiskInferenceJob',
#  'ReliabilityAssetAlertBase',
#  'LMEChangeHistory',
#  'DataConfiguration',
#  'CreateLabeledMaintenanceJob',
#  'FixedAssetHierarchyRelation',
#  'AnalysisWorkflowStateHistory',
#  'WorkOrderPartsDenormalized']

# %%
hierarchy = build_hierarchical_graph(top_nodes, node_map, adj_list, 3)

# %%
hierarchy
# Out:
# {'SandboxMdmDatasetToExcisionRuleMapping': {'SandboxMdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'SandboxMdmDatasetToExcisionRuleMapping',
#     'category': 'Entity',
#     'data': {'name': 'SandboxMdmDatasetToExcisionRuleMapping',
#      'categoryMetadataIdentifier': 'SandboxMdmDatasetToExcisionRuleMapping',
#      'package': 'panda'}},
#    'children': {'SandboxMdmDataset': {'node_info': {'id': 'SandboxMdmDataset',
#       'category': 'Entity',
#       'data': {'name': 'SandboxMdmDataset',
#        'categoryMetadataIdentifier': 'SandboxMdmDataset',
#        'package': 'panda'}},
#      'children': {'SandboxSampleFile': {'node_info': {'id': 'SandboxSampleFile',
#         'category': 'Entity',
#         'data': {'name': 'SandboxSampleFile',
#          'categoryMetadataIdentifier': 'SandboxSampleFile',
#          'package': 'panda'}},
#        'children': {'SourceFile': {'node_info': {'id': 'SourceFile',
#           'category': 'Entity',
#           'data': {'name': 'SourceFile',
#            'categoryMetadataIdentifier': 'SourceFile',
#            'package': 'platform'}},
#          'children': {}},
#         'AircraftModel': {'node_info': {'id': 'AircraftModel',
#           'category': 'Entity',
#           'data': {'name': 'AircraftModel',
#            'categoryMetadataIdentifier': 'AircraftModel',
#            'package': 'panda'}},
#          'children': {}},
#         'PandaUser': {'node_info': {'id': 'PandaUser',
#           'category': 'Entity',
#           'data': {'name': 'PandaUser',
#            'categoryMetadataIdentifier': 'PandaUser',
#            'package': 'panda'}},
#          'children': {}}}},
#       'MdmExcisionRule': {'node_info': {'id': 'MdmExcisionRule',
#         'category': 'Entity',
#         'data': {'name': 'MdmExcisionRule',
#          'categoryMetadataIdentifier': 'MdmExcisionRule',
#          'package': 'panda'}},
#        'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#           'category': 'Entity',
#           'data': {'name': 'MdmDataset',
#            'categoryMetadataIdentifier': 'MdmDataset',
#            'package': 'panda'}},
#          'children': {}}}},
#       'SandboxTransformedRemisData': {'node_info': {'id': 'SandboxTransformedRemisData',
#         'category': 'Entity',
#         'data': {'name': 'SandboxTransformedRemisData',
#          'categoryMetadataIdentifier': 'SandboxTransformedRemisData',
#          'package': 'panda'}},
#        'children': {'SandboxRawRemisData': {'node_info': {'id': 'SandboxRawRemisData',
#           'category': 'Entity',
#           'data': {'name': 'SandboxRawRemisData',
#            'categoryMetadataIdentifier': 'SandboxRawRemisData',
#            'package': 'panda'}},
#          'children': {}},
#         'SandboxTransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#           'category': 'Entity',
#           'data': {'name': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#            'categoryMetadataIdentifier': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#            'package': 'panda'}},
#          'children': {}}}},
#       'SandboxMdmDatasetToTrdMapping': {'node_info': {'id': 'SandboxMdmDatasetToTrdMapping',
#         'category': 'Entity',
#         'data': {'name': 'SandboxMdmDatasetToTrdMapping',
#          'categoryMetadataIdentifier': 'SandboxMdmDatasetToTrdMapping',
#          'package': 'panda'}},
#        'children': {}},
#       'MdmWucCorrectionRule': {'node_info': {'id': 'MdmWucCorrectionRule',
#         'category': 'Entity',
#         'data': {'name': 'MdmWucCorrectionRule',
#          'categoryMetadataIdentifier': 'MdmWucCorrectionRule',
#          'package': 'panda'}},
#        'children': {'WorkUnitCode': {'node_info': {'id': 'WorkUnitCode',
#           'category': 'Entity',
#           'data': {'name': 'WorkUnitCode',
#            'categoryMetadataIdentifier': 'WorkUnitCode',
#            'package': 'readiness'}},
#          'children': {}}}}}}}}},
#  'SandboxMdmDataset': {'SandboxMdmDataset': {'node_info': {'id': 'SandboxMdmDataset',
#     'category': 'Entity',
#     'data': {'name': 'SandboxMdmDataset',
#      'categoryMetadataIdentifier': 'SandboxMdmDataset',
#      'package': 'panda'}},
#    'children': {'SandboxSampleFile': {'node_info': {'id': 'SandboxSampleFile',
#       'category': 'Entity',
#       'data': {'name': 'SandboxSampleFile',
#        'categoryMetadataIdentifier': 'SandboxSampleFile',
#        'package': 'panda'}},
#      'children': {'SourceFile': {'node_info': {'id': 'SourceFile',
#         'category': 'Entity',
#         'data': {'name': 'SourceFile',
#          'categoryMetadataIdentifier': 'SourceFile',
#          'package': 'platform'}},
#        'children': {'SourceStatus': {'node_info': {'id': 'SourceStatus',
#           'category': 'Entity',
#           'data': {'name': 'SourceStatus',
#            'categoryMetadataIdentifier': 'SourceStatus',
#            'package': 'platform'}},
#          'children': {}}}},
#       'AircraftModel': {'node_info': {'id': 'AircraftModel',
#         'category': 'Entity',
#         'data': {'name': 'AircraftModel',
#          'categoryMetadataIdentifier': 'AircraftModel',
#          'package': 'panda'}},
#        'children': {'PandaGroup': {'node_info': {'id': 'PandaGroup',
#           'category': 'Entity',
#           'data': {'name': 'PandaGroup',
#            'categoryMetadataIdentifier': 'PandaGroup',
#            'package': 'panda'}},
#          'children': {}},
#         'FlightHourForecast': {'node_info': {'id': 'FlightHourForecast',
#           'category': 'Entity',
#           'data': {'name': 'FlightHourForecast',
#            'categoryMetadataIdentifier': 'FlightHourForecast',
#            'package': 'panda'}},
#          'children': {}},
#         'Aircraft': {'node_info': {'id': 'Aircraft',
#           'category': 'Entity',
#           'data': {'name': 'Aircraft',
#            'categoryMetadataIdentifier': 'Aircraft',
#            'package': 'panda'}},
#          'children': {}},
#         'Majcom': {'node_info': {'id': 'Majcom',
#           'category': 'Entity',
#           'data': {'name': 'Majcom',
#            'categoryMetadataIdentifier': 'Majcom',
#            'package': 'readiness'}},
#          'children': {}},
#         'AssetClass': {'node_info': {'id': 'AssetClass',
#           'category': 'Entity',
#           'data': {'name': 'AssetClass',
#            'categoryMetadataIdentifier': 'AssetClass',
#            'package': 'reliabilityDataModel'}},
#          'children': {}},
#         'MonthlyPartsRemoved': {'node_info': {'id': 'MonthlyPartsRemoved',
#           'category': 'Entity',
#           'data': {'name': 'MonthlyPartsRemoved',
#            'categoryMetadataIdentifier': 'MonthlyPartsRemoved',
#            'package': 'panda'}},
#          'children': {}},
#         'ReliabilityCase': {'node_info': {'id': 'ReliabilityCase',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityCase',
#            'categoryMetadataIdentifier': 'ReliabilityCase',
#            'package': 'panda'}},
#          'children': {}},
#         'PandaUser': {'node_info': {'id': 'PandaUser',
#           'category': 'Entity',
#           'data': {'name': 'PandaUser',
#            'categoryMetadataIdentifier': 'PandaUser',
#            'package': 'panda'}},
#          'children': {}},
#         'AircraftModelVariant': {'node_info': {'id': 'AircraftModelVariant',
#           'category': 'Entity',
#           'data': {'name': 'AircraftModelVariant',
#            'categoryMetadataIdentifier': 'AircraftModelVariant',
#            'package': 'panda'}},
#          'children': {}},
#         'WorkUnitCode': {'node_info': {'id': 'WorkUnitCode',
#           'category': 'Entity',
#           'data': {'name': 'WorkUnitCode',
#            'categoryMetadataIdentifier': 'WorkUnitCode',
#            'package': 'readiness'}},
#          'children': {}},
#         'UserAccessRequest': {'node_info': {'id': 'UserAccessRequest',
#           'category': 'Entity',
#           'data': {'name': 'UserAccessRequest',
#            'categoryMetadataIdentifier': 'UserAccessRequest',
#            'package': 'panda'}},
#          'children': {}}}}}},
#     'MdmExcisionRule': {'node_info': {'id': 'MdmExcisionRule',
#       'category': 'Entity',
#       'data': {'name': 'MdmExcisionRule',
#        'categoryMetadataIdentifier': 'MdmExcisionRule',
#        'package': 'panda'}},
#      'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#         'category': 'Entity',
#         'data': {'name': 'MdmDataset',
#          'categoryMetadataIdentifier': 'MdmDataset',
#          'package': 'panda'}},
#        'children': {'TransformedRemisData': {'node_info': {'id': 'TransformedRemisData',
#           'category': 'Entity',
#           'data': {'name': 'TransformedRemisData',
#            'categoryMetadataIdentifier': 'TransformedRemisData',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmDatasetToTrdMapping': {'node_info': {'id': 'MdmDatasetToTrdMapping',
#           'category': 'Entity',
#           'data': {'name': 'MdmDatasetToTrdMapping',
#            'categoryMetadataIdentifier': 'MdmDatasetToTrdMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'MdmDatasetToExcisionRuleMapping',
#           'category': 'Entity',
#           'data': {'name': 'MdmDatasetToExcisionRuleMapping',
#            'categoryMetadataIdentifier': 'MdmDatasetToExcisionRuleMapping',
#            'package': 'panda'}},
#          'children': {}}}}}},
#     'SandboxMdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'SandboxMdmDatasetToExcisionRuleMapping',
#       'category': 'Entity',
#       'data': {'name': 'SandboxMdmDatasetToExcisionRuleMapping',
#        'categoryMetadataIdentifier': 'SandboxMdmDatasetToExcisionRuleMapping',
#        'package': 'panda'}},
#      'children': {}},
#     'SandboxTransformedRemisData': {'node_info': {'id': 'SandboxTransformedRemisData',
#       'category': 'Entity',
#       'data': {'name': 'SandboxTransformedRemisData',
#        'categoryMetadataIdentifier': 'SandboxTransformedRemisData',
#        'package': 'panda'}},
#      'children': {'SandboxRawRemisData': {'node_info': {'id': 'SandboxRawRemisData',
#         'category': 'Entity',
#         'data': {'name': 'SandboxRawRemisData',
#          'categoryMetadataIdentifier': 'SandboxRawRemisData',
#          'package': 'panda'}},
#        'children': {}},
#       'SandboxTransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#         'category': 'Entity',
#         'data': {'name': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#          'categoryMetadataIdentifier': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#          'package': 'panda'}},
#        'children': {'MdmDataRule': {'node_info': {'id': 'MdmDataRule',
#           'category': 'Entity',
#           'data': {'name': 'MdmDataRule',
#            'categoryMetadataIdentifier': 'MdmDataRule',
#            'package': 'panda'}},
#          'children': {}}}}}},
#     'SandboxMdmDatasetToTrdMapping': {'node_info': {'id': 'SandboxMdmDatasetToTrdMapping',
#       'category': 'Entity',
#       'data': {'name': 'SandboxMdmDatasetToTrdMapping',
#        'categoryMetadataIdentifier': 'SandboxMdmDatasetToTrdMapping',
#        'package': 'panda'}},
#      'children': {}},
#     'MdmWucCorrectionRule': {'node_info': {'id': 'MdmWucCorrectionRule',
#       'category': 'Entity',
#       'data': {'name': 'MdmWucCorrectionRule',
#        'categoryMetadataIdentifier': 'MdmWucCorrectionRule',
#        'package': 'panda'}},
#      'children': {}}}}},
#  'SandboxMdmDatasetToTrdMapping': {'SandboxMdmDatasetToTrdMapping': {'node_info': {'id': 'SandboxMdmDatasetToTrdMapping',
#     'category': 'Entity',
#     'data': {'name': 'SandboxMdmDatasetToTrdMapping',
#      'categoryMetadataIdentifier': 'SandboxMdmDatasetToTrdMapping',
#      'package': 'panda'}},
#    'children': {'SandboxMdmDataset': {'node_info': {'id': 'SandboxMdmDataset',
#       'category': 'Entity',
#       'data': {'name': 'SandboxMdmDataset',
#        'categoryMetadataIdentifier': 'SandboxMdmDataset',
#        'package': 'panda'}},
#      'children': {'SandboxSampleFile': {'node_info': {'id': 'SandboxSampleFile',
#         'category': 'Entity',
#         'data': {'name': 'SandboxSampleFile',
#          'categoryMetadataIdentifier': 'SandboxSampleFile',
#          'package': 'panda'}},
#        'children': {'SourceFile': {'node_info': {'id': 'SourceFile',
#           'category': 'Entity',
#           'data': {'name': 'SourceFile',
#            'categoryMetadataIdentifier': 'SourceFile',
#            'package': 'platform'}},
#          'children': {}},
#         'AircraftModel': {'node_info': {'id': 'AircraftModel',
#           'category': 'Entity',
#           'data': {'name': 'AircraftModel',
#            'categoryMetadataIdentifier': 'AircraftModel',
#            'package': 'panda'}},
#          'children': {}},
#         'PandaUser': {'node_info': {'id': 'PandaUser',
#           'category': 'Entity',
#           'data': {'name': 'PandaUser',
#            'categoryMetadataIdentifier': 'PandaUser',
#            'package': 'panda'}},
#          'children': {}}}},
#       'MdmExcisionRule': {'node_info': {'id': 'MdmExcisionRule',
#         'category': 'Entity',
#         'data': {'name': 'MdmExcisionRule',
#          'categoryMetadataIdentifier': 'MdmExcisionRule',
#          'package': 'panda'}},
#        'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#           'category': 'Entity',
#           'data': {'name': 'MdmDataset',
#            'categoryMetadataIdentifier': 'MdmDataset',
#            'package': 'panda'}},
#          'children': {}}}},
#       'SandboxMdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'SandboxMdmDatasetToExcisionRuleMapping',
#         'category': 'Entity',
#         'data': {'name': 'SandboxMdmDatasetToExcisionRuleMapping',
#          'categoryMetadataIdentifier': 'SandboxMdmDatasetToExcisionRuleMapping',
#          'package': 'panda'}},
#        'children': {}},
#       'SandboxTransformedRemisData': {'node_info': {'id': 'SandboxTransformedRemisData',
#         'category': 'Entity',
#         'data': {'name': 'SandboxTransformedRemisData',
#          'categoryMetadataIdentifier': 'SandboxTransformedRemisData',
#          'package': 'panda'}},
#        'children': {'SandboxRawRemisData': {'node_info': {'id': 'SandboxRawRemisData',
#           'category': 'Entity',
#           'data': {'name': 'SandboxRawRemisData',
#            'categoryMetadataIdentifier': 'SandboxRawRemisData',
#            'package': 'panda'}},
#          'children': {}},
#         'SandboxTransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#           'category': 'Entity',
#           'data': {'name': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#            'categoryMetadataIdentifier': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#            'package': 'panda'}},
#          'children': {}}}},
#       'MdmWucCorrectionRule': {'node_info': {'id': 'MdmWucCorrectionRule',
#         'category': 'Entity',
#         'data': {'name': 'MdmWucCorrectionRule',
#          'categoryMetadataIdentifier': 'MdmWucCorrectionRule',
#          'package': 'panda'}},
#        'children': {'WorkUnitCode': {'node_info': {'id': 'WorkUnitCode',
#           'category': 'Entity',
#           'data': {'name': 'WorkUnitCode',
#            'categoryMetadataIdentifier': 'WorkUnitCode',
#            'package': 'readiness'}},
#          'children': {}}}}}}}}},
#  'WucToMdmWucCorrectionRulesMapping': {'WucToMdmWucCorrectionRulesMapping': {'node_info': {'id': 'WucToMdmWucCorrectionRulesMapping',
#     'category': 'Entity',
#     'data': {'name': 'WucToMdmWucCorrectionRulesMapping',
#      'categoryMetadataIdentifier': 'WucToMdmWucCorrectionRulesMapping',
#      'package': 'panda'}},
#    'children': {'MdmWucCorrectionRule': {'node_info': {'id': 'MdmWucCorrectionRule',
#       'category': 'Entity',
#       'data': {'name': 'MdmWucCorrectionRule',
#        'categoryMetadataIdentifier': 'MdmWucCorrectionRule',
#        'package': 'panda'}},
#      'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#         'category': 'Entity',
#         'data': {'name': 'MdmDataset',
#          'categoryMetadataIdentifier': 'MdmDataset',
#          'package': 'panda'}},
#        'children': {'TransformedRemisData': {'node_info': {'id': 'TransformedRemisData',
#           'category': 'Entity',
#           'data': {'name': 'TransformedRemisData',
#            'categoryMetadataIdentifier': 'TransformedRemisData',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmDatasetToTrdMapping': {'node_info': {'id': 'MdmDatasetToTrdMapping',
#           'category': 'Entity',
#           'data': {'name': 'MdmDatasetToTrdMapping',
#            'categoryMetadataIdentifier': 'MdmDatasetToTrdMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'MdmDatasetToExcisionRuleMapping',
#           'category': 'Entity',
#           'data': {'name': 'MdmDatasetToExcisionRuleMapping',
#            'categoryMetadataIdentifier': 'MdmDatasetToExcisionRuleMapping',
#            'package': 'panda'}},
#          'children': {}}}},
#       'WorkUnitCode': {'node_info': {'id': 'WorkUnitCode',
#         'category': 'Entity',
#         'data': {'name': 'WorkUnitCode',
#          'categoryMetadataIdentifier': 'WorkUnitCode',
#          'package': 'readiness'}},
#        'children': {'NsnToWucMapping': {'node_info': {'id': 'NsnToWucMapping',
#           'category': 'Entity',
#           'data': {'name': 'NsnToWucMapping',
#            'categoryMetadataIdentifier': 'NsnToWucMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'AircraftModel': {'node_info': {'id': 'AircraftModel',
#           'category': 'Entity',
#           'data': {'name': 'AircraftModel',
#            'categoryMetadataIdentifier': 'AircraftModel',
#            'package': 'panda'}},
#          'children': {}},
#         'AircraftAsset': {'node_info': {'id': 'AircraftAsset',
#           'category': 'Entity',
#           'data': {'name': 'AircraftAsset',
#            'categoryMetadataIdentifier': 'AircraftAsset',
#            'package': 'panda'}},
#          'children': {}},
#         'ReliabilityCase': {'node_info': {'id': 'ReliabilityCase',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityCase',
#            'categoryMetadataIdentifier': 'ReliabilityCase',
#            'package': 'panda'}},
#          'children': {}},
#         'NationalItemIdentificationNumber': {'node_info': {'id': 'NationalItemIdentificationNumber',
#           'category': 'Entity',
#           'data': {'name': 'NationalItemIdentificationNumber',
#            'categoryMetadataIdentifier': 'NationalItemIdentificationNumber',
#            'package': 'panda'}},
#          'children': {}},
#         'WucToReliabilityCaseMapping': {'node_info': {'id': 'WucToReliabilityCaseMapping',
#           'category': 'Entity',
#           'data': {'name': 'WucToReliabilityCaseMapping',
#            'categoryMetadataIdentifier': 'WucToReliabilityCaseMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'NationalStockNumber': {'node_info': {'id': 'NationalStockNumber',
#           'category': 'Entity',
#           'data': {'name': 'NationalStockNumber',
#            'categoryMetadataIdentifier': 'NationalStockNumber',
#            'package': 'readiness'}},
#          'children': {}},
#         'MaintenanceAction': {'node_info': {'id': 'MaintenanceAction',
#           'category': 'Entity',
#           'data': {'name': 'MaintenanceAction',
#            'categoryMetadataIdentifier': 'MaintenanceAction',
#            'package': 'readiness'}},
#          'children': {}}}}}}}}},
#  'MdmTrdExcRuleJob': {'MdmTrdExcRuleJob': {'node_info': {'id': 'MdmTrdExcRuleJob',
#     'category': 'Entity',
#     'data': {'name': 'MdmTrdExcRuleJob',
#      'categoryMetadataIdentifier': 'MdmTrdExcRuleJob',
#      'package': 'panda'}},
#    'children': {'MdmExcisionRule': {'node_info': {'id': 'MdmExcisionRule',
#       'category': 'Entity',
#       'data': {'name': 'MdmExcisionRule',
#        'categoryMetadataIdentifier': 'MdmExcisionRule',
#        'package': 'panda'}},
#      'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#         'category': 'Entity',
#         'data': {'name': 'MdmDataset',
#          'categoryMetadataIdentifier': 'MdmDataset',
#          'package': 'panda'}},
#        'children': {'TransformedRemisData': {'node_info': {'id': 'TransformedRemisData',
#           'category': 'Entity',
#           'data': {'name': 'TransformedRemisData',
#            'categoryMetadataIdentifier': 'TransformedRemisData',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmDatasetToTrdMapping': {'node_info': {'id': 'MdmDatasetToTrdMapping',
#           'category': 'Entity',
#           'data': {'name': 'MdmDatasetToTrdMapping',
#            'categoryMetadataIdentifier': 'MdmDatasetToTrdMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'MdmDatasetToExcisionRuleMapping',
#           'category': 'Entity',
#           'data': {'name': 'MdmDatasetToExcisionRuleMapping',
#            'categoryMetadataIdentifier': 'MdmDatasetToExcisionRuleMapping',
#            'package': 'panda'}},
#          'children': {}}}}}}}}},
#  'MdmGetTrdsAndExcRulesJob': {'MdmGetTrdsAndExcRulesJob': {'node_info': {'id': 'MdmGetTrdsAndExcRulesJob',
#     'category': 'Entity',
#     'data': {'name': 'MdmGetTrdsAndExcRulesJob',
#      'categoryMetadataIdentifier': 'MdmGetTrdsAndExcRulesJob',
#      'package': 'panda'}},
#    'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#       'category': 'Entity',
#       'data': {'name': 'MdmDataset',
#        'categoryMetadataIdentifier': 'MdmDataset',
#        'package': 'panda'}},
#      'children': {'TransformedRemisData': {'node_info': {'id': 'TransformedRemisData',
#         'category': 'Entity',
#         'data': {'name': 'TransformedRemisData',
#          'categoryMetadataIdentifier': 'TransformedRemisData',
#          'package': 'panda'}},
#        'children': {'TransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'TransformedRemisDataToMdmDataRuleRelation',
#           'category': 'Entity',
#           'data': {'name': 'TransformedRemisDataToMdmDataRuleRelation',
#            'categoryMetadataIdentifier': 'TransformedRemisDataToMdmDataRuleRelation',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmExcisionRule': {'node_info': {'id': 'MdmExcisionRule',
#           'category': 'Entity',
#           'data': {'name': 'MdmExcisionRule',
#            'categoryMetadataIdentifier': 'MdmExcisionRule',
#            'package': 'panda'}},
#          'children': {}},
#         'RawRemisData': {'node_info': {'id': 'RawRemisData',
#           'category': 'Entity',
#           'data': {'name': 'RawRemisData',
#            'categoryMetadataIdentifier': 'RawRemisData',
#            'package': 'panda'}},
#          'children': {}}}},
#       'MdmDatasetToTrdMapping': {'node_info': {'id': 'MdmDatasetToTrdMapping',
#         'category': 'Entity',
#         'data': {'name': 'MdmDatasetToTrdMapping',
#          'categoryMetadataIdentifier': 'MdmDatasetToTrdMapping',
#          'package': 'panda'}},
#        'children': {}},
#       'MdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'MdmDatasetToExcisionRuleMapping',
#         'category': 'Entity',
#         'data': {'name': 'MdmDatasetToExcisionRuleMapping',
#          'categoryMetadataIdentifier': 'MdmDatasetToExcisionRuleMapping',
#          'package': 'panda'}},
#        'children': {}}}}}}},
#  'MdmWucCorrectionRule': {'MdmWucCorrectionRule': {'node_info': {'id': 'MdmWucCorrectionRule',
#     'category': 'Entity',
#     'data': {'name': 'MdmWucCorrectionRule',
#      'categoryMetadataIdentifier': 'MdmWucCorrectionRule',
#      'package': 'panda'}},
#    'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#       'category': 'Entity',
#       'data': {'name': 'MdmDataset',
#        'categoryMetadataIdentifier': 'MdmDataset',
#        'package': 'panda'}},
#      'children': {'TransformedRemisData': {'node_info': {'id': 'TransformedRemisData',
#         'category': 'Entity',
#         'data': {'name': 'TransformedRemisData',
#          'categoryMetadataIdentifier': 'TransformedRemisData',
#          'package': 'panda'}},
#        'children': {'TransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'TransformedRemisDataToMdmDataRuleRelation',
#           'category': 'Entity',
#           'data': {'name': 'TransformedRemisDataToMdmDataRuleRelation',
#            'categoryMetadataIdentifier': 'TransformedRemisDataToMdmDataRuleRelation',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmExcisionRule': {'node_info': {'id': 'MdmExcisionRule',
#           'category': 'Entity',
#           'data': {'name': 'MdmExcisionRule',
#            'categoryMetadataIdentifier': 'MdmExcisionRule',
#            'package': 'panda'}},
#          'children': {}},
#         'RawRemisData': {'node_info': {'id': 'RawRemisData',
#           'category': 'Entity',
#           'data': {'name': 'RawRemisData',
#            'categoryMetadataIdentifier': 'RawRemisData',
#            'package': 'panda'}},
#          'children': {}}}},
#       'MdmDatasetToTrdMapping': {'node_info': {'id': 'MdmDatasetToTrdMapping',
#         'category': 'Entity',
#         'data': {'name': 'MdmDatasetToTrdMapping',
#          'categoryMetadataIdentifier': 'MdmDatasetToTrdMapping',
#          'package': 'panda'}},
#        'children': {}},
#       'MdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'MdmDatasetToExcisionRuleMapping',
#         'category': 'Entity',
#         'data': {'name': 'MdmDatasetToExcisionRuleMapping',
#          'categoryMetadataIdentifier': 'MdmDatasetToExcisionRuleMapping',
#          'package': 'panda'}},
#        'children': {}}}},
#     'WorkUnitCode': {'node_info': {'id': 'WorkUnitCode',
#       'category': 'Entity',
#       'data': {'name': 'WorkUnitCode',
#        'categoryMetadataIdentifier': 'WorkUnitCode',
#        'package': 'readiness'}},
#      'children': {'NsnToWucMapping': {'node_info': {'id': 'NsnToWucMapping',
#         'category': 'Entity',
#         'data': {'name': 'NsnToWucMapping',
#          'categoryMetadataIdentifier': 'NsnToWucMapping',
#          'package': 'panda'}},
#        'children': {'ReliabilityCaseSegment': {'node_info': {'id': 'ReliabilityCaseSegment',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityCaseSegment',
#            'categoryMetadataIdentifier': 'ReliabilityCaseSegment',
#            'package': 'panda'}},
#          'children': {}},
#         'Position': {'node_info': {'id': 'Position',
#           'category': 'Entity',
#           'data': {'name': 'Position',
#            'categoryMetadataIdentifier': 'Position',
#            'package': 'panda'}},
#          'children': {}},
#         'NationalStockNumber': {'node_info': {'id': 'NationalStockNumber',
#           'category': 'Entity',
#           'data': {'name': 'NationalStockNumber',
#            'categoryMetadataIdentifier': 'NationalStockNumber',
#            'package': 'readiness'}},
#          'children': {}},
#         'ReliabilityCase': {'node_info': {'id': 'ReliabilityCase',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityCase',
#            'categoryMetadataIdentifier': 'ReliabilityCase',
#            'package': 'panda'}},
#          'children': {}}}},
#       'AircraftModel': {'node_info': {'id': 'AircraftModel',
#         'category': 'Entity',
#         'data': {'name': 'AircraftModel',
#          'categoryMetadataIdentifier': 'AircraftModel',
#          'package': 'panda'}},
#        'children': {'PandaGroup': {'node_info': {'id': 'PandaGroup',
#           'category': 'Entity',
#           'data': {'name': 'PandaGroup',
#            'categoryMetadataIdentifier': 'PandaGroup',
#            'package': 'panda'}},
#          'children': {}},
#         'FlightHourForecast': {'node_info': {'id': 'FlightHourForecast',
#           'category': 'Entity',
#           'data': {'name': 'FlightHourForecast',
#            'categoryMetadataIdentifier': 'FlightHourForecast',
#            'package': 'panda'}},
#          'children': {}},
#         'Aircraft': {'node_info': {'id': 'Aircraft',
#           'category': 'Entity',
#           'data': {'name': 'Aircraft',
#            'categoryMetadataIdentifier': 'Aircraft',
#            'package': 'panda'}},
#          'children': {}},
#         'Majcom': {'node_info': {'id': 'Majcom',
#           'category': 'Entity',
#           'data': {'name': 'Majcom',
#            'categoryMetadataIdentifier': 'Majcom',
#            'package': 'readiness'}},
#          'children': {}},
#         'AssetClass': {'node_info': {'id': 'AssetClass',
#           'category': 'Entity',
#           'data': {'name': 'AssetClass',
#            'categoryMetadataIdentifier': 'AssetClass',
#            'package': 'reliabilityDataModel'}},
#          'children': {}},
#         'MonthlyPartsRemoved': {'node_info': {'id': 'MonthlyPartsRemoved',
#           'category': 'Entity',
#           'data': {'name': 'MonthlyPartsRemoved',
#            'categoryMetadataIdentifier': 'MonthlyPartsRemoved',
#            'package': 'panda'}},
#          'children': {}},
#         'PandaUser': {'node_info': {'id': 'PandaUser',
#           'category': 'Entity',
#           'data': {'name': 'PandaUser',
#            'categoryMetadataIdentifier': 'PandaUser',
#            'package': 'panda'}},
#          'children': {}},
#         'AircraftModelVariant': {'node_info': {'id': 'AircraftModelVariant',
#           'category': 'Entity',
#           'data': {'name': 'AircraftModelVariant',
#            'categoryMetadataIdentifier': 'AircraftModelVariant',
#            'package': 'panda'}},
#          'children': {}},
#         'UserAccessRequest': {'node_info': {'id': 'UserAccessRequest',
#           'category': 'Entity',
#           'data': {'name': 'UserAccessRequest',
#            'categoryMetadataIdentifier': 'UserAccessRequest',
#            'package': 'panda'}},
#          'children': {}}}},
#       'AircraftAsset': {'node_info': {'id': 'AircraftAsset',
#         'category': 'Entity',
#         'data': {'name': 'AircraftAsset',
#          'categoryMetadataIdentifier': 'AircraftAsset',
#          'package': 'panda'}},
#        'children': {'MaintenanceAction': {'node_info': {'id': 'MaintenanceAction',
#           'category': 'Entity',
#           'data': {'name': 'MaintenanceAction',
#            'categoryMetadataIdentifier': 'MaintenanceAction',
#            'package': 'readiness'}},
#          'children': {}}}},
#       'NationalItemIdentificationNumber': {'node_info': {'id': 'NationalItemIdentificationNumber',
#         'category': 'Entity',
#         'data': {'name': 'NationalItemIdentificationNumber',
#          'categoryMetadataIdentifier': 'NationalItemIdentificationNumber',
#          'package': 'panda'}},
#        'children': {'DeltaNiinDemandForecast': {'node_info': {'id': 'DeltaNiinDemandForecast',
#           'category': 'Entity',
#           'data': {'name': 'DeltaNiinDemandForecast',
#            'categoryMetadataIdentifier': 'DeltaNiinDemandForecast',
#            'package': 'panda'}},
#          'children': {}},
#         'CbmNiinDemandForecast': {'node_info': {'id': 'CbmNiinDemandForecast',
#           'category': 'Entity',
#           'data': {'name': 'CbmNiinDemandForecast',
#            'categoryMetadataIdentifier': 'CbmNiinDemandForecast',
#            'package': 'panda'}},
#          'children': {}},
#         'ExternalNiinDemandForecast': {'node_info': {'id': 'ExternalNiinDemandForecast',
#           'category': 'Entity',
#           'data': {'name': 'ExternalNiinDemandForecast',
#            'categoryMetadataIdentifier': 'ExternalNiinDemandForecast',
#            'package': 'panda'}},
#          'children': {}}}},
#       'WucToReliabilityCaseMapping': {'node_info': {'id': 'WucToReliabilityCaseMapping',
#         'category': 'Entity',
#         'data': {'name': 'WucToReliabilityCaseMapping',
#          'categoryMetadataIdentifier': 'WucToReliabilityCaseMapping',
#          'package': 'panda'}},
#        'children': {}}}}}}},
#  'RawRemisData': {'RawRemisData': {'node_info': {'id': 'RawRemisData',
#     'category': 'Entity',
#     'data': {'name': 'RawRemisData',
#      'categoryMetadataIdentifier': 'RawRemisData',
#      'package': 'panda'}},
#    'children': {'TransformedRemisData': {'node_info': {'id': 'TransformedRemisData',
#       'category': 'Entity',
#       'data': {'name': 'TransformedRemisData',
#        'categoryMetadataIdentifier': 'TransformedRemisData',
#        'package': 'panda'}},
#      'children': {'TransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'TransformedRemisDataToMdmDataRuleRelation',
#         'category': 'Entity',
#         'data': {'name': 'TransformedRemisDataToMdmDataRuleRelation',
#          'categoryMetadataIdentifier': 'TransformedRemisDataToMdmDataRuleRelation',
#          'package': 'panda'}},
#        'children': {'MdmDataRule': {'node_info': {'id': 'MdmDataRule',
#           'category': 'Entity',
#           'data': {'name': 'MdmDataRule',
#            'categoryMetadataIdentifier': 'MdmDataRule',
#            'package': 'panda'}},
#          'children': {}}}},
#       'MdmExcisionRule': {'node_info': {'id': 'MdmExcisionRule',
#         'category': 'Entity',
#         'data': {'name': 'MdmExcisionRule',
#          'categoryMetadataIdentifier': 'MdmExcisionRule',
#          'package': 'panda'}},
#        'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#           'category': 'Entity',
#           'data': {'name': 'MdmDataset',
#            'categoryMetadataIdentifier': 'MdmDataset',
#            'package': 'panda'}},
#          'children': {}}}}}}}}},
#  'MdmExcisionRule': {'MdmExcisionRule': {'node_info': {'id': 'MdmExcisionRule',
#     'category': 'Entity',
#     'data': {'name': 'MdmExcisionRule',
#      'categoryMetadataIdentifier': 'MdmExcisionRule',
#      'package': 'panda'}},
#    'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#       'category': 'Entity',
#       'data': {'name': 'MdmDataset',
#        'categoryMetadataIdentifier': 'MdmDataset',
#        'package': 'panda'}},
#      'children': {'TransformedRemisData': {'node_info': {'id': 'TransformedRemisData',
#         'category': 'Entity',
#         'data': {'name': 'TransformedRemisData',
#          'categoryMetadataIdentifier': 'TransformedRemisData',
#          'package': 'panda'}},
#        'children': {'TransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'TransformedRemisDataToMdmDataRuleRelation',
#           'category': 'Entity',
#           'data': {'name': 'TransformedRemisDataToMdmDataRuleRelation',
#            'categoryMetadataIdentifier': 'TransformedRemisDataToMdmDataRuleRelation',
#            'package': 'panda'}},
#          'children': {}},
#         'RawRemisData': {'node_info': {'id': 'RawRemisData',
#           'category': 'Entity',
#           'data': {'name': 'RawRemisData',
#            'categoryMetadataIdentifier': 'RawRemisData',
#            'package': 'panda'}},
#          'children': {}}}},
#       'MdmDatasetToTrdMapping': {'node_info': {'id': 'MdmDatasetToTrdMapping',
#         'category': 'Entity',
#         'data': {'name': 'MdmDatasetToTrdMapping',
#          'categoryMetadataIdentifier': 'MdmDatasetToTrdMapping',
#          'package': 'panda'}},
#        'children': {}},
#       'MdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'MdmDatasetToExcisionRuleMapping',
#         'category': 'Entity',
#         'data': {'name': 'MdmDatasetToExcisionRuleMapping',
#          'categoryMetadataIdentifier': 'MdmDatasetToExcisionRuleMapping',
#          'package': 'panda'}},
#        'children': {}}}}}}},
#  'MdmDataRuleVersion': {'MdmDataRuleVersion': {'node_info': {'id': 'MdmDataRuleVersion',
#     'category': 'Entity',
#     'data': {'name': 'MdmDataRuleVersion',
#      'categoryMetadataIdentifier': 'MdmDataRuleVersion',
#      'package': 'panda'}},
#    'children': {'PandaUser': {'node_info': {'id': 'PandaUser',
#       'category': 'Entity',
#       'data': {'name': 'PandaUser',
#        'categoryMetadataIdentifier': 'PandaUser',
#        'package': 'panda'}},
#      'children': {'User.Event.Login': {'node_info': {'id': 'User.Event.Login',
#         'category': 'Entity',
#         'data': {'name': 'User.Event.Login',
#          'categoryMetadataIdentifier': 'User.Event.Login',
#          'package': 'platform'}},
#        'children': {}},
#       'PandaGroup': {'node_info': {'id': 'PandaGroup',
#         'category': 'Entity',
#         'data': {'name': 'PandaGroup',
#          'categoryMetadataIdentifier': 'PandaGroup',
#          'package': 'panda'}},
#        'children': {'UserGroup': {'node_info': {'id': 'UserGroup',
#           'category': 'Entity',
#           'data': {'name': 'UserGroup',
#            'categoryMetadataIdentifier': 'UserGroup',
#            'package': 'platform'}},
#          'children': {}},
#         'AircraftModel': {'node_info': {'id': 'AircraftModel',
#           'category': 'Entity',
#           'data': {'name': 'AircraftModel',
#            'categoryMetadataIdentifier': 'AircraftModel',
#            'package': 'panda'}},
#          'children': {}},
#         'UserAccessRequest': {'node_info': {'id': 'UserAccessRequest',
#           'category': 'Entity',
#           'data': {'name': 'UserAccessRequest',
#            'categoryMetadataIdentifier': 'UserAccessRequest',
#            'package': 'panda'}},
#          'children': {}},
#         'AirBase': {'node_info': {'id': 'AirBase',
#           'category': 'Entity',
#           'data': {'name': 'AirBase',
#            'categoryMetadataIdentifier': 'AirBase',
#            'package': 'panda'}},
#          'children': {}}}},
#       'ReliabilityCase': {'node_info': {'id': 'ReliabilityCase',
#         'category': 'Entity',
#         'data': {'name': 'ReliabilityCase',
#          'categoryMetadataIdentifier': 'ReliabilityCase',
#          'package': 'panda'}},
#        'children': {'SplitSpec': {'node_info': {'id': 'SplitSpec',
#           'category': 'Entity',
#           'data': {'name': 'SplitSpec',
#            'categoryMetadataIdentifier': 'SplitSpec',
#            'package': 'panda'}},
#          'children': {}},
#         'PositionToReliabilityCaseMapping': {'node_info': {'id': 'PositionToReliabilityCaseMapping',
#           'category': 'Entity',
#           'data': {'name': 'PositionToReliabilityCaseMapping',
#            'categoryMetadataIdentifier': 'PositionToReliabilityCaseMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'WorkUnitCode': {'node_info': {'id': 'WorkUnitCode',
#           'category': 'Entity',
#           'data': {'name': 'WorkUnitCode',
#            'categoryMetadataIdentifier': 'WorkUnitCode',
#            'package': 'readiness'}},
#          'children': {}},
#         'AircraftAsset': {'node_info': {'id': 'AircraftAsset',
#           'category': 'Entity',
#           'data': {'name': 'AircraftAsset',
#            'categoryMetadataIdentifier': 'AircraftAsset',
#            'package': 'panda'}},
#          'children': {}},
#         'ForecastedAircraftPart': {'node_info': {'id': 'ForecastedAircraftPart',
#           'category': 'Entity',
#           'data': {'name': 'ForecastedAircraftPart',
#            'categoryMetadataIdentifier': 'ForecastedAircraftPart',
#            'package': 'panda'}},
#          'children': {}},
#         'PandaMlMetadata': {'node_info': {'id': 'PandaMlMetadata',
#           'category': 'Entity',
#           'data': {'name': 'PandaMlMetadata',
#            'categoryMetadataIdentifier': 'PandaMlMetadata',
#            'package': 'panda'}},
#          'children': {}},
#         'ReliabilityCaseSegment': {'node_info': {'id': 'ReliabilityCaseSegment',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityCaseSegment',
#            'categoryMetadataIdentifier': 'ReliabilityCaseSegment',
#            'package': 'panda'}},
#          'children': {}},
#         'LabeledMaintenanceAction': {'node_info': {'id': 'LabeledMaintenanceAction',
#           'category': 'Entity',
#           'data': {'name': 'LabeledMaintenanceAction',
#            'categoryMetadataIdentifier': 'LabeledMaintenanceAction',
#            'package': 'panda'}},
#          'children': {}},
#         'WucToReliabilityCaseMapping': {'node_info': {'id': 'WucToReliabilityCaseMapping',
#           'category': 'Entity',
#           'data': {'name': 'WucToReliabilityCaseMapping',
#            'categoryMetadataIdentifier': 'WucToReliabilityCaseMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'Position': {'node_info': {'id': 'Position',
#           'category': 'Entity',
#           'data': {'name': 'Position',
#            'categoryMetadataIdentifier': 'Position',
#            'package': 'panda'}},
#          'children': {}},
#         'NationalStockNumber': {'node_info': {'id': 'NationalStockNumber',
#           'category': 'Entity',
#           'data': {'name': 'NationalStockNumber',
#            'categoryMetadataIdentifier': 'NationalStockNumber',
#            'package': 'readiness'}},
#          'children': {}},
#         'LabeledMaintenanceEvent': {'node_info': {'id': 'LabeledMaintenanceEvent',
#           'category': 'Entity',
#           'data': {'name': 'LabeledMaintenanceEvent',
#            'categoryMetadataIdentifier': 'LabeledMaintenanceEvent',
#            'package': 'panda'}},
#          'children': {}},
#         'AircraftAssetMaintenanceRecommendation': {'node_info': {'id': 'AircraftAssetMaintenanceRecommendation',
#           'category': 'Entity',
#           'data': {'name': 'AircraftAssetMaintenanceRecommendation',
#            'categoryMetadataIdentifier': 'AircraftAssetMaintenanceRecommendation',
#            'package': 'panda'}},
#          'children': {}}}},
#       'UserAircraftAssetMaintenanceRecommendationRelation': {'node_info': {'id': 'UserAircraftAssetMaintenanceRecommendationRelation',
#         'category': 'Entity',
#         'data': {'name': 'UserAircraftAssetMaintenanceRecommendationRelation',
#          'categoryMetadataIdentifier': 'UserAircraftAssetMaintenanceRecommendationRelation',
#          'package': 'panda'}},
#        'children': {}},
#       'Majcom': {'node_info': {'id': 'Majcom',
#         'category': 'Entity',
#         'data': {'name': 'Majcom',
#          'categoryMetadataIdentifier': 'Majcom',
#          'package': 'readiness'}},
#        'children': {'ReliabilityAsset': {'node_info': {'id': 'ReliabilityAsset',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityAsset',
#            'categoryMetadataIdentifier': 'ReliabilityAsset',
#            'package': 'reliabilityDataModel'}},
#          'children': {}},
#         'UsafOrganization': {'node_info': {'id': 'UsafOrganization',
#           'category': 'Entity',
#           'data': {'name': 'UsafOrganization',
#            'categoryMetadataIdentifier': 'UsafOrganization',
#            'package': 'panda'}},
#          'children': {}},
#         'FlightHourForecast': {'node_info': {'id': 'FlightHourForecast',
#           'category': 'Entity',
#           'data': {'name': 'FlightHourForecast',
#            'categoryMetadataIdentifier': 'FlightHourForecast',
#            'package': 'panda'}},
#          'children': {}}}},
#       'User': {'node_info': {'id': 'User',
#         'category': 'Entity',
#         'data': {'name': 'User',
#          'categoryMetadataIdentifier': 'User',
#          'package': 'platform'}},
#        'children': {}},
#       'PandaUserStatusHistory': {'node_info': {'id': 'PandaUserStatusHistory',
#         'category': 'Entity',
#         'data': {'name': 'PandaUserStatusHistory',
#          'categoryMetadataIdentifier': 'PandaUserStatusHistory',
#          'package': 'panda'}},
#        'children': {}},
#       'PandaRole': {'node_info': {'id': 'PandaRole',
#         'category': 'Entity',
#         'data': {'name': 'PandaRole',
#          'categoryMetadataIdentifier': 'PandaRole',
#          'package': 'panda'}},
#        'children': {}}}},
#     'MdmDataRule': {'node_info': {'id': 'MdmDataRule',
#       'category': 'Entity',
#       'data': {'name': 'MdmDataRule',
#        'categoryMetadataIdentifier': 'MdmDataRule',
#        'package': 'panda'}},
#      'children': {'TransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'TransformedRemisDataToMdmDataRuleRelation',
#         'category': 'Entity',
#         'data': {'name': 'TransformedRemisDataToMdmDataRuleRelation',
#          'categoryMetadataIdentifier': 'TransformedRemisDataToMdmDataRuleRelation',
#          'package': 'panda'}},
#        'children': {'TransformedRemisData': {'node_info': {'id': 'TransformedRemisData',
#           'category': 'Entity',
#           'data': {'name': 'TransformedRemisData',
#            'categoryMetadataIdentifier': 'TransformedRemisData',
#            'package': 'panda'}},
#          'children': {}}}},
#       'SandboxTransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#         'category': 'Entity',
#         'data': {'name': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#          'categoryMetadataIdentifier': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#          'package': 'panda'}},
#        'children': {'SandboxTransformedRemisData': {'node_info': {'id': 'SandboxTransformedRemisData',
#           'category': 'Entity',
#           'data': {'name': 'SandboxTransformedRemisData',
#            'categoryMetadataIdentifier': 'SandboxTransformedRemisData',
#            'package': 'panda'}},
#          'children': {}}}}}}}}},
#  'TransformedRemisData': {'TransformedRemisData': {'node_info': {'id': 'TransformedRemisData',
#     'category': 'Entity',
#     'data': {'name': 'TransformedRemisData',
#      'categoryMetadataIdentifier': 'TransformedRemisData',
#      'package': 'panda'}},
#    'children': {'TransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'TransformedRemisDataToMdmDataRuleRelation',
#       'category': 'Entity',
#       'data': {'name': 'TransformedRemisDataToMdmDataRuleRelation',
#        'categoryMetadataIdentifier': 'TransformedRemisDataToMdmDataRuleRelation',
#        'package': 'panda'}},
#      'children': {'MdmDataRule': {'node_info': {'id': 'MdmDataRule',
#         'category': 'Entity',
#         'data': {'name': 'MdmDataRule',
#          'categoryMetadataIdentifier': 'MdmDataRule',
#          'package': 'panda'}},
#        'children': {'SandboxTransformedRemisDataToMdmDataRuleRelation': {'node_info': {'id': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#           'category': 'Entity',
#           'data': {'name': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#            'categoryMetadataIdentifier': 'SandboxTransformedRemisDataToMdmDataRuleRelation',
#            'package': 'panda'}},
#          'children': {}},
#         'AircraftModel': {'node_info': {'id': 'AircraftModel',
#           'category': 'Entity',
#           'data': {'name': 'AircraftModel',
#            'categoryMetadataIdentifier': 'AircraftModel',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmDataRuleVersion': {'node_info': {'id': 'MdmDataRuleVersion',
#           'category': 'Entity',
#           'data': {'name': 'MdmDataRuleVersion',
#            'categoryMetadataIdentifier': 'MdmDataRuleVersion',
#            'package': 'panda'}},
#          'children': {}}}}}},
#     'MdmExcisionRule': {'node_info': {'id': 'MdmExcisionRule',
#       'category': 'Entity',
#       'data': {'name': 'MdmExcisionRule',
#        'categoryMetadataIdentifier': 'MdmExcisionRule',
#        'package': 'panda'}},
#      'children': {'MdmDataset': {'node_info': {'id': 'MdmDataset',
#         'category': 'Entity',
#         'data': {'name': 'MdmDataset',
#          'categoryMetadataIdentifier': 'MdmDataset',
#          'package': 'panda'}},
#        'children': {'MdmDatasetToTrdMapping': {'node_info': {'id': 'MdmDatasetToTrdMapping',
#           'category': 'Entity',
#           'data': {'name': 'MdmDatasetToTrdMapping',
#            'categoryMetadataIdentifier': 'MdmDatasetToTrdMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'MdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'MdmDatasetToExcisionRuleMapping',
#           'category': 'Entity',
#           'data': {'name': 'MdmDatasetToExcisionRuleMapping',
#            'categoryMetadataIdentifier': 'MdmDatasetToExcisionRuleMapping',
#            'package': 'panda'}},
#          'children': {}}}}}},
#     'RawRemisData': {'node_info': {'id': 'RawRemisData',
#       'category': 'Entity',
#       'data': {'name': 'RawRemisData',
#        'categoryMetadataIdentifier': 'RawRemisData',
#        'package': 'panda'}},
#      'children': {}}}}},
#  'MdmDatasetToExcisionRuleMapping': {'MdmDatasetToExcisionRuleMapping': {'node_info': {'id': 'MdmDatasetToExcisionRuleMapping',
#     'category': 'Entity',
#     'data': {'name': 'MdmDatasetToExcisionRuleMapping',
#      'categoryMetadataIdentifier': 'MdmDatasetToExcisionRuleMapping',
# ...
#            'categoryMetadataIdentifier': 'FlightHourForecast',
#            'package': 'panda'}},
#          'children': {}}}},
#       'User': {'node_info': {'id': 'User',
#         'category': 'Entity',
#         'data': {'name': 'User',
#          'categoryMetadataIdentifier': 'User',
#          'package': 'platform'}},
#        'children': {}},
#       'PandaUserStatusHistory': {'node_info': {'id': 'PandaUserStatusHistory',
#         'category': 'Entity',
#         'data': {'name': 'PandaUserStatusHistory',
#          'categoryMetadataIdentifier': 'PandaUserStatusHistory',
#          'package': 'panda'}},
#        'children': {}},
#       'PandaRole': {'node_info': {'id': 'PandaRole',
#         'category': 'Entity',
#         'data': {'name': 'PandaRole',
#          'categoryMetadataIdentifier': 'PandaRole',
#          'package': 'panda'}},
#        'children': {}}}}}}},
#  'WorkOrderPartsDenormalized': {'WorkOrderPartsDenormalized': {'node_info': {'id': 'WorkOrderPartsDenormalized',
#     'category': 'Entity',
#     'data': {'name': 'WorkOrderPartsDenormalized',
#      'categoryMetadataIdentifier': 'WorkOrderPartsDenormalized',
#      'package': 'reliabilityDataModel'}},
#    'children': {'WorkOrder': {'node_info': {'id': 'WorkOrder',
#       'category': 'Entity',
#       'data': {'name': 'WorkOrder',
#        'categoryMetadataIdentifier': 'WorkOrder',
#        'package': 'facility'}},
#      'children': {'WorkUnitCode': {'node_info': {'id': 'WorkUnitCode',
#         'category': 'Entity',
#         'data': {'name': 'WorkUnitCode',
#          'categoryMetadataIdentifier': 'WorkUnitCode',
#          'package': 'readiness'}},
#        'children': {'NsnToWucMapping': {'node_info': {'id': 'NsnToWucMapping',
#           'category': 'Entity',
#           'data': {'name': 'NsnToWucMapping',
#            'categoryMetadataIdentifier': 'NsnToWucMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'AircraftModel': {'node_info': {'id': 'AircraftModel',
#           'category': 'Entity',
#           'data': {'name': 'AircraftModel',
#            'categoryMetadataIdentifier': 'AircraftModel',
#            'package': 'panda'}},
#          'children': {}},
#         'AircraftAsset': {'node_info': {'id': 'AircraftAsset',
#           'category': 'Entity',
#           'data': {'name': 'AircraftAsset',
#            'categoryMetadataIdentifier': 'AircraftAsset',
#            'package': 'panda'}},
#          'children': {}},
#         'ReliabilityCase': {'node_info': {'id': 'ReliabilityCase',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityCase',
#            'categoryMetadataIdentifier': 'ReliabilityCase',
#            'package': 'panda'}},
#          'children': {}},
#         'NationalItemIdentificationNumber': {'node_info': {'id': 'NationalItemIdentificationNumber',
#           'category': 'Entity',
#           'data': {'name': 'NationalItemIdentificationNumber',
#            'categoryMetadataIdentifier': 'NationalItemIdentificationNumber',
#            'package': 'panda'}},
#          'children': {}},
#         'WucToReliabilityCaseMapping': {'node_info': {'id': 'WucToReliabilityCaseMapping',
#           'category': 'Entity',
#           'data': {'name': 'WucToReliabilityCaseMapping',
#            'categoryMetadataIdentifier': 'WucToReliabilityCaseMapping',
#            'package': 'panda'}},
#          'children': {}},
#         'NationalStockNumber': {'node_info': {'id': 'NationalStockNumber',
#           'category': 'Entity',
#           'data': {'name': 'NationalStockNumber',
#            'categoryMetadataIdentifier': 'NationalStockNumber',
#            'package': 'readiness'}},
#          'children': {}},
#         'MaintenanceAction': {'node_info': {'id': 'MaintenanceAction',
#           'category': 'Entity',
#           'data': {'name': 'MaintenanceAction',
#            'categoryMetadataIdentifier': 'MaintenanceAction',
#            'package': 'readiness'}},
#          'children': {}}}},
#       'ReliabilityAssetCase': {'node_info': {'id': 'ReliabilityAssetCase',
#         'category': 'Entity',
#         'data': {'name': 'ReliabilityAssetCase',
#          'categoryMetadataIdentifier': 'ReliabilityAssetCase',
#          'package': 'reliabilityAssetCase'}},
#        'children': {'ReliabilityAsset': {'node_info': {'id': 'ReliabilityAsset',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityAsset',
#            'categoryMetadataIdentifier': 'ReliabilityAsset',
#            'package': 'reliabilityDataModel'}},
#          'children': {}},
#         'ReadinessAssetAlertToCaseRelation': {'node_info': {'id': 'ReadinessAssetAlertToCaseRelation',
#           'category': 'Entity',
#           'data': {'name': 'ReadinessAssetAlertToCaseRelation',
#            'categoryMetadataIdentifier': 'ReadinessAssetAlertToCaseRelation',
#            'package': 'readiness'}},
#          'children': {}},
#         'ReadinessAssetAlert': {'node_info': {'id': 'ReadinessAssetAlert',
#           'category': 'Entity',
#           'data': {'name': 'ReadinessAssetAlert',
#            'categoryMetadataIdentifier': 'ReadinessAssetAlert',
#            'package': 'readiness'}},
#          'children': {}},
#         'ReliabilityAssetAlertToCaseRelation': {'node_info': {'id': 'ReliabilityAssetAlertToCaseRelation',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityAssetAlertToCaseRelation',
#            'categoryMetadataIdentifier': 'ReliabilityAssetAlertToCaseRelation',
#            'package': 'reliabilityAssetCase'}},
#          'children': {}},
#         'CaseAssigneeHistory': {'node_info': {'id': 'CaseAssigneeHistory',
#           'category': 'Entity',
#           'data': {'name': 'CaseAssigneeHistory',
#            'categoryMetadataIdentifier': 'CaseAssigneeHistory',
#            'package': 'reliabilityAssetCase'}},
#          'children': {}},
#         'CaseComment': {'node_info': {'id': 'CaseComment',
#           'category': 'Entity',
#           'data': {'name': 'CaseComment',
#            'categoryMetadataIdentifier': 'CaseComment',
#            'package': 'reliabilityAssetCase'}},
#          'children': {}},
#         'MxEffort': {'node_info': {'id': 'MxEffort',
#           'category': 'Entity',
#           'data': {'name': 'MxEffort',
#            'categoryMetadataIdentifier': 'MxEffort',
#            'package': 'maintenanceEffort'}},
#          'children': {}},
#         'ReliabilityAssetCaseToAssetRelation': {'node_info': {'id': 'ReliabilityAssetCaseToAssetRelation',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityAssetCaseToAssetRelation',
#            'categoryMetadataIdentifier': 'ReliabilityAssetCaseToAssetRelation',
#            'package': 'reliabilityAssetCase'}},
#          'children': {}},
#         'ReadinessAssetPositionToFailureModeRelation': {'node_info': {'id': 'ReadinessAssetPositionToFailureModeRelation',
#           'category': 'Entity',
#           'data': {'name': 'ReadinessAssetPositionToFailureModeRelation',
#            'categoryMetadataIdentifier': 'ReadinessAssetPositionToFailureModeRelation',
#            'package': 'readiness'}},
#          'children': {}},
#         'ReliabilityAssetAlert': {'node_info': {'id': 'ReliabilityAssetAlert',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityAssetAlert',
#            'categoryMetadataIdentifier': 'ReliabilityAssetAlert',
#            'package': 'reliabilityMl'}},
#          'children': {}},
#         'CaseToPartQuantityRelation': {'node_info': {'id': 'CaseToPartQuantityRelation',
#           'category': 'Entity',
#           'data': {'name': 'CaseToPartQuantityRelation',
#            'categoryMetadataIdentifier': 'CaseToPartQuantityRelation',
#            'package': 'readiness'}},
#          'children': {}},
#         'CasePriorityHistory': {'node_info': {'id': 'CasePriorityHistory',
#           'category': 'Entity',
#           'data': {'name': 'CasePriorityHistory',
#            'categoryMetadataIdentifier': 'CasePriorityHistory',
#            'package': 'reliabilityAssetCase'}},
#          'children': {}},
#         'AssetClass': {'node_info': {'id': 'AssetClass',
#           'category': 'Entity',
#           'data': {'name': 'AssetClass',
#            'categoryMetadataIdentifier': 'AssetClass',
#            'package': 'reliabilityDataModel'}},
#          'children': {}},
#         'ReliabilityAssetCaseUpdateHistory': {'node_info': {'id': 'ReliabilityAssetCaseUpdateHistory',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityAssetCaseUpdateHistory',
#            'categoryMetadataIdentifier': 'ReliabilityAssetCaseUpdateHistory',
#            'package': 'readiness'}},
#          'children': {}},
#         'ReliabilityAssetCaseFailureModeRelation': {'node_info': {'id': 'ReliabilityAssetCaseFailureModeRelation',
#           'category': 'Entity',
#           'data': {'name': 'ReliabilityAssetCaseFailureModeRelation',
#            'categoryMetadataIdentifier': 'ReliabilityAssetCaseFailureModeRelation',
#            'package': 'reliabilityAssetCase'}},
#          'children': {}},
#         'Facility': {'node_info': {'id': 'Facility',
#           'category': 'Entity',
#           'data': {'name': 'Facility',
#            'categoryMetadataIdentifier': 'Facility',
#            'package': 'facility'}},
#          'children': {}}}},
#       'WorkOrderPartsSimilarityPredictions': {'node_info': {'id': 'WorkOrderPartsSimilarityPredictions',
#         'category': 'Entity',
#         'data': {'name': 'WorkOrderPartsSimilarityPredictions',
#          'categoryMetadataIdentifier': 'WorkOrderPartsSimilarityPredictions',
#          'package': 'reliabilityDataModel'}},
#        'children': {'InventorySeries': {'node_info': {'id': 'InventorySeries',
#           'category': 'Entity',
#           'data': {'name': 'InventorySeries',
#            'categoryMetadataIdentifier': 'InventorySeries',
#            'package': 'reliabilityDataModel'}},
#          'children': {}}}},
#       'Customer': {'node_info': {'id': 'Customer',
#         'category': 'Entity',
#         'data': {'name': 'Customer',
#          'categoryMetadataIdentifier': 'Customer',
#          'package': 'party'}},
#        'children': {}},
#       'Organization': {'node_info': {'id': 'Organization',
#         'category': 'Entity',
#         'data': {'name': 'Organization',
#          'categoryMetadataIdentifier': 'Organization',
#          'package': 'party'}},
#        'children': {'OrganizationHierarchyDenorm': {'node_info': {'id': 'OrganizationHierarchyDenorm',
#           'category': 'Entity',
#           'data': {'name': 'OrganizationHierarchyDenorm',
#            'categoryMetadataIdentifier': 'OrganizationHierarchyDenorm',
#            'package': 'party'}},
#          'children': {}},
#         'OrganizationSegment': {'node_info': {'id': 'OrganizationSegment',
#           'category': 'Entity',
#           'data': {'name': 'OrganizationSegment',
#            'categoryMetadataIdentifier': 'OrganizationSegment',
#            'package': 'party'}},
#          'children': {}},
#         'OrganizationRollup': {'node_info': {'id': 'OrganizationRollup',
#           'category': 'Entity',
#           'data': {'name': 'OrganizationRollup',
#            'categoryMetadataIdentifier': 'OrganizationRollup',
#            'package': 'party'}},
#          'children': {}},
#         'PersonOrganizationRelation': {'node_info': {'id': 'PersonOrganizationRelation',
#           'category': 'Entity',
#           'data': {'name': 'PersonOrganizationRelation',
#            'categoryMetadataIdentifier': 'PersonOrganizationRelation',
#            'package': 'party'}},
#          'children': {}},
#         'OrganizationCharacteristicSet': {'node_info': {'id': 'OrganizationCharacteristicSet',
#           'category': 'Entity',
#           'data': {'name': 'OrganizationCharacteristicSet',
#            'categoryMetadataIdentifier': 'OrganizationCharacteristicSet',
#            'package': 'party'}},
#          'children': {}},
#         'CustomerRelation': {'node_info': {'id': 'CustomerRelation',
#           'category': 'Entity',
#           'data': {'name': 'CustomerRelation',
#            'categoryMetadataIdentifier': 'CustomerRelation',
#            'package': 'party'}},
#          'children': {}},
#         'Country': {'node_info': {'id': 'Country',
#           'category': 'Entity',
#           'data': {'name': 'Country',
#            'categoryMetadataIdentifier': 'Country',
#            'package': 'location'}},
#          'children': {}}}},
#       'FixedAsset': {'node_info': {'id': 'FixedAsset',
#         'category': 'Entity',
#         'data': {'name': 'FixedAsset',
#          'categoryMetadataIdentifier': 'FixedAsset',
#          'package': 'facility'}},
#        'children': {'AssetOwner': {'node_info': {'id': 'AssetOwner',
#           'category': 'Entity',
#           'data': {'name': 'AssetOwner',
#            'categoryMetadataIdentifier': 'AssetOwner',
#            'package': 'assetOwner'}},
#          'children': {}},
#         'Region': {'node_info': {'id': 'Region',
#           'category': 'Entity',
#           'data': {'name': 'Region',
#            'categoryMetadataIdentifier': 'Region',
#            'package': 'location'}},
#          'children': {}},
#         'PartyRole': {'node_info': {'id': 'PartyRole',
#           'category': 'Entity',
#           'data': {'name': 'PartyRole',
#            'categoryMetadataIdentifier': 'PartyRole',
#            'package': 'party'}},
#          'children': {}},
#         'AssetPartyRole': {'node_info': {'id': 'AssetPartyRole',
#           'category': 'Entity',
#           'data': {'name': 'AssetPartyRole',
#            'categoryMetadataIdentifier': 'AssetPartyRole',
#            'package': 'assetOwner'}},
#          'children': {}},
#         'AssetHierarchyDenorm': {'node_info': {'id': 'AssetHierarchyDenorm',
#           'category': 'Entity',
#           'data': {'name': 'AssetHierarchyDenorm',
#            'categoryMetadataIdentifier': 'AssetHierarchyDenorm',
#            'package': 'facility'}},
#          'children': {}},
#         'Location': {'node_info': {'id': 'Location',
#           'category': 'Entity',
#           'data': {'name': 'Location',
#            'categoryMetadataIdentifier': 'Location',
#            'package': 'location'}},
#          'children': {}}}},
#       'WorkOrderSimilarityPredictions': {'node_info': {'id': 'WorkOrderSimilarityPredictions',
#         'category': 'Entity',
#         'data': {'name': 'WorkOrderSimilarityPredictions',
#          'categoryMetadataIdentifier': 'WorkOrderSimilarityPredictions',
#          'package': 'reliabilityDataModel'}},
#        'children': {}},
#       'Person': {'node_info': {'id': 'Person',
#         'category': 'Entity',
#         'data': {'name': 'Person',
#          'categoryMetadataIdentifier': 'Person',
#          'package': 'party'}},
#        'children': {'PersonUser': {'node_info': {'id': 'PersonUser',
#           'category': 'Entity',
#           'data': {'name': 'PersonUser',
#            'categoryMetadataIdentifier': 'PersonUser',
#            'package': 'party'}},
#          'children': {}},
#         'Member': {'node_info': {'id': 'Member',
#           'category': 'Entity',
#           'data': {'name': 'Member',
#            'categoryMetadataIdentifier': 'Member',
#            'package': 'platform'}},
#          'children': {}},
#         'Contact': {'node_info': {'id': 'Contact',
#           'category': 'Entity',
#           'data': {'name': 'Contact',
#            'categoryMetadataIdentifier': 'Contact',
#            'package': 'party'}},
#          'children': {}}}},
#       'User': {'node_info': {'id': 'User',
#         'category': 'Entity',
#         'data': {'name': 'User',
#          'categoryMetadataIdentifier': 'User',
#          'package': 'platform'}},
#        'children': {'UserGroup': {'node_info': {'id': 'UserGroup',
#           'category': 'Entity',
#           'data': {'name': 'UserGroup',
#            'categoryMetadataIdentifier': 'UserGroup',
#            'package': 'platform'}},
#          'children': {}}}},
#       'WorkItem': {'node_info': {'id': 'WorkItem',
#         'category': 'Entity',
#         'data': {'name': 'WorkItem',
#          'categoryMetadataIdentifier': 'WorkItem',
#          'package': 'facility'}},
#        'children': {}},
#       'Item': {'node_info': {'id': 'Item',
#         'category': 'Entity',
#         'data': {'name': 'Item',
#          'categoryMetadataIdentifier': 'Item',
#          'package': 'item'}},
#        'children': {}}}}}}}}

# %%
top_nodes_with_counts = [(node, count_descendants(node, adj_list)) for node in top_nodes]

# %%
top_nodes_with_counts
# Out:
# [('SandboxMdmDatasetToExcisionRuleMapping', 267),
#  ('SandboxMdmDataset', 267),
#  ('SandboxMdmDatasetToTrdMapping', 267),
#  ('WucToMdmWucCorrectionRulesMapping', 265),
#  ('MdmTrdExcRuleJob', 264),
#  ('MdmGetTrdsAndExcRulesJob', 264),
#  ('MdmWucCorrectionRule', 264),
#  ('RawRemisData', 263),
#  ('MdmExcisionRule', 263),
#  ('MdmDataRuleVersion', 263),
#  ('TransformedRemisData', 263),
#  ('MdmDatasetToExcisionRuleMapping', 263),
#  ('MdmDataset', 263),
#  ('SandboxTransformedRemisDataToMdmDataRuleRelation', 263),
#  ('MdmDataRule', 263),
#  ('SandboxRawRemisData', 263),
#  ('TransformedRemisDataToMdmDataRuleRelation', 263),
#  ('MdmDatasetToTrdMapping', 263),
#  ('SandboxTransformedRemisData', 263),
#  ('SandboxSampleFile', 251),
#  ('ProtectionLoop', 250),
#  ('OperationFileTracker', 250),
#  ('ProtectionLoopSensorRelation', 250),
#  ('ProtectionLoopAlert', 250),
#  ('FailureRecommendationRelation', 249),
#  ('CommentBoard', 249),
#  ('PandaMail', 249),
#  ('CommentBoardReply', 249),
#  ('ReadinessRiskInferenceLog', 249),
#  ('ReliabilityAssetClassDefinitionParserJobBatchResult', 249),
#  ('ReliabilityAssetClassDefinitionParserJob', 249),
#  ('FailureModeRelation', 249),
#  ('MasterSensor', 248),
#  ('MaintenanceDataSourceSpec', 248),
#  ('FacilityReliabilityAssetRelation', 248),
#  ('TypeMetaDocGetterSampleType', 248),
#  ('AircraftAssetMaintenanceRecommendationAlert', 248),
#  ('ReliabilityAssetRiskAlert', 248),
#  ('MeasurementSeries', 248),
#  ('ReliabilityModelRegistry.TargetEntry', 248),
#  ('ModelConfigCachedHyperparams', 248),
#  ('TimeBoundAlertMetric', 248),
#  ('ReadinessRiskInferenceJob', 248),
#  ('ReliabilityAssetAlertBase', 248),
#  ('LMEChangeHistory', 248),
#  ('DataConfiguration', 248),
#  ('CreateLabeledMaintenanceJob', 248),
#  ('FixedAssetHierarchyRelation', 248),
#  ('AnalysisWorkflowStateHistory', 248),
#  ('WorkOrderPartsDenormalized', 248)]

# %%
hierarchy, top_nodes = transform_graph(graph_data, 3, 50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 hierarchy, top_nodes = transform_graph(graph_data, max_depth, top_n)
#
# NameError: name 'max_depth' is not defined

# %%
from datetime import datetime
name = f"realGraph_.json"

# %%
time_name = str(datetime.now()).split(" ")[1]

# %%
output_file = f"realGraph_{time_name}.json"

# %%
def _do_generate_type_graph(output_file=output_file, analyze=False, js_code=None):
    """Generate a type graph from MCLI and optionally save/analyze it.
    
    Args:
        output_file: File to save the graph to (optional)
        analyze: Whether to analyze the graph after generating it
        js_code: Optional JavaScript code to execute instead of default graph generation
    
    Returns:
        Path to the saved graph file if saved, None otherwise
    """
    try:
        
        mcli_mngr = MCLIManager(env_url="https://stgawsrso.mcli.ai/lefvdev/panda009")
        mcli = mcli_mngr.mcli_as_basic_user()
        
        # Default JavaScript code to execute if none is provided
        if js_code is None:
            js_code = """
            var realGraph = GlobalCanvasCommonGraphUtil.mergeGraphs([
              {
                action: {
                  actionName: 'relationshipGraph',
                  typeName: 'DataModelGraphManager',
                },
                id: 'DataModelGraphRegistration',
                type: 'GlobalCanvasGraphRegistration',
              },
            ], [{
                id: 'Entity',
              }]);
            realGraph;  // Return the result
            """
            logger.info("Using default JavaScript code to generate graph")
        else:
            logger.info("Using custom JavaScript code to generate graph")
        
        logger.info("Executing JavaScript to generate graph...")
        merged_graph = mcli.Js.exec(js_code)
        if not merged_graph.graph:
            logger.error("JavaScript execution returned no data")
            raise ValueError("JavaScript execution returned no data")
            
        # Get basic statistics about the graph
        num_vertices = len(merged_graph.graph.m_vertices)
        num_edges = len(merged_graph.graph.m_edges)
        logger.info(f"Merged graph contains {num_vertices} vertices and {num_edges} edges")
        
        if output_file:
            # Make sure the parent directory exists
            output_path = Path(output_file)
            if not output_path.parent.exists():
                output_path.parent.mkdir(parents=True, exist_ok=True)
                logger.info(f"Created parent directory for output file: {output_path.parent}")
                
            # Save the graph to a file
            try:
                with open(output_file, 'w') as f:
                    json.dump(merged_graph.toJson(), f, indent=2)
                logger.info(f"Saved graph to {output_file}")
                
                if analyze:
                    # Analyze the graph
                    logger.info(f"Analyzing graph for hierarchical exports")
                    results = analyze_graph_for_hierarchical_exports(output_file)
                    
                    if results:
                        logger.info(f"Top 5 nodes by descendant count:")
                        for node in results:
                            logger.info(f"{node['id']} - {node['descendant_count']} descendants")
                    else:
                        logger.warning("No top nodes found in the graph.")
                        
                return output_file
            except Exception as e:
                logger.error(f"Error saving graph: {e}")
                raise
        
        return merged_graph
    except Exception as e:
        logger.error(f"Error in _do_generate_type_graph: {e}")
        import traceback
        logger.error(f"Traceback: {traceback.format_exc()}")
        raise

# %%
files = generate_erd_for_top_nodes("realGraph.json", max_depth=3, top_n=50)

# %%
files
# Out:
# []

# %%
  node_map, adj_list = build_adjacency_list(graph_data)

# %%
# Count descendants for each node
descendant_counts = {}
for node_id in node_map:
    descendant_counts[node_id] = count_descendants(node_id, adj_list)

# %%
descendant_counts
# Out:
# {'CaseCommentAttachment': 1,
#  'FailureRecommendationRelation': 249,
#  'DataValidationRuleset': 3,
#  'Tas.Response': 2,
#  'MasterSensor': 248,
#  'MlProject': 19,
#  'Tas.KnownIssue': 1,
#  'VectorStore.Collection': 1,
#  'DataValidationRun': 7,
#  'SystemUpdate': 1,
#  'MlModel.Monitor.Result': 16,
#  'PrivilegeBase': 1,
#  'UiSdlPageGroup': 1,
#  'ControlValvesModelableBase': 1,
#  'SensorBounds': 247,
#  'FinancialAsset': 1,
#  'TestUser': 1,
#  'ReliabilityCaseSegment': 247,
#  'TypeId': 1,
#  'MetricProfilerSpec': 1,
#  'ReliabilitySyntheticData.ReliabilityRisk.DataGenerationJob': 1,
#  'BaseCodeAnalysis.Metric.HardcodedCredentials.RegexRule': 1,
#  'SbaDartIngestSensorBatchJob': 1,
#  'MlWorkflowCoordinatableResult': 2,
#  'GanttChartDemoResourceToCalendar': 8,
#  'Exchange': 1,
#  'Employee': 20,
#  'RateData': 1,
#  'SourceTarget': 2,
#  'Action.Spy.Claim': 1,
#  'PendingRefreshUniqueIndexesReq': 1,
#  'ReliabilityRiskMl.Reconstruction.LightGBMPipe': 1,
#  'ModelRegistry.ModelDependency': 1,
#  'SqlCalcFieldsQueueEntry': 1,
#  'PhysicalAssetEvent': 247,
#  'ItemFacilityInventoryParams': 5,
#  'MaintenanceDataSourceSpec': 248,
#  'CalcFieldIssue': 1,
#  'TestScenario': 2,
#  'InvalidationQueuePaused': 1,
#  'MlSubjectToModelRelation': 1,
#  'MlModel.Train.JobRun': 4,
#  'TestStateMachineWithAfterUpdate': 1,
#  'ReplacementPandaRulePredicter': 1,
#  'InvalidationQueueHistory': 1,
#  'MlModel.Train.Job': 1,
#  'ReliabilityRiskMl.DataConcatenationPipe': 1,
#  'SklearnLikePipe': 1,
#  'SbaDartKeyCodeToFileMapping': 1,
#  'PandaUser': 247,
#  'SchemaSpreadsheetResult': 1,
#  'SplunkSearchResult': 1,
#  'Majcom': 247,
#  'DbLockEntry': 1,
#  'EventDFEMapper': 1,
#  'ReliabilityRiskMl.Pipeline.Interpreter.GeneralSimpleResidualInterpreter': 1,
#  'TestStateMachineHistory': 1,
#  'DocPackage': 1,
#  'WebServiceConfig': 1,
#  'TargetStageKey': 1,
#  'BatchTestStateMachineHistory': 1,
#  'Reconstruction.ScoreAggregationPipe': 1,
#  'Data.Spec': 1,
#  'CommentBoard': 249,
#  'ReliabilityAssetCaseFailureModeRelation': 247,
#  'ReadinessRiskMlModel': 1,
#  'ScheduleHoliday': 26,
#  'AnalysisWorkflowState': 1,
#  'MlModel.RuleRouter': 1,
#  'BaseCanonicalTesterResults': 1,
#  'TargetStatus': 1,
#  'NormalizedTimeseriesPersister': 1,
#  'SandboxMdmDatasetToExcisionRuleMapping': 267,
#  'WorkOrderUpdateLogMergeBatchJob': 1,
#  'MaximGunUser': 3,
#  'TestSpyAnimal': 1,
#  'RefreshAnalyticsBatchJob': 1,
#  'StagingRemisOnEquipmentMaintenanceActionTable': 3,
#  'TargetExampleThree': 1,
#  'BatchJob': 1,
#  'MaintenanceSeverityCode': 1,
#  'SecondaryDsUpsert': 1,
#  'SbaDegScoreInterpreter': 1,
#  'PartyRole': 26,
#  'DataLake.Table.ShareRequest': 4,
#  'InventoryItemKits': 247,
#  'ReliabilityRiskMl.DataColumnSelectionPipe': 1,
#  'Hpo.Experiment': 7,
#  'StagingRemisActualConfigurationWorkUnitCodeTable': 1,
#  'SensorDataReport': 1,
#  'ReliabilityAssetAlertToCaseRelation': 247,
#  'Workflow.Run.Nested.Action': 1,
#  'GanttChartDemoEvent': 8,
#  'FakeTypeOne': 2,
#  'SqlPiiQueueEntry': 1,
#  'RollupMetricBatchJob': 3,
#  'FileSystemBatchJob': 1,
#  'JSBatchJob': 1,
#  'TestAffiliationAssociation': 1,
#  'StagingRemisReportingOrganizationTable': 1,
#  'ClusterBoundPoint': 1,
#  'CodeSample': 1,
#  'SqlSqsQueueEntry': 1,
#  'StagingRemisOnEquipmentWorkOrderTable': 1,
#  'ItemPartyRole': 28,
#  'Persistable.Bin.Strategy.Custom': 1,
#  'Reconstruction.Post.AppendDataByStatePipe': 1,
#  'Action.Spy.Registry': 2,
#  'UserAccessRequestTransition': 1,
#  'EtlLog': 4,
#  'KerasPipeCpu': 1,
#  'TimeOnWingJob': 1,
#  'X12ParserProperties': 1,
#  'NsnToWucMapping': 247,
#  'DataApiEntityType': 3,
#  'HealthCheckLog': 1,
#  'PendingRefreshReq': 1,
#  'SqlKinesisQueueEntry': 1,
#  'SourceStatus': 2,
#  'Action.Mock.Auto': 1,
#  'MlModel.Evaluator': 1,
#  'AssetClassParentChildRelation': 247,
#  'TranslationIssue': 1,
#  'AircraftAssignment': 247,
#  'ReduceResult': 2,
#  'StagingRemisOffEquipmentWorkCenterEventDiscrepancyNarrativeTable': 5,
#  'ReliabilityAssetTteAlert': 7,
#  'RawRemisData': 263,
#  'PhysicalAssetEventResponse': 247,
#  'ReliabilityMl.ValidationPrediction': 1,
#  'Persistable.Bin.Strategy.Custom.State': 1,
#  'UiSdlMetadataFileManifest': 6,
#  'DataValidationPersistedResult': 1,
#  'ReliabilityMlModel': 247,
#  'SbaAdvanaToPandaDatalakeFileCopyJob': 1,
#  'SqlMetricDepsQueueEntry': 1,
#  'ReliabilityMl.ModelReport': 247,
#  'TargetExampleTDH': 2,
#  'ScheduleExceptionDatetimeWindow': 26,
#  'SchemaMigrationVersion': 1,
#  'ReliabilityAssetToModelValidationRelation': 4,
#  'Rate': 3,
#  'Publication': 1,
#  'VaultCertificate': 1,
#  'ReliabilityRiskScoreMlValidationContribution': 1,
#  'DeltaNiinDemandForecast': 247,
#  'AwsCloudWatchDimensions': 1,
#  'ReliabilityRiskScoreMlContribution': 1,
#  'InvalidationQueueErrorReviewComment': 2,
#  'TestPersistable': 1,
#  'NormalizedTimeseriesHotColdMigrator': 1,
#  'TestFileAttachment': 1,
#  'Workflow.Run.Make': 1,
#  'Person': 19,
#  'TestMajcom': 1,
#  'Organization': 19,
#  'InvalidationQueueError': 3,
#  'X12Segment': 1,
#  'FacilityReliabilityAssetRelation': 248,
#  'MdmExcisionRule': 263,
#  'FlightHourForecast': 247,
#  'PhysicalAssetCategory': 1,
#  'MlModel.Train.Result': 20,
#  'AbstractHelpContent': 1,
#  'Feature.Set.ExportSnapshotJob': 16,
#  'Workflow.Run': 2,
#  'EnvReport': 2,
#  'SbaDartDataFile': 247,
#  'ReadinessOperation': 247,
#  'GuideDocExport': 1,
#  'RegionHierarchyDenorm': 1,
#  'User.Event.Login': 1,
#  'ObservedK8sPod': 1,
#  'TargetExampleTDP': 1,
#  'JobStatusTracker': 2,
#  'MlPipe': 1,
#  'TSPerfTest': 1,
#  'DataLoadError': 1,
#  'SignUpToken': 1,
#  'Checkpoint': 1,
#  'GanttChartDemoEventGroup': 1,
#  'MLDataSourceSpec': 1,
#  'ObservedEvent': 1,
#  'MlModel.Route.OperationJob': 1,
#  'ReadinessAlertComment': 1,
#  'TypeMetaDocGetterSampleType': 248,
#  'PartitionableCompactionIssue': 1,
#  'ReliabilityRiskMl.Reconstruction.ElasticNetPipe': 1,
#  'ForecastedAircraftPart': 247,
#  'ReliabilityAssetAlertFeedback': 2,
#  'AbstractStateMachine': 1,
#  'PhysicalAssetHierarchyDenorm': 1,
#  'ActiveUnreliabilityJob': 1,
#  'RollupMetricPersistedResult': 1,
#  'CustomerContact': 20,
#  'DataValidationRule': 3,
#  'RefreshAclsBatchJob': 1,
#  'PhysicalAsset': 247,
#  'LabeledMaintenanceAction': 247,
#  'ThresholdHistory': 1,
#  'MlAtomicPipe': 1,
#  'ControlValvesModelable': 1,
#  'App.State': 1,
#  'Tas.MatchedIssue': 1,
#  'MlModel.Monitor.Job': 1,
#  'DynMapReduce': 1,
#  'StateMachineState': 1,
#  'MdmTrdExcRuleJob': 264,
#  'MdmDataRuleVersion': 263,
#  'Tas.TestSuiteResponse': 3,
#  'StagingRemisHowMalfunctionCodeTable': 1,
#  'UiBundlerResult': 6,
#  'ReliabilityRiskMl.Scaler.Pipe': 1,
#  'ReliabilityMl.Project': 20,
#  'ClusterCenterSeries': 2,
#  'ExMachina_Seq': 1,
#  'GanttChartDemoTimeRange': 1,
#  'StagingRemisStatusTable': 3,
#  'UserAccessRequestState': 1,
#  'ActionContextExtension': 1,
#  'TestStateMachineState': 1,
#  'MaintenanceTypeCode': 1,
#  'TransformedRemisData': 263,
#  'Tenant': 1,
#  'Feature.Set.Snapshot.Subject': 1,
#  'WorkOrderUpdateLog': 1,
#  'Tas.TestCase': 2,
#  'MaintenanceActionGroupDescriptionSegment': 247,
#  'ReliabilitySimilarWorkOrderFilter': 1,
#  'MaintenanceActionDataSourceSpec': 1,
#  'LabeledMaintenanceEvent': 247,
#  'MemberToReliabilityAsset': 1,
#  'DataApiSourcePoolEntityType': 1,
#  'PandaSystemNews': 1,
#  'CaseState': 1,
#  'TestMetricEvaluatable': 1,
#  'MetricDependency': 1,
#  'InvalidationQueueReport': 2,
#  'WorkOrderPerfTest': 2,
#  'StagingRemisOnEquipmentWorkCenterEventDiscrepancyNarrativeTable': 4,
#  'Mail': 1,
#  'Feature.Set': 1,
#  'TextContentConfiguration': 1,
#  'GanttChartDemoResource': 8,
#  'Aircraft': 247,
#  'X12SegmentElement': 1,
#  'RefreshBatchJob': 1,
#  'X12SegmentLoopRule': 1,
#  'FailureModeLibrary': 247,
#  'ReliabilityMlModel.MonitoringScore': 1,
#  'SqlPopulateAclQueueEntry': 1,
#  'ExpectedSensor': 247,
#  'Feature': 1,
#  'MaximGun': 3,
#  'PhysicalMeasurementSeries': 1,
#  'MlModel.Route.StatusHistory': 1,
#  'Currency': 1,
#  'EncryptedDek': 1,
#  'NotificationCategoryPreference': 3,
#  'PerfMetricCategory': 1,
#  'CachedGraph': 1,
#  'StagingRemisActualConfigurationTable': 1,
#  'ReadinessDataIngest': 1,
#  'ReliabilityModelRegistry.SourceEntry': 247,
#  'ReliabilityTteForecastPrediction': 1,
#  'ReliabilityRiskMlModel.Evaluator': 1,
#  'SqlActionQueueEntry': 1,
#  'CommentAPost': 1,
#  'StagingRemisOnEquipmentCorrectiveActionTable': 4,
#  'PartyCommunicationPreference': 26,
#  'DataLake.Table.ImportJob': 1,
#  'X12CompositeElementRule': 1,
#  'MlModel.Train.JobResult': 4,
#  'PartyRoleRelation': 26,
#  'PendingBatchJobReq': 1,
#  'StateMachineTransitionLock': 1,
#  'UiSdlMetadataFileManifestCache': 1,
#  'TestSpyAnimalBatchJob': 1,
#  'FileMeta': 1,
#  'ReliabilityAssetSensorRelation': 247,
#  'ReliabilityTtePrediction': 1,
#  'BatchTestStateMachine': 1,
#  'SklearnLikePipeV7': 1,
#  'SourceContent': 1,
#  'Feature.Set.CreateSnapshotJob': 1,
#  'MetricIssue': 1,
#  'PhysicalAssetRelativePositionHistory': 1,
#  'ReliabilityRiskMl.Pipeline.Interpreter.SimpleResidualInterpreter': 1,
#  'MaintenanceRecommendationTransition': 1,
#  'AircraftTelemetry': 1,
#  'ReliabilityAssetCaseToAssetRelation': 247,
#  'PathId': 1,
#  'Workflow.Run.JobBase': 1,
#  'PandaMail': 249,
#  'AdvanaPreProcessFileJob': 1,
#  'Hpo.Run': 3,
#  'GanttChartDemoEventDependency': 1,
#  'RollupMetricBatchJobBatchResult': 1,
#  'ReliabilityMlModelExperiment': 247,
#  'ReliabilityMl.ValidationPredictionHeader': 4,
#  'TestDataValidationSubject': 1,
#  'EventDFELastEval': 1,
#  'JSData': 1,
#  'MlTemplate.AtomicPipe': 1,
#  'InventoryMeasurement': 1,
#  'ReliabilityAssetCaseUpdateHistory': 247,
#  'Pkg.Store.Seq': 1,
#  'StagingRemisOffEquipmentMaintenanceActionTable': 4,
#  'TimeseriesPerfTest': 1,
#  'ReliabilityRiskMl.Pipeline.Interpreter.DirectionallyWeightedResidualInterpreter': 1,
#  'TrainingHandbookFile': 3,
#  'TestApiEntityType': 3,
#  'MetricsCache': 1,
#  'ObservedK8sEvent': 1,
#  'FacilityReliabilityAssetHierarchicalRelation': 247,
#  'ReliabilityCase': 247,
#  'MdmDatasetToExcisionRuleMapping': 263,
#  'AircraftAssetMaintenanceRecommendation': 247,
#  'TSStatsJob': 1,
#  'TestMetricData': 1,
#  'UserRecommendationCategory': 1,
#  'FailureModePriority': 1,
#  'NetworkProxyService': 1,
#  'MapReduce': 1,
#  'MomentInTimeCurrentCaseMetric': 1,
#  'ImageExportList': 1,
#  'MlModel.Monitor.BatchResult': 3,
#  'Workflow.Run.Input': 1,
#  'MlModel.Monitor.GroupRun': 2,
#  'CatBoostPipe': 1,
#  'Guard': 1,
#  'UserRecommendationDismissedHistory': 1,
#  'Tas.BuildInfo': 1,
#  'PartyTimedIntervalRelation': 1,
#  'XgBoostPipe': 1,
#  'BaseAdjudicatedMaintenanceEvent': 247,
#  'PyTestRunner': 1,
#  'MlCustomPipe': 1,
#  'JupyterNotebook': 3,
#  'SensorValueMapping': 247,
#  'ReliabilityAssetToRiskModelRelation': 247,
#  'FailureModeLineItem': 247,
#  'TransformStatus': 1,
#  'TargetExampleTwo': 2,
#  'Observation': 1,
#  'Region': 8,
#  'PandaMlMetadata': 247,
#  'AircraftOperationSensorEventSeries': 247,
#  'MlModel.OperationRun': 17,
#  'MapInValue': 3,
#  'NewsTile': 1,
#  'NormalizationLock': 1,
#  'MaintenanceEvent': 247,
#  'InsertNewBaseTypeBatchJob': 1,
#  'RegimeAnalysisDataCache': 1,
#  'PartyHierarchyDenorm': 1,
#  'ReliabilityAssetSensorHierarchicalRelation': 247,
#  'JobStatusReport': 2,
#  'InventoryItem218': 247,
#  'ItemCharacteristicSet': 1,
#  'UserFieldPreference': 20,
#  'StagingRemisUtilizationTable': 3,
#  'Feature.Store.Block.PackJob': 1,
#  'FailureModeDiagnostic': 1,
#  'SbaIrisC130JDataFile': 1,
#  'PossessionPurposeCode': 1,
#  'JobInformation': 1,
#  'TestTextContentStream': 1,
#  'NationalStockNumber': 247,
#  'MdmDataset': 263,
#  'PointOfContact': 1,
#  'NotificationHistory': 3,
#  'TestStateMachine': 2,
#  'TestApartment': 2,
#  'DataLake.Table.MetaFieldValue': 2,
#  'AdditionalRelationalDataSpec': 2,
#  'Alert': 1,
#  'NormalizedTimeseries': 2,
#  'GitHubToken': 3,
#  'ReliabilityRiskMl.Scaler.MinMaxScalerPipe': 1,
#  'SandboxTransformedRemisDataToMdmDataRuleRelation': 263,
#  'MessageClaim': 1,
#  'PositionFailureModeToNSNRelation': 247,
#  'FeatureEvaluatable.Bin.Strategy.Custom': 1,
#  'PandaDataPipelineToAdvanaDataMapping': 5,
#  'FacilityHierarchicalRelation': 3,
#  'SeedData': 1,
#  'AircraftAssetMaintenanceRecommendationAlert': 248,
#  'ReliabilityRiskMlModel': 247,
#  'UserGroup': 2,
#  'MonitoredEventWindow': 1,
#  'AircraftSensorEventValueHistory': 1,
#  'Action.Mock.Result': 1,
#  'X12Loop': 1,
#  'EchoEntity': 1,
#  'SklearnPipe': 1,
#  'Subscription': 1,
#  'MetricsCacheRefreshJob': 1,
#  'RollupMetricBatchJobTestDataSourceEntity': 5,
#  'Feature.Store.Block': 2,
#  'FactPopulationLog': 1,
#  'TestApiActionCode': 1,
#  'Action.Spy': 1,
#  'GeoAddressComponentType': 1,
#  'IdpCertificate': 1,
#  'GanttChartDemoCalendarInterval': 2,
#  'RollupMetricsRatioTest': 1,
#  'NativePyRun': 1,
#  'FactPopulatorJob': 1,
#  'Country': 2,
#  'MonthlyPartsRemovedJob': 1,
#  'AnalyticStat': 1,
#  'DataReplicatorSpec': 1,
#  'MetricsStatsJob': 1,
#  'Workflow.Coordinatable': 1,
#  'RefreshPartitionableCompactionBatchJob': 1,
#  'NotificationUserRecipient': 3,
#  'SupplyTransaction': 247,
#  'WhenDiscoveredCode': 1,
#  'TestStateMachineTransition': 1,
#  'RefreshNormalizationBatchJob': 1,
#  'ReliabilityAssetRiskAlert': 248,
#  'ReliabilityAssetCharacteristicValue': 1,
#  'KerasPipe': 1,
#  'PackageFile': 1,
#  'MeasurementSeries': 248,
#  'OrganizationSegment': 19,
#  'AbstractFeatherPandasFile': 1,
#  'TopicDocExport': 1,
#  'PendingWorkflowReq': 1,
#  'Export': 1,
#  'User.Session': 1,
#  'AdvanaDataTracker': 5,
#  'ReliabilityRiskMl.Pipeline': 1,
#  'ReliabilityRiskMl.Pipeline.Interpreter.ControlValvesInterpreter': 1,
#  'UserRegistration': 1,
#  'GroupedLOVItem': 1,
#  'SqlMapReduceQueueEntry': 1,
#  'SupervisedMLDataSourceSpec': 1,
#  'Feature.Set.Snapshot': 15,
#  'CustomizedTestStateMachineState': 1,
#  'Facility': 3,
#  'LoadAnalyzerConfig': 1,
#  'CodeCoverageReachCounter': 1,
#  'JobRunErrorDetail': 1,
#  'ReliabilityModelRegistry.TargetEntry': 248,
#  'Workflow.Run.Const': 1,
#  'SbaIrisCreateReadinessOperationBatchJob': 1,
#  'TestOrganizationDenorm': 1,
#  'MdmGenerateFileExportJob': 1,
#  'StopWords': 1,
#  'Formula': 1,
#  'SbaIrisKC135DataFile': 1,
#  'ReliabilityRiskMl.Alerting.Pipe': 1,
#  'PurchaseOrderPartsForecast': 4,
#  'ReadinessDatasetPreparationRun': 247,
#  'SbaOperationDataStatusHistory': 1,
#  'ReliabilityRiskMl.SetIndexPipe': 1,
#  'NationalItemIdentificationNumber': 247,
#  'JobHistory': 2,
#  'PersonUser': 19,
#  'Workflow.Run.Batch': 2,
#  'CloudStreamCheckpoint': 1,
#  'AircraftStatus': 247,
#  'MaintenanceActionDescriptionSegment': 247,
#  'DataIssue': 1,
#  'StateMachine': 1,
#  'DynamoDBAutoScalingLog': 1,
#  'Workflow.Run.Conditional': 1,
#  'AssetHierarchyDenorm': 1,
#  'PandaGroup': 247,
#  'MlModel.HealthCalc.Job': 1,
#  'SqlEventHubQueueEntry': 1,
#  'ReliabilityAssetToRiskModelValidationRelation': 5,
#  'FacilityCharacteristicSet': 1,
#  'DocCategory': 1,
#  'MemberToParty': 1,
#  'MlModel.Health.History': 15,
#  'SimpleSynchronousPyRun': 1,
#  'ReadinessAssetAlertToCaseRelation': 247,
#  'PartitionableCompactor': 1,
#  'MlModel.Monitor.TimedResult': 4,
#  'Workflow.Run.MapReduce': 3,
#  'ReliabilityRiskMl.Pipeline.Interpreter.SigmoidWeightedResidualInterpreter': 1,
#  'MaximGunSetupContext': 1,
#  'MlModel.Monitor.BatchGroupRun': 2,
#  'MlSubject.OperationJob': 1,
#  'App.Metric': 2,
#  'StagingRemisOnEquipmentMaintenanceRemoveAndInstallDataTable': 1,
#  'MlModel.Route': 19,
#  'Customer': 1,
#  'PandaRulePredicter': 247,
#  'ReadinessSyntheticDatasetBatchJob': 1,
#  'PackageBuildResult': 1,
#  'DataApiContext': 1,
#  'PeriodicCalcState': 3,
#  'WorkItem': 247,
#  'SupplyTransactionLinkagesJob': 2,
#  'MaintenanceAction': 247,
#  'JupyterFile': 1,
#  'InvalidationQueueLock': 1,
#  'FailureRecommendationFeedback': 1,
#  'PeriodicCalcStateHistory': 3,
#  'ScheduleCalendar': 26,
#  'StagingRemisOffEquipmentWorkOrderTable': 3,
#  'GanttChartDemoCalendar': 2,
#  'NormalizedTimeseriesState': 1,
#  'ReadinessShapInterpreter': 1,
#  'DynBatchJob': 1,
#  'RegionRelation': 8,
#  'ModelConfigCachedHyperparams': 248,
#  'PandaModelTransition': 1,
#  'FrequentlyAskedQuestion': 1,
#  'RollupMetricBatchJobTestDataPoint': 5,
#  'TestResult': 2,
#  'SqlKafkaQueueEntry': 1,
#  'TestDepartmentDenorm': 1,
#  'MlModel.Monitor.TimedResultHeader': 16,
#  'ExportFile': 1,
#  'X12SegmentRule': 1,
#  'MlModel.Evaluation.Result': 15,
#  'ModelRegistry.RegisterLoadBatchJob': 1,
#  'MlModel.Route.OperationJob.Run': 2,
#  'Feature.Chunk.DfBldr.Block': 1,
#  'Link': 1,
#  'EnableAclPrivilege': 1,
#  'CommentBoardReply': 249,
#  'WeatherStationCreator': 1,
#  'TimeOnMaintenanceActionsJob': 1,
#  'BaseCanonicalTesterCoverage': 1,
#  'ReliabilityRiskScoreMlPredictionHeader': 247,
#  'CMCProcessJob': 1,
#  'ReliabilitySyntheticData.ReliabilityRisk.AssetHierarchySpreadsheet': 2,
#  'ReliabilityRiskScoreMlValidationContributionHeader': 5,
#  'BasePhysicalMeasurementSeries': 2,
#  'MdmGetTrdsAndExcRulesJob': 264,
#  'FakeTypeTwo': 2,
#  'MetricProfileSpec': 2,
#  'DataValidationMapReduceJob': 8,
#  'SqlChangeLogQueueEntry': 1,
#  'TimeBetweenMaintenanceActionsJob': 1,
#  'MetricAccessGroup': 1,
#  'DocExport.FileUrlAlias': 1,
#  'TimeBoundAlertMetric': 248,
#  'MonthlyPartsRemoved': 247,
#  'MdmDataRule': 263,
#  'SbaIrisC17DataFile': 1,
#  'UserAircraftAssetMaintenanceRecommendationRelation': 247,
#  'EtlBatchJob': 1,
#  'ElasticSearchFieldMapping': 1,
#  'ReliabilityAssetToTteModelRelation': 6,
#  'ReadinessRiskInferenceLog': 249,
#  'AsyncAction': 1,
#  'ReliabilityMl.Contribution': 1,
#  'UsafOrganization': 247,
#  'ItemRelation': 1,
#  'SpacyEmbeddingPipe': 1,
#  'SqlBatchQueueEntry': 1,
#  'ReliabilityRiskMl.Reconstruction.VirtualSensorPipeline': 1,
#  'JupyterContent': 1,
#  'ReliabilityRiskScoreMlScoreHeader': 247,
#  'FeatureEvaluatable.Bin.Strategy': 1,
#  'ReadinessRiskInferenceJob': 248,
#  'DataIntegStatus': 5,
#  'ReadinessDataIngestBuilder': 1,
#  'TestSmartBulb': 2,
#  'SbaDataFile': 247,
#  'ReliabilityAssetAlertBase': 248,
#  'TestCountryCategory': 1,
#  'PersistableObjDigest': 1,
#  'TSStats': 2,
#  'OAuthApplication': 1,
#  'SbaOperationData': 247,
#  'X12CompositeElement': 1,
#  'ClusterCenterPoint': 1,
#  'AircraftModelCasesChanged': 1,
#  'MxEffort': 247,
#  'ReliabilityTtePredictionHeader': 6,
#  'ReliabilityRiskScoreMlContributionHeader': 247,
#  'JSMapReduceJob': 1,
#  'PandaUserStatusHistory': 1,
#  'SandboxSampleFile': 251,
#  'MlModel.Monitor.ModelToMetricMapping': 16,
#  'UiCodeCoverageScriptSource': 1,
#  'SensorDataSummary': 247,
#  'SignatureKey': 1,
#  'AssetClass': 247,
#  'Sensor': 247,
#  'Measurement': 1,
#  'SourceChunkStatus': 1,
#  'BusinessRegionRelation': 2,
#  'HowMalfunctionCode': 1,
#  'TestCassandraType': 1,
#  'InventorySeries': 3,
#  'Reconstruction.SetIndexPipe': 1,
#  'PartyPhone': 26,
#  'FacilityHierarchyDenorm': 1,
#  'RecursiveLOVItem': 1,
#  'ExportImportChunk': 1,
#  'Config.AuditLog': 1,
#  'Workflow.Run.NestedBase': 1,
#  'SqlSourceStatusQueueEntry': 1,
#  'FailureMode': 247,
#  'PurchaseOrderLine': 6,
#  'OrganizationCharacteristicSet': 1,
#  'DFEEvalHistory': 1,
#  'CustomizedTestStateMachineHistory': 1,
#  'ClassifierScore': 1,
#  'SourceFile': 3,
#  'SensorMeasurementBounds': 247,
#  'StoredLambda': 1,
#  'LOVItem': 1,
#  'MaintenanceRecommendationStateHistory': 1,
#  'MlSubject.ProcessJob': 1,
#  'Action.Spy.Lambda': 1,
#  'AircraftProjectSubject': 1,
#  'DepartmentLevel': 1,
#  'AssetPartyRole': 247,
#  'AircraftAsset': 247,
#  'ReliabilityAssetToReadinessRiskModelRelation': 2,
#  'SqlCronQueueEntry': 1,
#  'CaseAssigneeHistory': 1,
#  'ReliabilitySyntheticData.LastRunTracker': 1,
#  'Import': 1,
#  'StagingRemisInventoryTable': 2,
#  'Flight': 2,
#  'FixedAsset': 247,
#  'PhysicalAssetCategoryAssociation': 1,
#  'ModelTemplate': 1,
#  'WorkOrder': 247,
#  'DataValidationSubject': 7,
#  'TestApiObj': 3,
#  'Action.Mock.Lambda': 1,
#  'Workflow.Run.Field': 1,
#  'Workflow.Run.Action': 1,
#  'ReliabilityAssetHierarchyDenorm': 1,
#  'UserPreference': 2,
#  'TrainingVideoFile': 3,
#  'BatchInValue': 1,
#  'AssetOwner': 1,
#  'MetricPriority': 1,
#  'MlPipeline': 1,
#  'SandboxRawRemisData': 263,
#  'FacilityCharacteristicValue': 1,
#  'Position': 247,
#  'SourceFile.RemoveWithDataBatchJob': 1,
#  'TransformedRemisDataToMdmDataRuleRelation': 263,
#  'MlModel.Monitor.GroupResult': 1,
#  'TimeBetweenInstallsJob': 1,
#  'PandaInferenceJob': 247,
#  'WebpackPerformanceProfile': 5,
#  'ReliabilityAssetValidationAlert': 5,
#  'ReliabilityRiskMl.Scaler.StandardScalerPipe': 1,
#  'BaseCodeAnalysis.PackageHealth.Score.ComputeConstants': 1,
#  'Application': 1,
#  'PartyElectronicCommunication': 26,
#  'PhysicalAssetLocationHistory': 2,
#  'ReliabilityTteMlModel': 6,
#  'Action.Mock': 1,
#  'StagingRemisGeographicLocationTable': 1,
#  'Reconstruction.ConcatenationPipe': 1,
#  'TargetStage': 1,
#  'MlSubject.OperationJob.Run': 2,
#  'PartyEdge': 1,
#  'AdjudicatedMaintenanceAction': 247,
#  'MlModel': 15,
#  'StagingRemisOffEquipmentDiscrepancyTable': 4,
#  'AwsKinesisStreamCheckPoint': 1,
#  'StagingRemisOnEquipmentDiscrepancyTable': 2,
#  'Supplier': 19,
#  'MapReduceRun': 2,
#  'SavedEvalMetricsSpec': 1,
#  'TransactionAdmin': 1,
#  'AutoCreateUser': 1,
#  'SqlSourceQueueEntry': 1,
#  'AircraftModelVariant': 247,
#  'ReliabilitySparePartsSimilarityJob': 1,
#  'AiAssistant.Feedback.Question': 2,
#  'TestFileParent': 1,
#  'ReliabilityMl.Setup': 1,
#  'ActionTakenCode': 1,
#  'PurchaseOrderLineReceipt': 6,
#  'PendingRefreshStoredCalcReq': 1,
#  'NextId': 1,
#  'DataLake.Table.Managed.Iceberg': 1,
#  'CaseToPartQuantityRelation': 247,
#  'UserRecommendation': 3,
#  'ReliabilityRiskScoreMlValidationPrediction': 1,
#  'PendingRefreshAclReq': 1,
#  'UserNotificationPreference': 1,
#  'PurchaseOrder': 6,
#  'MlWorkflowCoordinatable': 1,
#  'ExportDataFile': 1,
#  'ReliabilityMlDatasetPreparationJob': 247,
#  'SandboxMdmDataset': 267,
#  'ReliabilityRiskMl.DataConcatenation1DPipe': 1,
#  'PersonOrganizationRelation': 19,
#  'Locale': 1,
#  'WeatherStation': 1,
#  'OrganizationHierarchyDenorm': 1,
#  'PendingMapReduceReq': 1,
#  'X12LoopNaming': 1,
#  'SourceTargetTwo': 1,
#  'ReliabilityAssetCase': 247,
#  'Unit': 1,
#  'MlModel.RelationRouter': 1,
#  'WorkOrderPartsForecast': 3,
#  'UiBundler': 5,
#  'ReadinessIngestEvent': 2,
#  'MomentInTimeCaseMetric': 1,
#  'GeographicalEntity': 1,
#  'AclPrivilege': 1,
#  'ReliabilityRiskMl.RiskScoreComputation.Pipe': 1,
#  'PandaRole': 1,
#  'AssetOnboardingSourceFile': 1,
#  'SensorProcessJob': 1,
#  'LastNamedTracker': 1,
#  'AbstractPandasFile': 1,
#  'MlModel.HealthCalc.Result': 15,
#  'CaseStateTransition': 1,
#  'Persistable.Bin.Strategy': 1,
#  'ReliabilityMl.Pipeline': 1,
#  'ScheduleHolidayDate': 26,
#  'Workflow.Run.Vertex': 3,
#  'PositionToReliabilityCaseMapping': 247,
#  'MetricDepIssue': 1,
#  'CassandraTableStats': 1,
#  'AiAssistant.Feedback.Answer': 2,
#  'ObservedK8sResource': 1,
#  'MlModel.Route.OperationJob.Result': 20,
#  'TypeDocExport': 1,
#  'TestCountryAssociation': 1,
#  'ReliabilityMl.Prediction': 1,
#  'PerfTestResult': 1,
#  'HierarchyBranch': 1,
#  'MaintenanceToPart': 247,
#  'AiAssistant.Feedback.AnswerSpec': 1,
#  'Pkg.State': 1,
#  'ReliabilityMl.ContributionHeader': 247,
#  'ReliabilityMl.ValidationContributionHeader': 4,
#  'AdjudicatedMaintenanceEvent': 247,
#  'ReliabilityAssetHierarchicalRelation': 247,
#  'MlModel.Router': 19,
#  'TestDataValidation': 1,
#  'PandaModelState': 1,
#  'LMEChangeHistory': 248,
#  'ReliabilityAssetClassDefinitionParserJobBatchResult': 249,
#  'SandboxMdmDatasetToTrdMapping': 267,
#  'CountryCode': 1,
#  'StagingRemisEndItemTable': 1,
#  'DataValidationBatchJob': 8,
#  'QuartileConfidence': 1,
#  'DataConfiguration': 248,
#  'ReliabilityMl.ValidationContribution': 1,
#  'TestDepartment': 2,
#  'StagingRemisWorkUnitCodeTable': 1,
#  'DataErDiagramResult': 1,
#  'JupyterDirectory': 2,
#  'PerfTestSuite': 1,
#  'MlModel.HealthCalc.JobRun': 2,
#  'ProtectionLoop': 250,
#  'MlModel.Evaluation.JobRun': 6,
#  'ScheduledTransitionTriggers': 1,
#  'ReliabilityTteForecastContributionHeader': 6,
#  'AirBaseModelPair': 247,
#  'MetricPriorityJob': 1,
#  'WorkOrderJobCategory': 1,
#  'ReliabilityTteContribution': 1,
#  'ExternalNiinDemandForecast': 247,
#  'ReadinessAlertPriorityHistory': 1,
#  'TargetStageSweep': 1,
#  'MlTemplate.Pipeline': 1,
#  'CreateLabeledMaintenanceJob': 248,
#  'GenerateTagSpec': 2,
#  'CustomerRelation': 19,
#  'AssetConfigurationLastUpdated': 1,
#  'AssetDocument': 247,
#  'BatchTestStateMachineTransition': 1,
#  'FixedAssetHierarchyRelation': 248,
#  'SplitSet': 1,
#  'MlModel.Evaluation.Job': 1,
#  'ReliabilityMl.LegacyLambda': 1,
#  'AdvanaDataIngestStatusHistory': 1,
#  'AnalysisWorkflowStateHistory': 248,
#  'WorkOrderPartsDenormalized': 248,
#  'Department': 19,
#  'OrganizationBaseConfigurableAclEnabled': 1,
#  'Tas.TrackingResponse': 2,
#  'UiSdlGraphTestEdge': 1,
#  'AiAssistant.Feedback.QuestionSpec': 1,
#  'Db.TypeSchema': 1,
#  'PointPhysicalMeasurementSeries': 247,
#  'PhysicalAssetLinearRelation': 1,
#  'OperationFileTracker': 250,
#  'WeatherDataResult': 1,
#  'AssetLevel': 1,
#  'Workflow': 2,
#  'ReliabilityMlDatasetPreparationRun': 247,
#  'ReliabilityAssetToModelRelation': 247,
#  'FeatureBase': 1,
#  'RiskMlModelPredictionHistory': 1,
#  'ReliabilityRiskMl.CommonIndexFilterPipe': 1,
#  'SqlAnalyticsQueueEntry': 1,
#  'LocationMeasurementDevice': 2,
#  'SourceChunk': 1,
#  'HierarchyDenormBatchJob': 1,
#  'TestApiContext': 3,
#  'DataLake.Table.DownloadRequest': 2,
#  'UserRecommendationStatusHistory': 6,
#  'LegacyControlValvesModelable': 1,
#  'OAuthAccess': 4,
#  'MlSubject.InterpretJob': 1,
#  'RollupMetricBatchJobResult': 1,
#  'HierDenormIssue': 1,
#  'SpacyMatcherPipe': 1,
#  'Party': 26,
#  'FailureModeFeedback': 1,
#  'SplitSpec': 247,
#  'WorkOrderPartsSimilarityPredictions': 247,
#  'UserEmailPreference': 248,
#  'ResourceProfile': 1,
#  'ReliabilityAssetCaseFailureRecommendationRelation': 248,
#  'RefreshDefaultFieldsBatchJob': 1,
#  'MaintenanceRecommendationState': 1,
#  'ReliabilityAssetClassDefinitionParserJob': 249,
#  'DisclosureReviewRequest': 3,
#  'Hpo.Trial': 4,
#  'SpacyPipe': 1,
#  'ClusterEventLog': 1,
#  'MetricsStats': 1,
#  'ReliabilityAssetToReadinessOperationRelation': 1,
#  'TestMetricChartData': 1,
#  'ValueScoreJob': 1,
#  'ScheduleRecurringDayRule': 26,
#  'ConsoleTool': 1,
#  'ProtectionLoopSensorRelation': 250,
#  'ReliabilityMl.PredictionHeader': 247,
#  'TestOrganization': 2,
#  'MdmDatasetToTrdMapping': 263,
#  'PhysicalAssetCategoryRelation': 1,
#  'ReliabilityMl.CustomPipeFactory': 1,
#  'PendingRefreshDefaultFieldsReq': 1,
#  'MetricTestData': 1,
#  'TaggedComment': 1,
#  'DataApiOtherEntityType': 1,
#  'TestApiContextMR': 1,
#  'ExternalDsWhitelist': 1,
#  'TargetExampleOne': 1,
#  'UnitOfConversion': 1,
#  'MemberToPhysicalAsset': 1,
#  'CbmNiinDemandForecast': 247,
#  'UiCodeCoverageChromeResult': 1,
#  'FailureModeRecommendation': 247,
#  'RpKeyPair': 1,
#  'AircraftTelemetryHistory': 248,
#  'ReliabilityAsset': 247,
#  'Idp': 2,
#  'PhysicalAssetRealTimeLocation': 247,
#  'SensorAnalysisDataCache': 1,
#  'SetupWorkingDirPerformanceProfile': 5,
#  'VanityUrl': 1,
#  'SqlNormalizationQueueEntry': 1,
#  'CloudMessageRegistry': 1,
#  'PandaModelStateHistory': 1,
#  'AnalysisWorkflowTransition': 1,
#  'MlSubject.Group': 1,
#  'MlModel.Monitor.JobRun': 2,
#  'BatchJobRun': 1,
#  'WorkOrderSimilarityPredictions': 247,
#  'GovUser': 3,
#  'TestGraphVisualizationEdge': 2,
#  'ZipLatLong': 1,
#  'ReliabilityTteContributionHeader': 6,
#  'Tas.CloseAutomationState': 3,
#  'PkgInference': 1,
#  'SqlKvStoreData': 1,
#  'ReliabilityMl.CustomPipe': 1,
#  'InventoryItem': 247,
#  'MdmWucCorrectionRule': 264,
#  'MaintenanceEventDescriptionSegment': 247,
#  'ReliabilityAssetAlert': 1,
#  'AdditionalExportSpec': 2,
#  'MaintenanceActionGroup': 247,
#  'AssetHierarchyTemplate': 1,
#  'MaintenanceEventDataSourceSpec': 1,
#  'LightGbmPipe': 1,
#  'CaseComment': 1,
#  'RefreshUniqueIndexesBatchJob': 1,
#  'StagingRemisInventoryAssignmentTable': 2,
#  'WucToReliabilityCaseMapping': 247,
#  'AppRebuilder': 1,
#  'SensorEventType': 2,
#  'PhysicalAssetHierarchyRelation': 1,
#  'TestApiOtherEntityType': 1,
#  'AdoptionReport': 248,
#  'ModelInferenceProxyPipe': 1,
#  'ReliabilitySparePartsForecastJob': 1,
#  'App.Metric.Dashboard': 1,
#  'ReliabilityRiskMl.Pipeline.Interpreter.SimpleResidualToolkitInterpreter': 1,
#  'SupplyLocation': 247,
#  'MlSubject.OperationJob.Result': 20,
#  'OrganizationRollup': 19,
#  'PendingJobReq': 1,
#  'TestGraphVisualizationNode': 1,
#  'ServiceEndpoint': 1,
#  'ObjBatchMapReduceJob': 1,
#  'MlLambdaPipe': 1,
#  'Location': 1,
#  'InvalidationQueueCompactor': 1,
#  'NormalizationMonitor': 1,
#  'TargetExampleMultiLayer3': 1,
#  'EventWindow': 2,
#  'CodeCoverageCounter': 2,
#  'TargetExampleMultiLayer2': 1,
#  'TargetExampleMultiLayer1': 1,
#  'DataValidationRulesetHierarchicalRelation': 3,
#  'Hpo.RunCoordinator': 5,
#  'GeoPoliticalRegion': 2,
#  'UiSdlGraphTestVertex': 1,
#  'Item': 1,
#  'RefreshCalcFieldsBatchJob': 1,
#  'IstanbulCoverageFileResult': 1,
#  'MlDynamicPipe': 1,
#  'AnalyticIssue': 1,
#  'WeatherDataUpdater': 1,
#  'AirBase': 247,
#  'AircraftAssetR2DetectionProjectSubject': 1,
#  'BatchTestStateMachineState': 1,
#  'Translation': 2,
#  'UiBundlerPerformanceProfile': 5,
#  'TestActionMock': 2,
#  'MaximGunFire': 3,
#  'GanttChartDemoResourceTimeRanges': 8,
#  'MapResult': 3,
#  'ReadinessAssetAlert': 247,
#  'FailureModePositionToOperation': 247,
#  'NotificationRecipient': 3,
#  'SqlCacheQueueEntry': 1,
#  'DataLake.Table.Managed': 1,
#  'CaseStateHistory': 2,
#  'ReliabilityRiskScoreMlValidationPredictionHeader': 5,
#  'ReliabilityTteForecastContribution': 1,
#  'EnvLog': 1,
#  'ReadinessDataIngestDefault': 1,
#  'CronJob': 2,
#  'APost': 1,
#  'LocationGeocodingJob': 1,
#  'GitMergeLog': 1,
#  'AircraftStatusCode': 1,
#  'InventoryHistory': 247,
#  'SbaDegScore': 1,
#  'TimeBoundCaseMetric': 1,
#  'PandaRulePredicterWord': 247,
#  'ReadinessAlertCommentAttachment': 1,
#  'SupplyTransactionEditedMetadata': 247,
#  'WucToMdmWucCorrectionRulesMapping': 265,
#  'PhysicalAssetRealTimeLocationMeasurement': 1,
#  'CasePriorityHistory': 1,
#  'EngineeringRecommendation': 247,
#  'RefreshMetricDepsBatchJob': 1,
#  'ScheduleHolidaySchedule': 26,
#  'TestSmartBulbToApartmentRelation': 1,
#  'UserAccessRequestStateHistory': 1,
#  'MlModel.Evaluation.Run': 2,
#  'PandaDataPipelineStatusHistory': 1,
#  'PartyPostalAddress': 26,
#  'HuggingfacePipe': 1,
#  'Workflow.Run.Nested': 3,
#  'EtlCoordinator': 4,
#  'InvalidationQueueErrorReview': 2,
#  'TestAffiliationCategory': 1,
#  'DeltaSegmentDemandForecast': 247,
#  'ReliabilityRiskMl.RiskScoreScaling.Pipe': 1,
#  'UserAccessRequest': 247,
#  'TagGenerator': 1,
#  'MlOperationRun': 1,
#  'ReliabilityRiskScoreMlScore': 1,
#  'Tag': 1,
#  'DocExport.Error': 1,
#  'RescheduleCalcFieldsBatchJob': 1,
#  'SbaIrisRC135DataFile': 1,
#  'Pkg.File.Db': 1,
#  'ReadinessAlertAssigneeHistory': 1,
#  'UiSdlSavedSearch': 1,
#  'PersistableObjDigestBatchJob': 1,
#  'BusinessRegion': 2,
#  'Hierarchy': 1,
#  'CustomizedTestStateMachine': 1,
#  'AirBaseToUsafOrganizationMapping': 247,
#  'DataValidationPersistedRulesetResult': 1,
#  'BundleStatus': 5,
#  'Member': 1,
#  'SbaPerformanceDashboardMetricTilesCache': 1,
#  'StagingRemisInventoryPossessionTable': 2,
#  'PopulateAclIssue': 1,
#  'Resource': 1,
#  'LambdaPandaRulePredicter': 2,
#  'Sequence': 1,
#  'VmTypeInfo': 1,
#  'EditedNationalStockNumber': 247,
#  ...}

# %%
# Sort nodes by descendant count
sorted_nodes = sorted(descendant_counts.items(), key=lambda x: x[1], reverse=True)

# %%
# Return top N nodes
top_nodes = [(node_id, count) for node_id, count in sorted_nodes[:50]]

# %%
top_nodes = [(node_id, count) for node_id, count in sorted_nodes[:50]]

# %%
top_nodes
# Out:
# [('SandboxMdmDatasetToExcisionRuleMapping', 267),
#  ('SandboxMdmDataset', 267),
#  ('SandboxMdmDatasetToTrdMapping', 267),
#  ('WucToMdmWucCorrectionRulesMapping', 265),
#  ('MdmTrdExcRuleJob', 264),
#  ('MdmGetTrdsAndExcRulesJob', 264),
#  ('MdmWucCorrectionRule', 264),
#  ('RawRemisData', 263),
#  ('MdmExcisionRule', 263),
#  ('MdmDataRuleVersion', 263),
#  ('TransformedRemisData', 263),
#  ('MdmDatasetToExcisionRuleMapping', 263),
#  ('MdmDataset', 263),
#  ('SandboxTransformedRemisDataToMdmDataRuleRelation', 263),
#  ('MdmDataRule', 263),
#  ('SandboxRawRemisData', 263),
#  ('TransformedRemisDataToMdmDataRuleRelation', 263),
#  ('MdmDatasetToTrdMapping', 263),
#  ('SandboxTransformedRemisData', 263),
#  ('SandboxSampleFile', 251),
#  ('ProtectionLoop', 250),
#  ('OperationFileTracker', 250),
#  ('ProtectionLoopSensorRelation', 250),
#  ('ProtectionLoopAlert', 250),
#  ('FailureRecommendationRelation', 249),
#  ('CommentBoard', 249),
#  ('PandaMail', 249),
#  ('CommentBoardReply', 249),
#  ('ReadinessRiskInferenceLog', 249),
#  ('ReliabilityAssetClassDefinitionParserJobBatchResult', 249),
#  ('ReliabilityAssetClassDefinitionParserJob', 249),
#  ('FailureModeRelation', 249),
#  ('MasterSensor', 248),
#  ('MaintenanceDataSourceSpec', 248),
#  ('FacilityReliabilityAssetRelation', 248),
#  ('TypeMetaDocGetterSampleType', 248),
#  ('AircraftAssetMaintenanceRecommendationAlert', 248),
#  ('ReliabilityAssetRiskAlert', 248),
#  ('MeasurementSeries', 248),
#  ('ReliabilityModelRegistry.TargetEntry', 248),
#  ('ModelConfigCachedHyperparams', 248),
#  ('TimeBoundAlertMetric', 248),
#  ('ReadinessRiskInferenceJob', 248),
#  ('ReliabilityAssetAlertBase', 248),
#  ('LMEChangeHistory', 248),
#  ('DataConfiguration', 248),
#  ('CreateLabeledMaintenanceJob', 248),
#  ('FixedAssetHierarchyRelation', 248),
#  ('AnalysisWorkflowStateHistory', 248),
#  ('WorkOrderPartsDenormalized', 248)]
